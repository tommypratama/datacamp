# %% [markdown]
# # 4. Basic pandas optimizations
#
# Bab ini menawarkan pengantar singkat tentang cara bekerja secara efisien dengan pandas DataFrames. Anda akan mempelajari berbagai opsi yang Anda miliki untuk iterasi melalui DataFrame. Kemudian, Anda akan belajar cara menerapkan fungsi secara efisien ke data yang disimpan dalam DataFrame.

# %% [markdown]
# ## Intro to pandas DataFrame iteration

# %% [markdown]
# ### pandas recap
#
# * Lihat ikhtisar pandas di [Intermediate Python for Data Science](https://github.com/tommypratama/datacamp/tree/master/Intermediate%20Python%20for%20Data%20Science)
# * Library yang digunakan untuk analisis data
# * Struktur data utama adalah DataFrame
#   * Data tabular dengan baris dan kolom berlabel
#   * Dibangun di atas struktur NumPy array
# * Tujuan Bab:
#   * Praktik terbaik untuk iterasi melalui pandas DataFrame

# %% [markdown]
# ### Baseball stats

# %%
import pandas as pd

baseball_df = pd.read_csv("datasets/baseball_stats.csv", usecols=['Team', 'League', 'Year', 'RS', 'RA', 'W', 'G', 'Playoffs'])
baseball_df.head()
# Out:
#   Team League  Year   RS   RA   W  Playoffs    G
# 0  ARI     NL  2012  734  688  81         0  162
# 1  ATL     NL  2012  700  600  94         1  162
# 2  BAL     AL  2012  712  705  93         1  162
# 3  BOS     AL  2012  734  806  69         0  162
# 4  CHC     NL  2012  613  759  61         0  162

# %% [markdown]
# ### Calculating win percentage

# %%
import numpy as np

def calc_win_perc(wins, games_played):
    win_perc = wins / games_played
    return np.round(win_perc,2)

# %%
win_perc = calc_win_perc(50, 100)
print(win_perc)
# Out:
# 0.5

# %% [markdown]
# ### Adding win percentage to DataFrame

# %%
win_perc_list = []

for i in range(len(baseball_df)):
    row = baseball_df.iloc[i]
    
    wins = row['W']
    games_played = row['G']
    
    win_perc = calc_win_perc(wins, games_played)
    win_perc_list.append(win_perc)
    
baseball_df['WP'] = win_perc_list

# %%
baseball_df.head()
# Out:
#   Team League  Year   RS   RA   W  Playoffs    G    WP
# 0  ARI     NL  2012  734  688  81         0  162  0.50
# 1  ATL     NL  2012  700  600  94         1  162  0.58
# 2  BAL     AL  2012  712  705  93         1  162  0.57
# 3  BOS     AL  2012  734  806  69         0  162  0.43
# 4  CHC     NL  2012  613  759  61         0  162  0.38

# %% [markdown]
# ### Iterating with .iloc

# %%
# %%timeit
win_perc_list = []

for i in range(len(baseball_df)):
    row = baseball_df.iloc[i]
    
    wins = row['W']
    games_played = row['G']
    
    win_perc = calc_win_perc(wins, games_played)
    win_perc_list.append(win_perc)
    
baseball_df['WP'] = win_perc_list
# Out:
# 254 ms ± 2.42 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ### Iterating with .iterrows()

# %%
win_perc_list = []

for i,row in baseball_df.iterrows():
    wins = row['W']
    games_played = row['G']
    
    win_perc = calc_win_perc(wins, games_played)
    win_perc_list.append(win_perc)
    
baseball_df['WP'] = win_perc_list

# %%
# %%timeit
win_perc_list = []

for i,row in baseball_df.iterrows():
    wins = row['W']
    games_played = row['G']
    
    win_perc = calc_win_perc(wins, games_played)
    win_perc_list.append(win_perc)
    
baseball_df['WP'] = win_perc_list
# Out:
# 159 ms ± 1.95 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Practice: Iterating with .iterrows()
#
# `.iterrows()` mengembalikan setiap baris DataFrame sebagai pasangan tuple (indeks, pandas Series). Tapi apa artinya ini? Mari kita jelajahi dengan beberapa latihan coding.
#
# DataFrame pandas telah dimuat sebagai `pit_df`. DataFrame ini berisi statistik untuk tim Baseball Liga Utama bernama Pittsburgh Pirates (disingkat `'PIT'`) dari tahun 2008 hingga tahun 2012.

# %%
# Create dataframe
pit_df = baseball_df[['Team', 'League', 'Year', 'RS', 'RA', 'W', 'G', 'Playoffs']]

# %%
# Iterate over pit_df and print each row
for i,row in pit_df.iterrows():
    print(row)
# Out:
# Team         ARI
# League        NL
# Year        2012
# RS           734
# RA           688
# W             81
# G            162
# Playoffs       0
# Name: 0, dtype: object
# Team         ATL
# League        NL
# Year        2012
# RS           700
# RA           600
# W             94
# G            162
# Playoffs       1
# Name: 1, dtype: object
# Team         BAL
# League        AL
# Year        2012
# RS           712
# RA           705
# W             93
# G            162
# Playoffs       1
# Name: 2, dtype: object
# Team         BOS
# League        AL
# Year        2012
# RS           734
# RA           806
# W             69
# G            162
# Playoffs       0
# Name: 3, dtype: object
# Team         CHC
# League        NL
# Year        2012
# RS           613
# RA           759
# W             61
# G            162
# Playoffs       0
# Name: 4, dtype: object
# Team         CHW
# League        AL
# Year        2012
# RS           748
# RA           676
# W             85
# G            162
# Playoffs       0
# Name: 5, dtype: object
# Team         CIN
# League        NL
# Year        2012
# RS           669
# RA           588
# W             97
# G            162
# Playoffs       1
# Name: 6, dtype: object
# Team         CLE
# League        AL
# Year        2012
# RS           667
# RA           845
# W             68
# G            162
# Playoffs       0
# Name: 7, dtype: object
# Team         COL
# League        NL
# Year        2012
# RS           758
# RA           890
# W             64
# G            162
# Playoffs       0
# Name: 8, dtype: object
# Team         DET
# League        AL
# Year        2012
# RS           726
# RA           670
# W             88
# G            162
# Playoffs       1
# Name: 9, dtype: object
# Team         HOU
# League        NL
# Year        2012
# RS           583
# RA           794
# W             55
# G            162
# Playoffs       0
# Name: 10, dtype: object
# Team         KCR
# League        AL
# Year        2012
# RS           676
# RA           746
# W             72
# G            162
# Playoffs       0
# Name: 11, dtype: object
# Team         LAA
# League        AL
# Year        2012
# RS           767
# RA           699
# W             89
# G            162
# Playoffs       0
# Name: 12, dtype: object
# Team         LAD
# League        NL
# Year        2012
# RS           637
# RA           597
# W             86
# G            162
# Playoffs       0
# Name: 13, dtype: object
# Team         MIA
# League        NL
# Year        2012
# RS           609
# RA           724
# W             69
# G            162
# Playoffs       0
# Name: 14, dtype: object
# Team         MIL
# League        NL
# Year        2012
# RS           776
# RA           733
# W             83
# G            162
# Playoffs       0
# Name: 15, dtype: object
# Team         MIN
# League        AL
# Year        2012
# RS           701
# RA           832
# W             66
# G            162
# Playoffs       0
# Name: 16, dtype: object
# Team         NYM
# League        NL
# Year        2012
# RS           650
# RA           709
# W             74
# G            162
# Playoffs       0
# Name: 17, dtype: object
# Team         NYY
# League        AL
# Year        2012
# RS           804
# RA           668
# W             95
# G            162
# Playoffs       1
# Name: 18, dtype: object
# Team         OAK
# League        AL
# Year        2012
# RS           713
# RA           614
# W             94
# G            162
# Playoffs       1
# Name: 19, dtype: object
# Team         PHI
# League        NL
# Year        2012
# RS           684
# RA           680
# W             81
# G            162
# Playoffs       0
# Name: 20, dtype: object
# Team         PIT
# League        NL
# Year        2012
# RS           651
# RA           674
# W             79
# G            162
# Playoffs       0
# Name: 21, dtype: object
# Team         SDP
# League        NL
# Year        2012
# RS           651
# RA           710
# W             76
# G            162
# Playoffs       0
# Name: 22, dtype: object
# Team         SEA
# League        AL
# Year        2012
# RS           619
# RA           651
# W             75
# G            162
# Playoffs       0
# Name: 23, dtype: object
# Team         SFG
# League        NL
# Year        2012
# RS           718
# RA           649
# W             94
# G            162
# Playoffs       1
# Name: 24, dtype: object
# Team         STL
# League        NL
# Year        2012
# RS           765
# RA           648
# W             88
# G            162
# Playoffs       1
# Name: 25, dtype: object
# Team         TBR
# League        AL
# Year        2012
# RS           697
# RA           577
# W             90
# G            162
# Playoffs       0
# Name: 26, dtype: object
# Team         TEX
# League        AL
# Year        2012
# RS           808
# RA           707
# W             93
# G            162
# Playoffs       1
# Name: 27, dtype: object
# Team         TOR
# League        AL
# Year        2012
# RS           716
# RA           784
# W             73
# G            162
# Playoffs       0
# Name: 28, dtype: object
# Team         WSN
# League        NL
# Year        2012
# RS           731
# RA           594
# W             98
# G            162
# Playoffs       1
# Name: 29, dtype: object
# Team         ARI
# League        NL
# Year        2011
# RS           731
# RA           662
# W             94
# G            162
# Playoffs       1
# Name: 30, dtype: object
# Team         ATL
# League        NL
# Year        2011
# RS           641
# RA           605
# W             89
# G            162
# Playoffs       0
# Name: 31, dtype: object
# Team         BAL
# League        AL
# Year        2011
# RS           708
# RA           860
# W             69
# G            162
# Playoffs       0
# Name: 32, dtype: object
# Team         BOS
# League        AL
# Year        2011
# RS           875
# RA           737
# W             90
# G            162
# Playoffs       0
# Name: 33, dtype: object
# Team         CHC
# League        NL
# Year        2011
# RS           654
# RA           756
# W             71
# G            162
# Playoffs       0
# Name: 34, dtype: object
# Team         CHW
# League        AL
# Year        2011
# RS           654
# RA           706
# W             79
# G            162
# Playoffs       0
# Name: 35, dtype: object
# Team         CIN
# League        NL
# Year        2011
# RS           735
# RA           720
# W             79
# G            162
# Playoffs       0
# Name: 36, dtype: object
# Team         CLE
# League        AL
# Year        2011
# RS           704
# RA           760
# W             80
# G            162
# Playoffs       0
# Name: 37, dtype: object
# Team         COL
# League        NL
# Year        2011
# RS           735
# RA           774
# W             73
# G            162
# Playoffs       0
# Name: 38, dtype: object
# Team         DET
# League        AL
# Year        2011
# RS           787
# RA           711
# W             95
# G            162
# Playoffs       1
# Name: 39, dtype: object
# Team         FLA
# League        NL
# Year        2011
# RS           625
# RA           702
# W             72
# G            162
# Playoffs       0
# Name: 40, dtype: object
# Team         HOU
# League        NL
# Year        2011
# RS           615
# RA           796
# W             56
# G            162
# Playoffs       0
# Name: 41, dtype: object
# Team         KCR
# League        AL
# Year        2011
# RS           730
# RA           762
# W             71
# G            162
# Playoffs       0
# Name: 42, dtype: object
# Team         LAA
# League        AL
# Year        2011
# RS           667
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 43, dtype: object
# Team         LAD
# League        NL
# Year        2011
# RS           644
# RA           612
# W             82
# G            161
# Playoffs       0
# Name: 44, dtype: object
# Team         MIL
# League        NL
# Year        2011
# RS           721
# RA           638
# W             96
# G            162
# Playoffs       1
# Name: 45, dtype: object
# Team         MIN
# League        AL
# Year        2011
# RS           619
# RA           804
# W             63
# G            162
# Playoffs       0
# Name: 46, dtype: object
# Team         NYM
# League        NL
# Year        2011
# RS           718
# RA           742
# W             77
# G            162
# Playoffs       0
# Name: 47, dtype: object
# Team         NYY
# League        AL
# Year        2011
# RS           867
# RA           657
# W             97
# G            162
# Playoffs       1
# Name: 48, dtype: object
# Team         OAK
# League        AL
# Year        2011
# RS           645
# RA           679
# W             74
# G            162
# Playoffs       0
# Name: 49, dtype: object
# Team         PHI
# League        NL
# Year        2011
# RS           713
# RA           529
# W            102
# G            162
# Playoffs       1
# Name: 50, dtype: object
# Team         PIT
# League        NL
# Year        2011
# RS           610
# RA           712
# W             72
# G            162
# Playoffs       0
# Name: 51, dtype: object
# Team         SDP
# League        NL
# Year        2011
# RS           593
# RA           611
# W             71
# G            162
# Playoffs       0
# Name: 52, dtype: object
# Team         SEA
# League        AL
# Year        2011
# RS           556
# RA           675
# W             67
# G            162
# Playoffs       0
# Name: 53, dtype: object
# Team         SFG
# League        NL
# Year        2011
# RS           570
# RA           578
# W             86
# G            162
# Playoffs       0
# Name: 54, dtype: object
# Team         STL
# League        NL
# Year        2011
# RS           762
# RA           692
# W             90
# G            162
# Playoffs       1
# Name: 55, dtype: object
# Team         TBR
# League        AL
# Year        2011
# RS           707
# RA           614
# W             91
# G            162
# Playoffs       1
# Name: 56, dtype: object
# Team         TEX
# League        AL
# Year        2011
# RS           855
# RA           677
# W             96
# G            162
# Playoffs       1
# Name: 57, dtype: object
# Team         TOR
# League        AL
# Year        2011
# RS           743
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 58, dtype: object
# Team         WSN
# League        NL
# Year        2011
# RS           624
# RA           643
# W             80
# G            161
# Playoffs       0
# Name: 59, dtype: object
# Team         ARI
# League        NL
# Year        2010
# RS           713
# RA           836
# W             65
# G            162
# Playoffs       0
# Name: 60, dtype: object
# Team         ATL
# League        NL
# Year        2010
# RS           738
# RA           629
# W             91
# G            162
# Playoffs       1
# Name: 61, dtype: object
# Team         BAL
# League        AL
# Year        2010
# RS           613
# RA           785
# W             66
# G            162
# Playoffs       0
# Name: 62, dtype: object
# Team         BOS
# League        AL
# Year        2010
# RS           818
# RA           744
# W             89
# G            162
# Playoffs       0
# Name: 63, dtype: object
# Team         CHC
# League        NL
# Year        2010
# RS           685
# RA           767
# W             75
# G            162
# Playoffs       0
# Name: 64, dtype: object
# Team         CHW
# League        AL
# Year        2010
# RS           752
# RA           704
# W             88
# G            162
# Playoffs       0
# Name: 65, dtype: object
# Team         CIN
# League        NL
# Year        2010
# RS           790
# RA           685
# W             91
# G            162
# Playoffs       1
# Name: 66, dtype: object
# Team         CLE
# League        AL
# Year        2010
# RS           646
# RA           752
# W             69
# G            162
# Playoffs       0
# Name: 67, dtype: object
# Team         COL
# League        NL
# Year        2010
# RS           770
# RA           717
# W             83
# G            162
# Playoffs       0
# Name: 68, dtype: object
# Team         DET
# League        AL
# Year        2010
# RS           751
# RA           743
# W             81
# G            162
# Playoffs       0
# Name: 69, dtype: object
# Team         FLA
# League        NL
# Year        2010
# RS           719
# RA           717
# W             80
# G            162
# Playoffs       0
# Name: 70, dtype: object
# Team         HOU
# League        NL
# Year        2010
# RS           611
# RA           729
# W             76
# G            162
# Playoffs       0
# Name: 71, dtype: object
# Team         KCR
# League        AL
# Year        2010
# RS           676
# RA           845
# W             67
# G            162
# Playoffs       0
# Name: 72, dtype: object
# Team         LAA
# League        AL
# Year        2010
# RS           681
# RA           702
# W             80
# G            162
# Playoffs       0
# Name: 73, dtype: object
# Team         LAD
# League        NL
# Year        2010
# RS           667
# RA           692
# W             80
# G            162
# Playoffs       0
# Name: 74, dtype: object
# Team         MIL
# League        NL
# Year        2010
# RS           750
# RA           804
# W             77
# G            162
# Playoffs       0
# Name: 75, dtype: object
# Team         MIN
# League        AL
# Year        2010
# RS           781
# RA           671
# W             94
# G            162
# Playoffs       1
# Name: 76, dtype: object
# Team         NYM
# League        NL
# Year        2010
# RS           656
# RA           652
# W             79
# G            162
# Playoffs       0
# Name: 77, dtype: object
# Team         NYY
# League        AL
# Year        2010
# RS           859
# RA           693
# W             95
# G            162
# Playoffs       1
# Name: 78, dtype: object
# Team         OAK
# League        AL
# Year        2010
# RS           663
# RA           626
# W             81
# G            162
# Playoffs       0
# Name: 79, dtype: object
# Team         PHI
# League        NL
# Year        2010
# RS           772
# RA           640
# W             97
# G            162
# Playoffs       1
# Name: 80, dtype: object
# Team         PIT
# League        NL
# Year        2010
# RS           587
# RA           866
# W             57
# G            162
# Playoffs       0
# Name: 81, dtype: object
# Team         SDP
# League        NL
# Year        2010
# RS           665
# RA           581
# W             90
# G            162
# Playoffs       0
# Name: 82, dtype: object
# Team         SEA
# League        AL
# Year        2010
# RS           513
# RA           698
# W             61
# G            162
# Playoffs       0
# Name: 83, dtype: object
# Team         SFG
# League        NL
# Year        2010
# RS           697
# RA           583
# W             92
# G            162
# Playoffs       1
# Name: 84, dtype: object
# Team         STL
# League        NL
# Year        2010
# RS           736
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 85, dtype: object
# Team         TBR
# League        AL
# Year        2010
# RS           802
# RA           649
# W             96
# G            162
# Playoffs       1
# Name: 86, dtype: object
# Team         TEX
# League        AL
# Year        2010
# RS           787
# RA           687
# W             90
# G            162
# Playoffs       1
# Name: 87, dtype: object
# Team         TOR
# League        AL
# Year        2010
# RS           755
# RA           728
# W             85
# G            162
# Playoffs       0
# Name: 88, dtype: object
# Team         WSN
# League        NL
# Year        2010
# RS           655
# RA           742
# W             69
# G            162
# Playoffs       0
# Name: 89, dtype: object
# Team         ARI
# League        NL
# Year        2009
# RS           720
# RA           782
# W             70
# G            162
# Playoffs       0
# Name: 90, dtype: object
# Team         ATL
# League        NL
# Year        2009
# RS           735
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 91, dtype: object
# Team         BAL
# League        AL
# Year        2009
# RS           741
# RA           876
# W             64
# G            162
# Playoffs       0
# Name: 92, dtype: object
# Team         BOS
# League        AL
# Year        2009
# RS           872
# RA           736
# W             95
# G            162
# Playoffs       1
# Name: 93, dtype: object
# Team         CHC
# League        NL
# Year        2009
# RS           707
# RA           672
# W             83
# G            161
# Playoffs       0
# Name: 94, dtype: object
# Team         CHW
# League        AL
# Year        2009
# RS           724
# RA           732
# W             79
# G            162
# Playoffs       0
# Name: 95, dtype: object
# Team         CIN
# League        NL
# Year        2009
# RS           673
# RA           723
# W             78
# G            162
# Playoffs       0
# Name: 96, dtype: object
# Team         CLE
# League        AL
# Year        2009
# RS           773
# RA           865
# W             65
# G            162
# Playoffs       0
# Name: 97, dtype: object
# Team         COL
# League        NL
# Year        2009
# RS           804
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 98, dtype: object
# Team         DET
# League        AL
# Year        2009
# RS           743
# RA           745
# W             86
# G            163
# Playoffs       0
# Name: 99, dtype: object
# Team         FLA
# League        NL
# Year        2009
# RS           772
# RA           766
# W             87
# G            162
# Playoffs       0
# Name: 100, dtype: object
# Team         HOU
# League        NL
# Year        2009
# RS           643
# RA           770
# W             74
# G            162
# Playoffs       0
# Name: 101, dtype: object
# Team         KCR
# League        AL
# Year        2009
# RS           686
# RA           842
# W             65
# G            162
# Playoffs       0
# Name: 102, dtype: object
# Team         LAA
# League        AL
# Year        2009
# RS           883
# RA           761
# W             97
# G            162
# Playoffs       1
# Name: 103, dtype: object
# Team         LAD
# League        NL
# Year        2009
# RS           780
# RA           611
# W             95
# G            162
# Playoffs       1
# Name: 104, dtype: object
# Team         MIL
# League        NL
# Year        2009
# RS           785
# RA           818
# W             80
# G            162
# Playoffs       0
# Name: 105, dtype: object
# Team         MIN
# League        AL
# Year        2009
# RS           817
# RA           765
# W             87
# G            163
# Playoffs       1
# Name: 106, dtype: object
# Team         NYM
# League        NL
# Year        2009
# RS           671
# RA           757
# W             70
# G            162
# Playoffs       0
# Name: 107, dtype: object
# Team         NYY
# League        AL
# Year        2009
# RS           915
# RA           753
# W            103
# G            162
# Playoffs       1
# Name: 108, dtype: object
# Team         OAK
# League        AL
# Year        2009
# RS           759
# RA           761
# W             75
# G            162
# Playoffs       0
# Name: 109, dtype: object
# Team         PHI
# League        NL
# Year        2009
# RS           820
# RA           709
# W             93
# G            162
# Playoffs       1
# Name: 110, dtype: object
# Team         PIT
# League        NL
# Year        2009
# RS           636
# RA           768
# W             62
# G            161
# Playoffs       0
# Name: 111, dtype: object
# Team         SDP
# League        NL
# Year        2009
# RS           638
# RA           769
# W             75
# G            162
# Playoffs       0
# Name: 112, dtype: object
# Team         SEA
# League        AL
# Year        2009
# RS           640
# RA           692
# W             85
# G            162
# Playoffs       0
# Name: 113, dtype: object
# Team         SFG
# League        NL
# Year        2009
# RS           657
# RA           611
# W             88
# G            162
# Playoffs       0
# Name: 114, dtype: object
# Team         STL
# League        NL
# Year        2009
# RS           730
# RA           640
# W             91
# G            162
# Playoffs       1
# Name: 115, dtype: object
# Team         TBR
# League        AL
# Year        2009
# RS           803
# RA           754
# W             84
# G            162
# Playoffs       0
# Name: 116, dtype: object
# Team         TEX
# League        AL
# Year        2009
# RS           784
# RA           740
# W             87
# G            162
# Playoffs       0
# Name: 117, dtype: object
# Team         TOR
# League        AL
# Year        2009
# RS           798
# RA           771
# W             75
# G            162
# Playoffs       0
# Name: 118, dtype: object
# Team         WSN
# League        NL
# Year        2009
# RS           710
# RA           874
# W             59
# G            162
# Playoffs       0
# Name: 119, dtype: object
# Team         ARI
# League        NL
# Year        2008
# RS           720
# RA           706
# W             82
# G            162
# Playoffs       0
# Name: 120, dtype: object
# Team         ATL
# League        NL
# Year        2008
# RS           753
# RA           778
# W             72
# G            162
# Playoffs       0
# Name: 121, dtype: object
# Team         BAL
# League        AL
# Year        2008
# RS           782
# RA           869
# W             68
# G            161
# Playoffs       0
# Name: 122, dtype: object
# Team         BOS
# League        AL
# Year        2008
# RS           845
# RA           694
# W             95
# G            162
# Playoffs       1
# Name: 123, dtype: object
# Team         CHC
# League        NL
# Year        2008
# RS           855
# RA           671
# W             97
# G            161
# Playoffs       1
# Name: 124, dtype: object
# Team         CHW
# League        AL
# Year        2008
# RS           811
# RA           729
# W             89
# G            163
# Playoffs       1
# Name: 125, dtype: object
# Team         CIN
# League        NL
# Year        2008
# RS           704
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 126, dtype: object
# Team         CLE
# League        AL
# Year        2008
# RS           805
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 127, dtype: object
# Team         COL
# League        NL
# Year        2008
# RS           747
# RA           822
# W             74
# G            162
# Playoffs       0
# Name: 128, dtype: object
# Team         DET
# League        AL
# Year        2008
# RS           821
# RA           857
# W             74
# G            162
# Playoffs       0
# Name: 129, dtype: object
# Team         FLA
# League        NL
# Year        2008
# RS           770
# RA           767
# W             84
# G            161
# Playoffs       0
# Name: 130, dtype: object
# Team         HOU
# League        NL
# Year        2008
# RS           712
# RA           743
# W             86
# G            161
# Playoffs       0
# Name: 131, dtype: object
# Team         KCR
# League        AL
# Year        2008
# RS           691
# RA           781
# W             75
# G            162
# Playoffs       0
# Name: 132, dtype: object
# Team         LAA
# League        AL
# Year        2008
# RS           765
# RA           697
# W            100
# G            162
# Playoffs       1
# Name: 133, dtype: object
# Team         LAD
# League        NL
# Year        2008
# RS           700
# RA           648
# W             84
# G            162
# Playoffs       1
# Name: 134, dtype: object
# Team         MIL
# League        NL
# Year        2008
# RS           750
# RA           689
# W             90
# G            162
# Playoffs       1
# Name: 135, dtype: object
# Team         MIN
# League        AL
# Year        2008
# RS           829
# RA           745
# W             88
# G            163
# Playoffs       0
# Name: 136, dtype: object
# Team         NYM
# League        NL
# Year        2008
# RS           799
# RA           715
# W             89
# G            162
# Playoffs       0
# Name: 137, dtype: object
# Team         NYY
# League        AL
# Year        2008
# RS           789
# RA           727
# W             89
# G            162
# Playoffs       0
# Name: 138, dtype: object
# Team         OAK
# League        AL
# Year        2008
# RS           646
# RA           690
# W             75
# G            161
# Playoffs       0
# Name: 139, dtype: object
# Team         PHI
# League        NL
# Year        2008
# RS           799
# RA           680
# W             92
# G            162
# Playoffs       1
# Name: 140, dtype: object
# Team         PIT
# League        NL
# Year        2008
# RS           735
# RA           884
# W             67
# G            162
# Playoffs       0
# Name: 141, dtype: object
# Team         SDP
# League        NL
# Year        2008
# RS           637
# RA           764
# W             63
# G            162
# Playoffs       0
# Name: 142, dtype: object
# Team         SEA
# League        AL
# Year        2008
# RS           671
# RA           811
# W             61
# G            162
# Playoffs       0
# Name: 143, dtype: object
# Team         SFG
# League        NL
# Year        2008
# RS           640
# RA           759
# W             72
# G            162
# Playoffs       0
# Name: 144, dtype: object
# Team         STL
# League        NL
# Year        2008
# RS           779
# RA           725
# W             86
# G            162
# Playoffs       0
# Name: 145, dtype: object
# Team         TBR
# League        AL
# Year        2008
# RS           774
# RA           671
# W             97
# G            162
# Playoffs       1
# Name: 146, dtype: object
# Team         TEX
# League        AL
# Year        2008
# RS           901
# RA           967
# W             79
# G            162
# Playoffs       0
# Name: 147, dtype: object
# Team         TOR
# League        AL
# Year        2008
# RS           714
# RA           610
# W             86
# G            162
# Playoffs       0
# Name: 148, dtype: object
# Team         WSN
# League        NL
# Year        2008
# RS           641
# RA           825
# W             59
# G            161
# Playoffs       0
# Name: 149, dtype: object
# Team         ARI
# League        NL
# Year        2007
# RS           712
# RA           732
# W             90
# G            162
# Playoffs       1
# Name: 150, dtype: object
# Team         ATL
# League        NL
# Year        2007
# RS           810
# RA           733
# W             84
# G            162
# Playoffs       0
# Name: 151, dtype: object
# Team         BAL
# League        AL
# Year        2007
# RS           756
# RA           868
# W             69
# G            162
# Playoffs       0
# Name: 152, dtype: object
# Team         BOS
# League        AL
# Year        2007
# RS           867
# RA           657
# W             96
# G            162
# Playoffs       1
# Name: 153, dtype: object
# Team         CHC
# League        NL
# Year        2007
# RS           752
# RA           690
# W             85
# G            162
# Playoffs       1
# Name: 154, dtype: object
# Team         CHW
# League        AL
# Year        2007
# RS           693
# RA           839
# W             72
# G            162
# Playoffs       0
# Name: 155, dtype: object
# Team         CIN
# League        NL
# Year        2007
# RS           783
# RA           853
# W             72
# G            162
# Playoffs       0
# Name: 156, dtype: object
# Team         CLE
# League        AL
# Year        2007
# RS           811
# RA           704
# W             96
# G            162
# Playoffs       1
# Name: 157, dtype: object
# Team         COL
# League        NL
# Year        2007
# RS           860
# RA           758
# W             90
# G            163
# Playoffs       1
# Name: 158, dtype: object
# Team         DET
# League        AL
# Year        2007
# RS           887
# RA           797
# W             88
# G            162
# Playoffs       0
# Name: 159, dtype: object
# Team         FLA
# League        NL
# Year        2007
# RS           790
# RA           891
# W             71
# G            162
# Playoffs       0
# Name: 160, dtype: object
# Team         HOU
# League        NL
# Year        2007
# RS           723
# RA           813
# W             73
# G            162
# Playoffs       0
# Name: 161, dtype: object
# Team         KCR
# League        AL
# Year        2007
# RS           706
# RA           778
# W             69
# G            162
# Playoffs       0
# Name: 162, dtype: object
# Team         LAA
# League        AL
# Year        2007
# RS           822
# RA           731
# W             94
# G            162
# Playoffs       1
# Name: 163, dtype: object
# Team         LAD
# League        NL
# Year        2007
# RS           735
# RA           727
# W             82
# G            162
# Playoffs       0
# Name: 164, dtype: object
# Team         MIL
# League        NL
# Year        2007
# RS           801
# RA           776
# W             83
# G            162
# Playoffs       0
# Name: 165, dtype: object
# Team         MIN
# League        AL
# Year        2007
# RS           718
# RA           725
# W             79
# G            162
# Playoffs       0
# Name: 166, dtype: object
# Team         NYM
# League        NL
# Year        2007
# RS           804
# RA           750
# W             88
# G            162
# Playoffs       0
# Name: 167, dtype: object
# Team         NYY
# League        AL
# Year        2007
# RS           968
# RA           777
# W             94
# G            162
# Playoffs       1
# Name: 168, dtype: object
# Team         OAK
# League        AL
# Year        2007
# RS           741
# RA           758
# W             76
# G            162
# Playoffs       0
# Name: 169, dtype: object
# Team         PHI
# League        NL
# Year        2007
# RS           892
# RA           821
# W             89
# G            162
# Playoffs       1
# Name: 170, dtype: object
# Team         PIT
# League        NL
# Year        2007
# RS           724
# RA           846
# W             68
# G            162
# Playoffs       0
# Name: 171, dtype: object
# Team         SDP
# League        NL
# Year        2007
# RS           741
# RA           666
# W             89
# G            163
# Playoffs       0
# Name: 172, dtype: object
# Team         SEA
# League        AL
# Year        2007
# RS           794
# RA           813
# W             88
# G            162
# Playoffs       0
# Name: 173, dtype: object
# Team         SFG
# League        NL
# Year        2007
# RS           683
# RA           720
# W             71
# G            162
# Playoffs       0
# Name: 174, dtype: object
# Team         STL
# League        NL
# Year        2007
# RS           725
# RA           829
# W             78
# G            162
# Playoffs       0
# Name: 175, dtype: object
# Team         TBD
# League        AL
# Year        2007
# RS           782
# RA           944
# W             66
# G            162
# Playoffs       0
# Name: 176, dtype: object
# Team         TEX
# League        AL
# Year        2007
# RS           816
# RA           844
# W             75
# G            162
# Playoffs       0
# Name: 177, dtype: object
# Team         TOR
# League        AL
# Year        2007
# RS           753
# RA           699
# W             83
# G            162
# Playoffs       0
# Name: 178, dtype: object
# Team         WSN
# League        NL
# Year        2007
# RS           673
# RA           783
# W             73
# G            162
# Playoffs       0
# Name: 179, dtype: object
# Team         ARI
# League        NL
# Year        2006
# RS           773
# RA           788
# W             76
# G            162
# Playoffs       0
# Name: 180, dtype: object
# Team         ATL
# League        NL
# Year        2006
# RS           849
# RA           805
# W             79
# G            162
# Playoffs       0
# Name: 181, dtype: object
# Team         BAL
# League        AL
# Year        2006
# RS           768
# RA           899
# W             70
# G            162
# Playoffs       0
# Name: 182, dtype: object
# Team         BOS
# League        AL
# Year        2006
# RS           820
# RA           825
# W             86
# G            162
# Playoffs       0
# Name: 183, dtype: object
# Team         CHC
# League        NL
# Year        2006
# RS           716
# RA           834
# W             66
# G            162
# Playoffs       0
# Name: 184, dtype: object
# Team         CHW
# League        AL
# Year        2006
# RS           868
# RA           794
# W             90
# G            162
# Playoffs       0
# Name: 185, dtype: object
# Team         CIN
# League        NL
# Year        2006
# RS           749
# RA           801
# W             80
# G            162
# Playoffs       0
# Name: 186, dtype: object
# Team         CLE
# League        AL
# Year        2006
# RS           870
# RA           782
# W             78
# G            162
# Playoffs       0
# Name: 187, dtype: object
# Team         COL
# League        NL
# Year        2006
# RS           813
# RA           812
# W             76
# G            162
# Playoffs       0
# Name: 188, dtype: object
# Team         DET
# League        AL
# Year        2006
# RS           822
# RA           675
# W             95
# G            162
# Playoffs       1
# Name: 189, dtype: object
# Team         FLA
# League        NL
# Year        2006
# RS           758
# RA           772
# W             78
# G            162
# Playoffs       0
# Name: 190, dtype: object
# Team         HOU
# League        NL
# Year        2006
# RS           735
# RA           719
# W             82
# G            162
# Playoffs       0
# Name: 191, dtype: object
# Team         KCR
# League        AL
# Year        2006
# RS           757
# RA           971
# W             62
# G            162
# Playoffs       0
# Name: 192, dtype: object
# Team         LAA
# League        AL
# Year        2006
# RS           766
# RA           732
# W             89
# G            162
# Playoffs       0
# Name: 193, dtype: object
# Team         LAD
# League        NL
# Year        2006
# RS           820
# RA           751
# W             88
# G            162
# Playoffs       1
# Name: 194, dtype: object
# Team         MIL
# League        NL
# Year        2006
# RS           730
# RA           833
# W             75
# G            162
# Playoffs       0
# Name: 195, dtype: object
# Team         MIN
# League        AL
# Year        2006
# RS           801
# RA           683
# W             96
# G            162
# Playoffs       1
# Name: 196, dtype: object
# Team         NYM
# League        NL
# Year        2006
# RS           834
# RA           731
# W             97
# G            162
# Playoffs       1
# Name: 197, dtype: object
# Team         NYY
# League        AL
# Year        2006
# RS           930
# RA           767
# W             97
# G            162
# Playoffs       1
# Name: 198, dtype: object
# Team         OAK
# League        AL
# Year        2006
# RS           771
# RA           727
# W             93
# G            162
# Playoffs       1
# Name: 199, dtype: object
# Team         PHI
# League        NL
# Year        2006
# RS           865
# RA           812
# W             85
# G            162
# Playoffs       0
# Name: 200, dtype: object
# Team         PIT
# League        NL
# Year        2006
# RS           691
# RA           797
# W             67
# G            162
# Playoffs       0
# Name: 201, dtype: object
# Team         SDP
# League        NL
# Year        2006
# RS           731
# RA           679
# W             88
# G            162
# Playoffs       1
# Name: 202, dtype: object
# Team         SEA
# League        AL
# Year        2006
# RS           756
# RA           792
# W             78
# G            162
# Playoffs       0
# Name: 203, dtype: object
# Team         SFG
# League        NL
# Year        2006
# RS           746
# RA           790
# W             76
# G            161
# Playoffs       0
# Name: 204, dtype: object
# Team         STL
# League        NL
# Year        2006
# RS           781
# RA           762
# W             83
# G            161
# Playoffs       1
# Name: 205, dtype: object
# Team         TBD
# League        AL
# Year        2006
# RS           689
# RA           856
# W             61
# G            162
# Playoffs       0
# Name: 206, dtype: object
# Team         TEX
# League        AL
# Year        2006
# RS           835
# RA           784
# W             80
# G            162
# Playoffs       0
# Name: 207, dtype: object
# Team         TOR
# League        AL
# Year        2006
# RS           809
# RA           754
# W             87
# G            162
# Playoffs       0
# Name: 208, dtype: object
# Team         WSN
# League        NL
# Year        2006
# RS           746
# RA           872
# W             71
# G            162
# Playoffs       0
# Name: 209, dtype: object
# Team         ARI
# League        NL
# Year        2005
# RS           696
# RA           856
# W             77
# G            162
# Playoffs       0
# Name: 210, dtype: object
# Team         ATL
# League        NL
# Year        2005
# RS           769
# RA           674
# W             90
# G            162
# Playoffs       1
# Name: 211, dtype: object
# Team         BAL
# League        AL
# Year        2005
# RS           729
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 212, dtype: object
# Team         BOS
# League        AL
# Year        2005
# RS           910
# RA           805
# W             95
# G            162
# Playoffs       1
# Name: 213, dtype: object
# Team         CHC
# League        NL
# Year        2005
# RS           703
# RA           714
# W             79
# G            162
# Playoffs       0
# Name: 214, dtype: object
# Team         CHW
# League        AL
# Year        2005
# RS           741
# RA           645
# W             99
# G            162
# Playoffs       1
# Name: 215, dtype: object
# Team         CIN
# League        NL
# Year        2005
# RS           820
# RA           889
# W             73
# G            163
# Playoffs       0
# Name: 216, dtype: object
# Team         CLE
# League        AL
# Year        2005
# RS           790
# RA           642
# W             93
# G            162
# Playoffs       0
# Name: 217, dtype: object
# Team         COL
# League        NL
# Year        2005
# RS           740
# RA           862
# W             67
# G            162
# Playoffs       0
# Name: 218, dtype: object
# Team         DET
# League        AL
# Year        2005
# RS           723
# RA           787
# W             71
# G            162
# Playoffs       0
# Name: 219, dtype: object
# Team         FLA
# League        NL
# Year        2005
# RS           717
# RA           732
# W             83
# G            162
# Playoffs       0
# Name: 220, dtype: object
# Team         HOU
# League        NL
# Year        2005
# RS           693
# RA           609
# W             89
# G            163
# Playoffs       1
# Name: 221, dtype: object
# Team         KCR
# League        AL
# Year        2005
# RS           701
# RA           935
# W             56
# G            162
# Playoffs       0
# Name: 222, dtype: object
# Team         LAA
# League        AL
# Year        2005
# RS           761
# RA           643
# W             95
# G            162
# Playoffs       1
# Name: 223, dtype: object
# Team         LAD
# League        NL
# Year        2005
# RS           685
# RA           755
# W             71
# G            162
# Playoffs       0
# Name: 224, dtype: object
# Team         MIL
# League        NL
# Year        2005
# RS           726
# RA           697
# W             81
# G            162
# Playoffs       0
# Name: 225, dtype: object
# Team         MIN
# League        AL
# Year        2005
# RS           688
# RA           662
# W             83
# G            162
# Playoffs       0
# Name: 226, dtype: object
# Team         NYM
# League        NL
# Year        2005
# RS           722
# RA           648
# W             83
# G            162
# Playoffs       0
# Name: 227, dtype: object
# Team         NYY
# League        AL
# Year        2005
# RS           886
# RA           789
# W             95
# G            162
# Playoffs       1
# Name: 228, dtype: object
# Team         OAK
# League        AL
# Year        2005
# RS           772
# RA           658
# W             88
# G            162
# Playoffs       0
# Name: 229, dtype: object
# Team         PHI
# League        NL
# Year        2005
# RS           807
# RA           726
# W             88
# G            162
# Playoffs       0
# Name: 230, dtype: object
# Team         PIT
# League        NL
# Year        2005
# RS           680
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 231, dtype: object
# Team         SDP
# League        NL
# Year        2005
# RS           684
# RA           726
# W             82
# G            162
# Playoffs       1
# Name: 232, dtype: object
# Team         SEA
# League        AL
# Year        2005
# RS           699
# RA           751
# W             69
# G            162
# Playoffs       0
# Name: 233, dtype: object
# Team         SFG
# League        NL
# Year        2005
# RS           649
# RA           745
# W             75
# G            162
# Playoffs       0
# Name: 234, dtype: object
# Team         STL
# League        NL
# Year        2005
# RS           805
# RA           634
# W            100
# G            162
# Playoffs       1
# Name: 235, dtype: object
# Team         TBD
# League        AL
# Year        2005
# RS           750
# RA           936
# W             67
# G            162
# Playoffs       0
# Name: 236, dtype: object
# Team         TEX
# League        AL
# Year        2005
# RS           865
# RA           858
# W             79
# G            162
# Playoffs       0
# Name: 237, dtype: object
# Team         TOR
# League        AL
# Year        2005
# RS           775
# RA           705
# W             80
# G            162
# Playoffs       0
# Name: 238, dtype: object
# Team         WSN
# League        NL
# Year        2005
# RS           639
# RA           673
# W             81
# G            162
# Playoffs       0
# Name: 239, dtype: object
# Team         ANA
# League        AL
# Year        2004
# RS           836
# RA           734
# W             92
# G            162
# Playoffs       1
# Name: 240, dtype: object
# Team         ARI
# League        NL
# Year        2004
# RS           615
# RA           899
# W             51
# G            162
# Playoffs       0
# Name: 241, dtype: object
# Team         ATL
# League        NL
# Year        2004
# RS           803
# RA           668
# W             96
# G            162
# Playoffs       1
# Name: 242, dtype: object
# Team         BAL
# League        AL
# Year        2004
# RS           842
# RA           830
# W             78
# G            162
# Playoffs       0
# Name: 243, dtype: object
# Team         BOS
# League        AL
# Year        2004
# RS           949
# RA           768
# W             98
# G            162
# Playoffs       1
# Name: 244, dtype: object
# Team         CHC
# League        NL
# Year        2004
# RS           789
# RA           665
# W             89
# G            162
# Playoffs       0
# Name: 245, dtype: object
# Team         CHW
# League        AL
# Year        2004
# RS           865
# RA           831
# W             83
# G            162
# Playoffs       0
# Name: 246, dtype: object
# Team         CIN
# League        NL
# Year        2004
# RS           750
# RA           907
# W             76
# G            162
# Playoffs       0
# Name: 247, dtype: object
# Team         CLE
# League        AL
# Year        2004
# RS           858
# RA           857
# W             80
# G            162
# Playoffs       0
# Name: 248, dtype: object
# Team         COL
# League        NL
# Year        2004
# RS           833
# RA           923
# W             68
# G            162
# Playoffs       0
# Name: 249, dtype: object
# Team         DET
# League        AL
# Year        2004
# RS           827
# RA           844
# W             72
# G            162
# Playoffs       0
# Name: 250, dtype: object
# Team         FLA
# League        NL
# Year        2004
# RS           718
# RA           700
# W             83
# G            162
# Playoffs       0
# Name: 251, dtype: object
# Team         HOU
# League        NL
# Year        2004
# RS           803
# RA           698
# W             92
# G            162
# Playoffs       1
# Name: 252, dtype: object
# Team         KCR
# League        AL
# Year        2004
# RS           720
# RA           905
# W             58
# G            162
# Playoffs       0
# Name: 253, dtype: object
# Team         LAD
# League        NL
# Year        2004
# RS           761
# RA           684
# W             93
# G            162
# Playoffs       1
# Name: 254, dtype: object
# Team         MIL
# League        NL
# Year        2004
# RS           634
# RA           757
# W             67
# G            161
# Playoffs       0
# Name: 255, dtype: object
# Team         MIN
# League        AL
# Year        2004
# RS           780
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 256, dtype: object
# Team         MON
# League        NL
# Year        2004
# RS           635
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 257, dtype: object
# Team         NYM
# League        NL
# Year        2004
# RS           684
# RA           731
# W             71
# G            162
# Playoffs       0
# Name: 258, dtype: object
# Team         NYY
# League        AL
# Year        2004
# RS           897
# RA           808
# W            101
# G            162
# Playoffs       1
# Name: 259, dtype: object
# Team         OAK
# League        AL
# Year        2004
# RS           793
# RA           742
# W             91
# G            162
# Playoffs       0
# Name: 260, dtype: object
# Team         PHI
# League        NL
# Year        2004
# RS           840
# RA           781
# W             86
# G            162
# Playoffs       0
# Name: 261, dtype: object
# Team         PIT
# League        NL
# Year        2004
# RS           680
# RA           744
# W             72
# G            161
# Playoffs       0
# Name: 262, dtype: object
# Team         SDP
# League        NL
# Year        2004
# RS           768
# RA           705
# W             87
# G            162
# Playoffs       0
# Name: 263, dtype: object
# Team         SEA
# League        AL
# Year        2004
# RS           698
# RA           823
# W             63
# G            162
# Playoffs       0
# Name: 264, dtype: object
# Team         SFG
# League        NL
# Year        2004
# RS           850
# RA           770
# W             91
# G            162
# Playoffs       0
# Name: 265, dtype: object
# Team         STL
# League        NL
# Year        2004
# RS           855
# RA           659
# W            105
# G            162
# Playoffs       1
# Name: 266, dtype: object
# Team         TBD
# League        AL
# Year        2004
# RS           714
# RA           842
# W             70
# G            161
# Playoffs       0
# Name: 267, dtype: object
# Team         TEX
# League        AL
# Year        2004
# RS           860
# RA           794
# W             89
# G            162
# Playoffs       0
# Name: 268, dtype: object
# Team         TOR
# League        AL
# Year        2004
# RS           719
# RA           823
# W             67
# G            161
# Playoffs       0
# Name: 269, dtype: object
# Team         ANA
# League        AL
# Year        2003
# RS           736
# RA           743
# W             77
# G            162
# Playoffs       0
# Name: 270, dtype: object
# Team         ARI
# League        NL
# Year        2003
# RS           717
# RA           685
# W             84
# G            162
# Playoffs       0
# Name: 271, dtype: object
# Team         ATL
# League        NL
# Year        2003
# RS           907
# RA           740
# W            101
# G            162
# Playoffs       1
# Name: 272, dtype: object
# Team         BAL
# League        AL
# Year        2003
# RS           743
# RA           820
# W             71
# G            163
# Playoffs       0
# Name: 273, dtype: object
# Team         BOS
# League        AL
# Year        2003
# RS           961
# RA           809
# W             95
# G            162
# Playoffs       1
# Name: 274, dtype: object
# Team         CHC
# League        NL
# Year        2003
# RS           724
# RA           683
# W             88
# G            162
# Playoffs       1
# Name: 275, dtype: object
# Team         CHW
# League        AL
# Year        2003
# RS           791
# RA           715
# W             86
# G            162
# Playoffs       0
# Name: 276, dtype: object
# Team         CIN
# League        NL
# Year        2003
# RS           694
# RA           886
# W             69
# G            162
# Playoffs       0
# Name: 277, dtype: object
# Team         CLE
# League        AL
# Year        2003
# RS           699
# RA           778
# W             68
# G            162
# Playoffs       0
# Name: 278, dtype: object
# Team         COL
# League        NL
# Year        2003
# RS           853
# RA           892
# W             74
# G            162
# Playoffs       0
# Name: 279, dtype: object
# Team         DET
# League        AL
# Year        2003
# RS           591
# RA           928
# W             43
# G            162
# Playoffs       0
# Name: 280, dtype: object
# Team         FLA
# League        NL
# Year        2003
# RS           751
# RA           692
# W             91
# G            162
# Playoffs       1
# Name: 281, dtype: object
# Team         HOU
# League        NL
# Year        2003
# RS           805
# RA           677
# W             87
# G            162
# Playoffs       0
# Name: 282, dtype: object
# Team         KCR
# League        AL
# Year        2003
# RS           836
# RA           867
# W             83
# G            162
# Playoffs       0
# Name: 283, dtype: object
# Team         LAD
# League        NL
# Year        2003
# RS           574
# RA           556
# W             85
# G            162
# Playoffs       0
# Name: 284, dtype: object
# Team         MIL
# League        NL
# Year        2003
# RS           714
# RA           873
# W             68
# G            162
# Playoffs       0
# Name: 285, dtype: object
# Team         MIN
# League        AL
# Year        2003
# RS           801
# RA           758
# W             90
# G            162
# Playoffs       1
# Name: 286, dtype: object
# Team         MON
# League        NL
# Year        2003
# RS           711
# RA           716
# W             83
# G            162
# Playoffs       0
# Name: 287, dtype: object
# Team         NYM
# League        NL
# Year        2003
# RS           642
# RA           754
# W             66
# G            161
# Playoffs       0
# Name: 288, dtype: object
# Team         NYY
# League        AL
# Year        2003
# RS           877
# RA           716
# W            101
# G            163
# Playoffs       1
# Name: 289, dtype: object
# Team         OAK
# League        AL
# Year        2003
# RS           768
# RA           643
# W             96
# G            162
# Playoffs       1
# Name: 290, dtype: object
# Team         PHI
# League        NL
# Year        2003
# RS           791
# RA           697
# W             86
# G            162
# Playoffs       0
# Name: 291, dtype: object
# Team         PIT
# League        NL
# Year        2003
# RS           753
# RA           801
# W             75
# G            162
# Playoffs       0
# Name: 292, dtype: object
# Team         SDP
# League        NL
# Year        2003
# RS           678
# RA           831
# W             64
# G            162
# Playoffs       0
# Name: 293, dtype: object
# Team         SEA
# League        AL
# Year        2003
# RS           795
# RA           637
# W             93
# G            162
# Playoffs       0
# Name: 294, dtype: object
# Team         SFG
# League        NL
# Year        2003
# RS           755
# RA           638
# W            100
# G            161
# Playoffs       1
# Name: 295, dtype: object
# Team         STL
# League        NL
# Year        2003
# RS           876
# RA           796
# W             85
# G            162
# Playoffs       0
# Name: 296, dtype: object
# Team         TBD
# League        AL
# Year        2003
# RS           715
# RA           852
# W             63
# G            162
# Playoffs       0
# Name: 297, dtype: object
# Team         TEX
# League        AL
# Year        2003
# RS           826
# RA           969
# W             71
# G            162
# ...
# RS           755
# RA           601
# W             97
# G            160
# Playoffs       1
# Name: 1133, dtype: object
# Team         BOS
# League        AL
# Year        1966
# RS           655
# RA           731
# W             72
# G            162
# Playoffs       0
# Name: 1134, dtype: object
# Team         CAL
# League        AL
# Year        1966
# RS           604
# RA           643
# W             80
# G            162
# Playoffs       0
# Name: 1135, dtype: object
# Team         CHC
# League        NL
# Year        1966
# RS           644
# RA           809
# W             59
# G            162
# Playoffs       0
# Name: 1136, dtype: object
# Team         CHW
# League        AL
# Year        1966
# RS           574
# RA           517
# W             83
# G            163
# Playoffs       0
# Name: 1137, dtype: object
# Team         CIN
# League        NL
# Year        1966
# RS           692
# RA           702
# W             76
# G            160
# Playoffs       0
# Name: 1138, dtype: object
# Team         CLE
# League        AL
# Year        1966
# RS           574
# RA           586
# W             81
# G            162
# Playoffs       0
# Name: 1139, dtype: object
# Team         DET
# League        AL
# Year        1966
# RS           719
# RA           698
# W             88
# G            162
# Playoffs       0
# Name: 1140, dtype: object
# Team         HOU
# League        NL
# Year        1966
# RS           612
# RA           695
# W             72
# G            163
# Playoffs       0
# Name: 1141, dtype: object
# Team         KCA
# League        AL
# Year        1966
# RS           564
# RA           648
# W             74
# G            160
# Playoffs       0
# Name: 1142, dtype: object
# Team         LAD
# League        NL
# Year        1966
# RS           606
# RA           490
# W             95
# G            162
# Playoffs       1
# Name: 1143, dtype: object
# Team         MIN
# League        AL
# Year        1966
# RS           663
# RA           581
# W             89
# G            162
# Playoffs       0
# Name: 1144, dtype: object
# Team         NYM
# League        NL
# Year        1966
# RS           587
# RA           761
# W             66
# G            161
# Playoffs       0
# Name: 1145, dtype: object
# Team         NYY
# League        AL
# Year        1966
# RS           611
# RA           612
# W             70
# G            160
# Playoffs       0
# Name: 1146, dtype: object
# Team         PHI
# League        NL
# Year        1966
# RS           696
# RA           640
# W             87
# G            162
# Playoffs       0
# Name: 1147, dtype: object
# Team         PIT
# League        NL
# Year        1966
# RS           759
# RA           641
# W             92
# G            162
# Playoffs       0
# Name: 1148, dtype: object
# Team         SFG
# League        NL
# Year        1966
# RS           675
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1149, dtype: object
# Team         STL
# League        NL
# Year        1966
# RS           571
# RA           577
# W             83
# G            162
# Playoffs       0
# Name: 1150, dtype: object
# Team         WSA
# League        AL
# Year        1966
# RS           557
# RA           659
# W             71
# G            159
# Playoffs       0
# Name: 1151, dtype: object
# Team         BAL
# League        AL
# Year        1965
# RS           641
# RA           578
# W             94
# G            162
# Playoffs       0
# Name: 1152, dtype: object
# Team         BOS
# League        AL
# Year        1965
# RS           669
# RA           791
# W             62
# G            162
# Playoffs       0
# Name: 1153, dtype: object
# Team         CAL
# League        AL
# Year        1965
# RS           527
# RA           569
# W             75
# G            162
# Playoffs       0
# Name: 1154, dtype: object
# Team         CHC
# League        NL
# Year        1965
# RS           635
# RA           723
# W             72
# G            164
# Playoffs       0
# Name: 1155, dtype: object
# Team         CHW
# League        AL
# Year        1965
# RS           647
# RA           555
# W             95
# G            162
# Playoffs       0
# Name: 1156, dtype: object
# Team         CIN
# League        NL
# Year        1965
# RS           825
# RA           704
# W             89
# G            162
# Playoffs       0
# Name: 1157, dtype: object
# Team         CLE
# League        AL
# Year        1965
# RS           663
# RA           613
# W             87
# G            162
# Playoffs       0
# Name: 1158, dtype: object
# Team         DET
# League        AL
# Year        1965
# RS           680
# RA           602
# W             89
# G            162
# Playoffs       0
# Name: 1159, dtype: object
# Team         HOU
# League        NL
# Year        1965
# RS           569
# RA           711
# W             65
# G            162
# Playoffs       0
# Name: 1160, dtype: object
# Team         KCA
# League        AL
# Year        1965
# RS           585
# RA           755
# W             59
# G            162
# Playoffs       0
# Name: 1161, dtype: object
# Team         LAD
# League        NL
# Year        1965
# RS           608
# RA           521
# W             97
# G            162
# Playoffs       1
# Name: 1162, dtype: object
# Team         MIN
# League        AL
# Year        1965
# RS           774
# RA           600
# W            102
# G            162
# Playoffs       1
# Name: 1163, dtype: object
# Team         MLN
# League        NL
# Year        1965
# RS           708
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 1164, dtype: object
# Team         NYM
# League        NL
# Year        1965
# RS           495
# RA           752
# W             50
# G            164
# Playoffs       0
# Name: 1165, dtype: object
# Team         NYY
# League        AL
# Year        1965
# RS           611
# RA           604
# W             77
# G            162
# Playoffs       0
# Name: 1166, dtype: object
# Team         PHI
# League        NL
# Year        1965
# RS           654
# RA           667
# W             85
# G            162
# Playoffs       0
# Name: 1167, dtype: object
# Team         PIT
# League        NL
# Year        1965
# RS           675
# RA           580
# W             90
# G            163
# Playoffs       0
# Name: 1168, dtype: object
# Team         SFG
# League        NL
# Year        1965
# RS           682
# RA           593
# W             95
# G            163
# Playoffs       0
# Name: 1169, dtype: object
# Team         STL
# League        NL
# Year        1965
# RS           707
# RA           674
# W             80
# G            162
# Playoffs       0
# Name: 1170, dtype: object
# Team         WSA
# League        AL
# Year        1965
# RS           591
# RA           721
# W             70
# G            162
# Playoffs       0
# Name: 1171, dtype: object
# Team         BAL
# League        AL
# Year        1964
# RS           679
# RA           567
# W             97
# G            163
# Playoffs       0
# Name: 1172, dtype: object
# Team         BOS
# League        AL
# Year        1964
# RS           688
# RA           793
# W             72
# G            162
# Playoffs       0
# Name: 1173, dtype: object
# Team         CHC
# League        NL
# Year        1964
# RS           649
# RA           724
# W             76
# G            162
# Playoffs       0
# Name: 1174, dtype: object
# Team         CHW
# League        AL
# Year        1964
# RS           642
# RA           501
# W             98
# G            162
# Playoffs       0
# Name: 1175, dtype: object
# Team         CIN
# League        NL
# Year        1964
# RS           660
# RA           566
# W             92
# G            163
# Playoffs       0
# Name: 1176, dtype: object
# Team         CLE
# League        AL
# Year        1964
# RS           689
# RA           693
# W             79
# G            164
# Playoffs       0
# Name: 1177, dtype: object
# Team         DET
# League        AL
# Year        1964
# RS           699
# RA           678
# W             85
# G            163
# Playoffs       0
# Name: 1178, dtype: object
# Team         HOU
# League        NL
# Year        1964
# RS           495
# RA           628
# W             66
# G            162
# Playoffs       0
# Name: 1179, dtype: object
# Team         KCA
# League        AL
# Year        1964
# RS           621
# RA           836
# W             57
# G            163
# Playoffs       0
# Name: 1180, dtype: object
# Team         LAA
# League        AL
# Year        1964
# RS           544
# RA           551
# W             82
# G            162
# Playoffs       0
# Name: 1181, dtype: object
# Team         LAD
# League        NL
# Year        1964
# RS           614
# RA           572
# W             80
# G            164
# Playoffs       0
# Name: 1182, dtype: object
# Team         MIN
# League        AL
# Year        1964
# RS           737
# RA           678
# W             79
# G            163
# Playoffs       0
# Name: 1183, dtype: object
# Team         MLN
# League        NL
# Year        1964
# RS           803
# RA           744
# W             88
# G            162
# Playoffs       0
# Name: 1184, dtype: object
# Team         NYM
# League        NL
# Year        1964
# RS           569
# RA           776
# W             53
# G            163
# Playoffs       0
# Name: 1185, dtype: object
# Team         NYY
# League        AL
# Year        1964
# RS           730
# RA           577
# W             99
# G            164
# Playoffs       1
# Name: 1186, dtype: object
# Team         PHI
# League        NL
# Year        1964
# RS           693
# RA           632
# W             92
# G            162
# Playoffs       0
# Name: 1187, dtype: object
# Team         PIT
# League        NL
# Year        1964
# RS           663
# RA           636
# W             80
# G            162
# Playoffs       0
# Name: 1188, dtype: object
# Team         SFG
# League        NL
# Year        1964
# RS           656
# RA           587
# W             90
# G            162
# Playoffs       0
# Name: 1189, dtype: object
# Team         STL
# League        NL
# Year        1964
# RS           715
# RA           652
# W             93
# G            162
# Playoffs       1
# Name: 1190, dtype: object
# Team         WSA
# League        AL
# Year        1964
# RS           578
# RA           733
# W             62
# G            162
# Playoffs       0
# Name: 1191, dtype: object
# Team         BAL
# League        AL
# Year        1963
# RS           644
# RA           621
# W             86
# G            162
# Playoffs       0
# Name: 1192, dtype: object
# Team         BOS
# League        AL
# Year        1963
# RS           666
# RA           704
# W             76
# G            161
# Playoffs       0
# Name: 1193, dtype: object
# Team         CHC
# League        NL
# Year        1963
# RS           570
# RA           578
# W             82
# G            162
# Playoffs       0
# Name: 1194, dtype: object
# Team         CHW
# League        AL
# Year        1963
# RS           683
# RA           544
# W             94
# G            162
# Playoffs       0
# Name: 1195, dtype: object
# Team         CIN
# League        NL
# Year        1963
# RS           648
# RA           594
# W             86
# G            162
# Playoffs       0
# Name: 1196, dtype: object
# Team         CLE
# League        AL
# Year        1963
# RS           635
# RA           702
# W             79
# G            162
# Playoffs       0
# Name: 1197, dtype: object
# Team         DET
# League        AL
# Year        1963
# RS           700
# RA           703
# W             79
# G            162
# Playoffs       0
# Name: 1198, dtype: object
# Team         HOU
# League        NL
# Year        1963
# RS           464
# RA           640
# W             66
# G            162
# Playoffs       0
# Name: 1199, dtype: object
# Team         KCA
# League        AL
# Year        1963
# RS           615
# RA           704
# W             73
# G            162
# Playoffs       0
# Name: 1200, dtype: object
# Team         LAA
# League        AL
# Year        1963
# RS           597
# RA           660
# W             70
# G            161
# Playoffs       0
# Name: 1201, dtype: object
# Team         LAD
# League        NL
# Year        1963
# RS           640
# RA           550
# W             99
# G            163
# Playoffs       1
# Name: 1202, dtype: object
# Team         MIN
# League        AL
# Year        1963
# RS           767
# RA           602
# W             91
# G            161
# Playoffs       0
# Name: 1203, dtype: object
# Team         MLN
# League        NL
# Year        1963
# RS           677
# RA           603
# W             84
# G            163
# Playoffs       0
# Name: 1204, dtype: object
# Team         NYM
# League        NL
# Year        1963
# RS           501
# RA           774
# W             51
# G            162
# Playoffs       0
# Name: 1205, dtype: object
# Team         NYY
# League        AL
# Year        1963
# RS           714
# RA           547
# W            104
# G            161
# Playoffs       1
# Name: 1206, dtype: object
# Team         PHI
# League        NL
# Year        1963
# RS           642
# RA           578
# W             87
# G            162
# Playoffs       0
# Name: 1207, dtype: object
# Team         PIT
# League        NL
# Year        1963
# RS           567
# RA           595
# W             74
# G            162
# Playoffs       0
# Name: 1208, dtype: object
# Team         SFG
# League        NL
# Year        1963
# RS           725
# RA           641
# W             88
# G            162
# Playoffs       0
# Name: 1209, dtype: object
# Team         STL
# League        NL
# Year        1963
# RS           747
# RA           628
# W             93
# G            162
# Playoffs       0
# Name: 1210, dtype: object
# Team         WSA
# League        AL
# Year        1963
# RS           578
# RA           812
# W             56
# G            162
# Playoffs       0
# Name: 1211, dtype: object
# Team         BAL
# League        AL
# Year        1962
# RS           652
# RA           680
# W             77
# G            162
# Playoffs       0
# Name: 1212, dtype: object
# Team         BOS
# League        AL
# Year        1962
# RS           707
# RA           756
# W             76
# G            160
# Playoffs       0
# Name: 1213, dtype: object
# Team         CHC
# League        NL
# Year        1962
# RS           632
# RA           827
# W             59
# G            162
# Playoffs       0
# Name: 1214, dtype: object
# Team         CHW
# League        AL
# Year        1962
# RS           707
# RA           658
# W             85
# G            162
# Playoffs       0
# Name: 1215, dtype: object
# Team         CIN
# League        NL
# Year        1962
# RS           802
# RA           685
# W             98
# G            162
# Playoffs       0
# Name: 1216, dtype: object
# Team         CLE
# League        AL
# Year        1962
# RS           682
# RA           745
# W             80
# G            162
# Playoffs       0
# Name: 1217, dtype: object
# Team         DET
# League        AL
# Year        1962
# RS           758
# RA           692
# W             85
# G            161
# Playoffs       0
# Name: 1218, dtype: object
# Team         HOU
# League        NL
# Year        1962
# RS           592
# RA           717
# W             64
# G            162
# Playoffs       0
# Name: 1219, dtype: object
# Team         KCA
# League        AL
# Year        1962
# RS           745
# RA           837
# W             72
# G            162
# Playoffs       0
# Name: 1220, dtype: object
# Team         LAA
# League        AL
# Year        1962
# RS           718
# RA           706
# W             86
# G            162
# Playoffs       0
# Name: 1221, dtype: object
# Team         LAD
# League        NL
# Year        1962
# RS           842
# RA           697
# W            102
# G            165
# Playoffs       0
# Name: 1222, dtype: object
# Team         MIN
# League        AL
# Year        1962
# RS           798
# RA           713
# W             91
# G            163
# Playoffs       0
# Name: 1223, dtype: object
# Team         MLN
# League        NL
# Year        1962
# RS           730
# RA           665
# W             86
# G            162
# Playoffs       0
# Name: 1224, dtype: object
# Team         NYM
# League        NL
# Year        1962
# RS           617
# RA           948
# W             40
# G            161
# Playoffs       0
# Name: 1225, dtype: object
# Team         NYY
# League        AL
# Year        1962
# RS           817
# RA           680
# W             96
# G            162
# Playoffs       1
# Name: 1226, dtype: object
# Team         PHI
# League        NL
# Year        1962
# RS           705
# RA           759
# W             81
# G            161
# Playoffs       0
# Name: 1227, dtype: object
# Team         PIT
# League        NL
# Year        1962
# RS           706
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1228, dtype: object
# Team         SFG
# League        NL
# Year        1962
# RS           878
# RA           690
# W            103
# G            165
# Playoffs       1
# Name: 1229, dtype: object
# Team         STL
# League        NL
# Year        1962
# RS           774
# RA           664
# W             84
# G            163
# Playoffs       0
# Name: 1230, dtype: object
# Team         WSA
# League        AL
# Year        1962
# RS           599
# RA           716
# W             60
# G            162
# Playoffs       0
# Name: 1231, dtype: object

# %%
# Iterate over pit_df and print each index variable and then each row
for i,row in pit_df.iterrows():
    print(i)
    print(row)
    print(type(row))
# Out:
# 0
# Team         ARI
# League        NL
# Year        2012
# RS           734
# RA           688
# W             81
# G            162
# Playoffs       0
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>
# 1
# Team         ATL
# League        NL
# Year        2012
# RS           700
# RA           600
# W             94
# G            162
# Playoffs       1
# Name: 1, dtype: object
# <class 'pandas.core.series.Series'>
# 2
# Team         BAL
# League        AL
# Year        2012
# RS           712
# RA           705
# W             93
# G            162
# Playoffs       1
# Name: 2, dtype: object
# <class 'pandas.core.series.Series'>
# 3
# Team         BOS
# League        AL
# Year        2012
# RS           734
# RA           806
# W             69
# G            162
# Playoffs       0
# Name: 3, dtype: object
# <class 'pandas.core.series.Series'>
# 4
# Team         CHC
# League        NL
# Year        2012
# RS           613
# RA           759
# W             61
# G            162
# Playoffs       0
# Name: 4, dtype: object
# <class 'pandas.core.series.Series'>
# 5
# Team         CHW
# League        AL
# Year        2012
# RS           748
# RA           676
# W             85
# G            162
# Playoffs       0
# Name: 5, dtype: object
# <class 'pandas.core.series.Series'>
# 6
# Team         CIN
# League        NL
# Year        2012
# RS           669
# RA           588
# W             97
# G            162
# Playoffs       1
# Name: 6, dtype: object
# <class 'pandas.core.series.Series'>
# 7
# Team         CLE
# League        AL
# Year        2012
# RS           667
# RA           845
# W             68
# G            162
# Playoffs       0
# Name: 7, dtype: object
# <class 'pandas.core.series.Series'>
# 8
# Team         COL
# League        NL
# Year        2012
# RS           758
# RA           890
# W             64
# G            162
# Playoffs       0
# Name: 8, dtype: object
# <class 'pandas.core.series.Series'>
# 9
# Team         DET
# League        AL
# Year        2012
# RS           726
# RA           670
# W             88
# G            162
# Playoffs       1
# Name: 9, dtype: object
# <class 'pandas.core.series.Series'>
# 10
# Team         HOU
# League        NL
# Year        2012
# RS           583
# RA           794
# W             55
# G            162
# Playoffs       0
# Name: 10, dtype: object
# <class 'pandas.core.series.Series'>
# 11
# Team         KCR
# League        AL
# Year        2012
# RS           676
# RA           746
# W             72
# G            162
# Playoffs       0
# Name: 11, dtype: object
# <class 'pandas.core.series.Series'>
# 12
# Team         LAA
# League        AL
# Year        2012
# RS           767
# RA           699
# W             89
# G            162
# Playoffs       0
# Name: 12, dtype: object
# <class 'pandas.core.series.Series'>
# 13
# Team         LAD
# League        NL
# Year        2012
# RS           637
# RA           597
# W             86
# G            162
# Playoffs       0
# Name: 13, dtype: object
# <class 'pandas.core.series.Series'>
# 14
# Team         MIA
# League        NL
# Year        2012
# RS           609
# RA           724
# W             69
# G            162
# Playoffs       0
# Name: 14, dtype: object
# <class 'pandas.core.series.Series'>
# 15
# Team         MIL
# League        NL
# Year        2012
# RS           776
# RA           733
# W             83
# G            162
# Playoffs       0
# Name: 15, dtype: object
# <class 'pandas.core.series.Series'>
# 16
# Team         MIN
# League        AL
# Year        2012
# RS           701
# RA           832
# W             66
# G            162
# Playoffs       0
# Name: 16, dtype: object
# <class 'pandas.core.series.Series'>
# 17
# Team         NYM
# League        NL
# Year        2012
# RS           650
# RA           709
# W             74
# G            162
# Playoffs       0
# Name: 17, dtype: object
# <class 'pandas.core.series.Series'>
# 18
# Team         NYY
# League        AL
# Year        2012
# RS           804
# RA           668
# W             95
# G            162
# Playoffs       1
# Name: 18, dtype: object
# <class 'pandas.core.series.Series'>
# 19
# Team         OAK
# League        AL
# Year        2012
# RS           713
# RA           614
# W             94
# G            162
# Playoffs       1
# Name: 19, dtype: object
# <class 'pandas.core.series.Series'>
# 20
# Team         PHI
# League        NL
# Year        2012
# RS           684
# RA           680
# W             81
# G            162
# Playoffs       0
# Name: 20, dtype: object
# <class 'pandas.core.series.Series'>
# 21
# Team         PIT
# League        NL
# Year        2012
# RS           651
# RA           674
# W             79
# G            162
# Playoffs       0
# Name: 21, dtype: object
# <class 'pandas.core.series.Series'>
# 22
# Team         SDP
# League        NL
# Year        2012
# RS           651
# RA           710
# W             76
# G            162
# Playoffs       0
# Name: 22, dtype: object
# <class 'pandas.core.series.Series'>
# 23
# Team         SEA
# League        AL
# Year        2012
# RS           619
# RA           651
# W             75
# G            162
# Playoffs       0
# Name: 23, dtype: object
# <class 'pandas.core.series.Series'>
# 24
# Team         SFG
# League        NL
# Year        2012
# RS           718
# RA           649
# W             94
# G            162
# Playoffs       1
# Name: 24, dtype: object
# <class 'pandas.core.series.Series'>
# 25
# Team         STL
# League        NL
# Year        2012
# RS           765
# RA           648
# W             88
# G            162
# Playoffs       1
# Name: 25, dtype: object
# <class 'pandas.core.series.Series'>
# 26
# Team         TBR
# League        AL
# Year        2012
# RS           697
# RA           577
# W             90
# G            162
# Playoffs       0
# Name: 26, dtype: object
# <class 'pandas.core.series.Series'>
# 27
# Team         TEX
# League        AL
# Year        2012
# RS           808
# RA           707
# W             93
# G            162
# Playoffs       1
# Name: 27, dtype: object
# <class 'pandas.core.series.Series'>
# 28
# Team         TOR
# League        AL
# Year        2012
# RS           716
# RA           784
# W             73
# G            162
# Playoffs       0
# Name: 28, dtype: object
# <class 'pandas.core.series.Series'>
# 29
# Team         WSN
# League        NL
# Year        2012
# RS           731
# RA           594
# W             98
# G            162
# Playoffs       1
# Name: 29, dtype: object
# <class 'pandas.core.series.Series'>
# 30
# Team         ARI
# League        NL
# Year        2011
# RS           731
# RA           662
# W             94
# G            162
# Playoffs       1
# Name: 30, dtype: object
# <class 'pandas.core.series.Series'>
# 31
# Team         ATL
# League        NL
# Year        2011
# RS           641
# RA           605
# W             89
# G            162
# Playoffs       0
# Name: 31, dtype: object
# <class 'pandas.core.series.Series'>
# 32
# Team         BAL
# League        AL
# Year        2011
# RS           708
# RA           860
# W             69
# G            162
# Playoffs       0
# Name: 32, dtype: object
# <class 'pandas.core.series.Series'>
# 33
# Team         BOS
# League        AL
# Year        2011
# RS           875
# RA           737
# W             90
# G            162
# Playoffs       0
# Name: 33, dtype: object
# <class 'pandas.core.series.Series'>
# 34
# Team         CHC
# League        NL
# Year        2011
# RS           654
# RA           756
# W             71
# G            162
# Playoffs       0
# Name: 34, dtype: object
# <class 'pandas.core.series.Series'>
# 35
# Team         CHW
# League        AL
# Year        2011
# RS           654
# RA           706
# W             79
# G            162
# Playoffs       0
# Name: 35, dtype: object
# <class 'pandas.core.series.Series'>
# 36
# Team         CIN
# League        NL
# Year        2011
# RS           735
# RA           720
# W             79
# G            162
# Playoffs       0
# Name: 36, dtype: object
# <class 'pandas.core.series.Series'>
# 37
# Team         CLE
# League        AL
# Year        2011
# RS           704
# RA           760
# W             80
# G            162
# Playoffs       0
# Name: 37, dtype: object
# <class 'pandas.core.series.Series'>
# 38
# Team         COL
# League        NL
# Year        2011
# RS           735
# RA           774
# W             73
# G            162
# Playoffs       0
# Name: 38, dtype: object
# <class 'pandas.core.series.Series'>
# 39
# Team         DET
# League        AL
# Year        2011
# RS           787
# RA           711
# W             95
# G            162
# Playoffs       1
# Name: 39, dtype: object
# <class 'pandas.core.series.Series'>
# 40
# Team         FLA
# League        NL
# Year        2011
# RS           625
# RA           702
# W             72
# G            162
# Playoffs       0
# Name: 40, dtype: object
# <class 'pandas.core.series.Series'>
# 41
# Team         HOU
# League        NL
# Year        2011
# RS           615
# RA           796
# W             56
# G            162
# Playoffs       0
# Name: 41, dtype: object
# <class 'pandas.core.series.Series'>
# 42
# Team         KCR
# League        AL
# Year        2011
# RS           730
# RA           762
# W             71
# G            162
# Playoffs       0
# Name: 42, dtype: object
# <class 'pandas.core.series.Series'>
# 43
# Team         LAA
# League        AL
# Year        2011
# RS           667
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 43, dtype: object
# <class 'pandas.core.series.Series'>
# 44
# Team         LAD
# League        NL
# Year        2011
# RS           644
# RA           612
# W             82
# G            161
# Playoffs       0
# Name: 44, dtype: object
# <class 'pandas.core.series.Series'>
# 45
# Team         MIL
# League        NL
# Year        2011
# RS           721
# RA           638
# W             96
# G            162
# Playoffs       1
# Name: 45, dtype: object
# <class 'pandas.core.series.Series'>
# 46
# Team         MIN
# League        AL
# Year        2011
# RS           619
# RA           804
# W             63
# G            162
# Playoffs       0
# Name: 46, dtype: object
# <class 'pandas.core.series.Series'>
# 47
# Team         NYM
# League        NL
# Year        2011
# RS           718
# RA           742
# W             77
# G            162
# Playoffs       0
# Name: 47, dtype: object
# <class 'pandas.core.series.Series'>
# 48
# Team         NYY
# League        AL
# Year        2011
# RS           867
# RA           657
# W             97
# G            162
# Playoffs       1
# Name: 48, dtype: object
# <class 'pandas.core.series.Series'>
# 49
# Team         OAK
# League        AL
# Year        2011
# RS           645
# RA           679
# W             74
# G            162
# Playoffs       0
# Name: 49, dtype: object
# <class 'pandas.core.series.Series'>
# 50
# Team         PHI
# League        NL
# Year        2011
# RS           713
# RA           529
# W            102
# G            162
# Playoffs       1
# Name: 50, dtype: object
# <class 'pandas.core.series.Series'>
# 51
# Team         PIT
# League        NL
# Year        2011
# RS           610
# RA           712
# W             72
# G            162
# Playoffs       0
# Name: 51, dtype: object
# <class 'pandas.core.series.Series'>
# 52
# Team         SDP
# League        NL
# Year        2011
# RS           593
# RA           611
# W             71
# G            162
# Playoffs       0
# Name: 52, dtype: object
# <class 'pandas.core.series.Series'>
# 53
# Team         SEA
# League        AL
# Year        2011
# RS           556
# RA           675
# W             67
# G            162
# Playoffs       0
# Name: 53, dtype: object
# <class 'pandas.core.series.Series'>
# 54
# Team         SFG
# League        NL
# Year        2011
# RS           570
# RA           578
# W             86
# G            162
# Playoffs       0
# Name: 54, dtype: object
# <class 'pandas.core.series.Series'>
# 55
# Team         STL
# League        NL
# Year        2011
# RS           762
# RA           692
# W             90
# G            162
# Playoffs       1
# Name: 55, dtype: object
# <class 'pandas.core.series.Series'>
# 56
# Team         TBR
# League        AL
# Year        2011
# RS           707
# RA           614
# W             91
# G            162
# Playoffs       1
# Name: 56, dtype: object
# <class 'pandas.core.series.Series'>
# 57
# Team         TEX
# League        AL
# Year        2011
# RS           855
# RA           677
# W             96
# G            162
# Playoffs       1
# Name: 57, dtype: object
# <class 'pandas.core.series.Series'>
# 58
# Team         TOR
# League        AL
# Year        2011
# RS           743
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 58, dtype: object
# <class 'pandas.core.series.Series'>
# 59
# Team         WSN
# League        NL
# Year        2011
# RS           624
# RA           643
# W             80
# G            161
# Playoffs       0
# Name: 59, dtype: object
# <class 'pandas.core.series.Series'>
# 60
# Team         ARI
# League        NL
# Year        2010
# RS           713
# RA           836
# W             65
# G            162
# Playoffs       0
# Name: 60, dtype: object
# <class 'pandas.core.series.Series'>
# 61
# Team         ATL
# League        NL
# Year        2010
# RS           738
# RA           629
# W             91
# G            162
# Playoffs       1
# Name: 61, dtype: object
# <class 'pandas.core.series.Series'>
# 62
# Team         BAL
# League        AL
# Year        2010
# RS           613
# RA           785
# W             66
# G            162
# Playoffs       0
# Name: 62, dtype: object
# <class 'pandas.core.series.Series'>
# 63
# Team         BOS
# League        AL
# Year        2010
# RS           818
# RA           744
# W             89
# G            162
# Playoffs       0
# Name: 63, dtype: object
# <class 'pandas.core.series.Series'>
# 64
# Team         CHC
# League        NL
# Year        2010
# RS           685
# RA           767
# W             75
# G            162
# Playoffs       0
# Name: 64, dtype: object
# <class 'pandas.core.series.Series'>
# 65
# Team         CHW
# League        AL
# Year        2010
# RS           752
# RA           704
# W             88
# G            162
# Playoffs       0
# Name: 65, dtype: object
# <class 'pandas.core.series.Series'>
# 66
# Team         CIN
# League        NL
# Year        2010
# RS           790
# RA           685
# W             91
# G            162
# Playoffs       1
# Name: 66, dtype: object
# <class 'pandas.core.series.Series'>
# 67
# Team         CLE
# League        AL
# Year        2010
# RS           646
# RA           752
# W             69
# G            162
# Playoffs       0
# Name: 67, dtype: object
# <class 'pandas.core.series.Series'>
# 68
# Team         COL
# League        NL
# Year        2010
# RS           770
# RA           717
# W             83
# G            162
# Playoffs       0
# Name: 68, dtype: object
# <class 'pandas.core.series.Series'>
# 69
# Team         DET
# League        AL
# Year        2010
# RS           751
# RA           743
# W             81
# G            162
# Playoffs       0
# Name: 69, dtype: object
# <class 'pandas.core.series.Series'>
# 70
# Team         FLA
# League        NL
# Year        2010
# RS           719
# RA           717
# W             80
# G            162
# Playoffs       0
# Name: 70, dtype: object
# <class 'pandas.core.series.Series'>
# 71
# Team         HOU
# League        NL
# Year        2010
# RS           611
# RA           729
# W             76
# G            162
# Playoffs       0
# Name: 71, dtype: object
# <class 'pandas.core.series.Series'>
# 72
# Team         KCR
# League        AL
# Year        2010
# RS           676
# RA           845
# W             67
# G            162
# Playoffs       0
# Name: 72, dtype: object
# <class 'pandas.core.series.Series'>
# 73
# Team         LAA
# League        AL
# Year        2010
# RS           681
# RA           702
# W             80
# G            162
# Playoffs       0
# Name: 73, dtype: object
# <class 'pandas.core.series.Series'>
# 74
# Team         LAD
# League        NL
# Year        2010
# RS           667
# RA           692
# W             80
# G            162
# Playoffs       0
# Name: 74, dtype: object
# <class 'pandas.core.series.Series'>
# 75
# Team         MIL
# League        NL
# Year        2010
# RS           750
# RA           804
# W             77
# G            162
# Playoffs       0
# Name: 75, dtype: object
# <class 'pandas.core.series.Series'>
# 76
# Team         MIN
# League        AL
# Year        2010
# RS           781
# RA           671
# W             94
# G            162
# Playoffs       1
# Name: 76, dtype: object
# <class 'pandas.core.series.Series'>
# 77
# Team         NYM
# League        NL
# Year        2010
# RS           656
# RA           652
# W             79
# G            162
# Playoffs       0
# Name: 77, dtype: object
# <class 'pandas.core.series.Series'>
# 78
# Team         NYY
# League        AL
# Year        2010
# RS           859
# RA           693
# W             95
# G            162
# Playoffs       1
# Name: 78, dtype: object
# <class 'pandas.core.series.Series'>
# 79
# Team         OAK
# League        AL
# Year        2010
# RS           663
# RA           626
# W             81
# G            162
# Playoffs       0
# Name: 79, dtype: object
# <class 'pandas.core.series.Series'>
# 80
# Team         PHI
# League        NL
# Year        2010
# RS           772
# RA           640
# W             97
# G            162
# Playoffs       1
# Name: 80, dtype: object
# <class 'pandas.core.series.Series'>
# 81
# Team         PIT
# League        NL
# Year        2010
# RS           587
# RA           866
# W             57
# G            162
# Playoffs       0
# Name: 81, dtype: object
# <class 'pandas.core.series.Series'>
# 82
# Team         SDP
# League        NL
# Year        2010
# RS           665
# RA           581
# W             90
# G            162
# Playoffs       0
# Name: 82, dtype: object
# <class 'pandas.core.series.Series'>
# 83
# Team         SEA
# League        AL
# Year        2010
# RS           513
# RA           698
# W             61
# G            162
# Playoffs       0
# Name: 83, dtype: object
# <class 'pandas.core.series.Series'>
# 84
# Team         SFG
# League        NL
# Year        2010
# RS           697
# RA           583
# W             92
# G            162
# Playoffs       1
# Name: 84, dtype: object
# <class 'pandas.core.series.Series'>
# 85
# Team         STL
# League        NL
# Year        2010
# RS           736
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 85, dtype: object
# <class 'pandas.core.series.Series'>
# 86
# Team         TBR
# League        AL
# Year        2010
# RS           802
# RA           649
# W             96
# G            162
# Playoffs       1
# Name: 86, dtype: object
# <class 'pandas.core.series.Series'>
# 87
# Team         TEX
# League        AL
# Year        2010
# RS           787
# RA           687
# W             90
# G            162
# Playoffs       1
# Name: 87, dtype: object
# <class 'pandas.core.series.Series'>
# 88
# Team         TOR
# League        AL
# Year        2010
# RS           755
# RA           728
# W             85
# G            162
# Playoffs       0
# Name: 88, dtype: object
# <class 'pandas.core.series.Series'>
# 89
# Team         WSN
# League        NL
# Year        2010
# RS           655
# RA           742
# W             69
# G            162
# Playoffs       0
# Name: 89, dtype: object
# <class 'pandas.core.series.Series'>
# 90
# Team         ARI
# League        NL
# Year        2009
# RS           720
# RA           782
# W             70
# G            162
# Playoffs       0
# Name: 90, dtype: object
# <class 'pandas.core.series.Series'>
# 91
# Team         ATL
# League        NL
# Year        2009
# RS           735
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 91, dtype: object
# <class 'pandas.core.series.Series'>
# 92
# Team         BAL
# League        AL
# Year        2009
# RS           741
# RA           876
# W             64
# G            162
# Playoffs       0
# Name: 92, dtype: object
# <class 'pandas.core.series.Series'>
# 93
# Team         BOS
# League        AL
# Year        2009
# RS           872
# RA           736
# W             95
# G            162
# Playoffs       1
# Name: 93, dtype: object
# <class 'pandas.core.series.Series'>
# 94
# Team         CHC
# League        NL
# Year        2009
# RS           707
# RA           672
# W             83
# G            161
# Playoffs       0
# Name: 94, dtype: object
# <class 'pandas.core.series.Series'>
# 95
# Team         CHW
# League        AL
# Year        2009
# RS           724
# RA           732
# W             79
# G            162
# Playoffs       0
# Name: 95, dtype: object
# <class 'pandas.core.series.Series'>
# 96
# Team         CIN
# League        NL
# Year        2009
# RS           673
# RA           723
# W             78
# G            162
# Playoffs       0
# Name: 96, dtype: object
# <class 'pandas.core.series.Series'>
# 97
# Team         CLE
# League        AL
# Year        2009
# RS           773
# RA           865
# W             65
# G            162
# Playoffs       0
# Name: 97, dtype: object
# <class 'pandas.core.series.Series'>
# 98
# Team         COL
# League        NL
# Year        2009
# RS           804
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 98, dtype: object
# <class 'pandas.core.series.Series'>
# 99
# Team         DET
# League        AL
# Year        2009
# RS           743
# RA           745
# W             86
# G            163
# Playoffs       0
# Name: 99, dtype: object
# <class 'pandas.core.series.Series'>
# 100
# Team         FLA
# League        NL
# Year        2009
# RS           772
# RA           766
# W             87
# G            162
# Playoffs       0
# Name: 100, dtype: object
# <class 'pandas.core.series.Series'>
# 101
# Team         HOU
# League        NL
# Year        2009
# RS           643
# RA           770
# W             74
# G            162
# Playoffs       0
# Name: 101, dtype: object
# <class 'pandas.core.series.Series'>
# 102
# Team         KCR
# League        AL
# Year        2009
# RS           686
# RA           842
# W             65
# G            162
# Playoffs       0
# Name: 102, dtype: object
# <class 'pandas.core.series.Series'>
# 103
# Team         LAA
# League        AL
# Year        2009
# RS           883
# RA           761
# W             97
# G            162
# Playoffs       1
# Name: 103, dtype: object
# <class 'pandas.core.series.Series'>
# 104
# Team         LAD
# League        NL
# Year        2009
# RS           780
# RA           611
# W             95
# G            162
# Playoffs       1
# Name: 104, dtype: object
# <class 'pandas.core.series.Series'>
# 105
# Team         MIL
# League        NL
# Year        2009
# RS           785
# RA           818
# W             80
# G            162
# Playoffs       0
# Name: 105, dtype: object
# <class 'pandas.core.series.Series'>
# 106
# Team         MIN
# League        AL
# Year        2009
# RS           817
# RA           765
# W             87
# G            163
# Playoffs       1
# Name: 106, dtype: object
# <class 'pandas.core.series.Series'>
# 107
# Team         NYM
# League        NL
# Year        2009
# RS           671
# RA           757
# W             70
# G            162
# Playoffs       0
# Name: 107, dtype: object
# <class 'pandas.core.series.Series'>
# 108
# Team         NYY
# League        AL
# Year        2009
# RS           915
# RA           753
# W            103
# G            162
# Playoffs       1
# Name: 108, dtype: object
# <class 'pandas.core.series.Series'>
# 109
# Team         OAK
# League        AL
# Year        2009
# RS           759
# RA           761
# W             75
# G            162
# Playoffs       0
# Name: 109, dtype: object
# <class 'pandas.core.series.Series'>
# 110
# Team         PHI
# League        NL
# Year        2009
# RS           820
# RA           709
# W             93
# G            162
# Playoffs       1
# Name: 110, dtype: object
# <class 'pandas.core.series.Series'>
# 111
# Team         PIT
# League        NL
# Year        2009
# RS           636
# RA           768
# W             62
# G            161
# Playoffs       0
# Name: 111, dtype: object
# <class 'pandas.core.series.Series'>
# 112
# Team         SDP
# League        NL
# Year        2009
# RS           638
# RA           769
# W             75
# G            162
# Playoffs       0
# Name: 112, dtype: object
# <class 'pandas.core.series.Series'>
# 113
# Team         SEA
# League        AL
# Year        2009
# RS           640
# RA           692
# W             85
# G            162
# Playoffs       0
# Name: 113, dtype: object
# <class 'pandas.core.series.Series'>
# 114
# Team         SFG
# League        NL
# Year        2009
# RS           657
# RA           611
# W             88
# G            162
# Playoffs       0
# Name: 114, dtype: object
# <class 'pandas.core.series.Series'>
# 115
# Team         STL
# League        NL
# Year        2009
# RS           730
# RA           640
# W             91
# G            162
# Playoffs       1
# Name: 115, dtype: object
# <class 'pandas.core.series.Series'>
# 116
# Team         TBR
# League        AL
# Year        2009
# RS           803
# RA           754
# W             84
# G            162
# Playoffs       0
# Name: 116, dtype: object
# <class 'pandas.core.series.Series'>
# 117
# Team         TEX
# League        AL
# Year        2009
# RS           784
# RA           740
# W             87
# G            162
# Playoffs       0
# Name: 117, dtype: object
# <class 'pandas.core.series.Series'>
# 118
# Team         TOR
# League        AL
# Year        2009
# RS           798
# RA           771
# W             75
# G            162
# Playoffs       0
# Name: 118, dtype: object
# <class 'pandas.core.series.Series'>
# 119
# Team         WSN
# League        NL
# Year        2009
# RS           710
# RA           874
# W             59
# G            162
# Playoffs       0
# Name: 119, dtype: object
# <class 'pandas.core.series.Series'>
# 120
# Team         ARI
# League        NL
# Year        2008
# RS           720
# RA           706
# W             82
# G            162
# Playoffs       0
# Name: 120, dtype: object
# <class 'pandas.core.series.Series'>
# 121
# Team         ATL
# League        NL
# Year        2008
# RS           753
# RA           778
# W             72
# G            162
# Playoffs       0
# Name: 121, dtype: object
# <class 'pandas.core.series.Series'>
# 122
# Team         BAL
# League        AL
# Year        2008
# RS           782
# RA           869
# W             68
# G            161
# Playoffs       0
# Name: 122, dtype: object
# <class 'pandas.core.series.Series'>
# 123
# Team         BOS
# League        AL
# Year        2008
# RS           845
# RA           694
# W             95
# G            162
# Playoffs       1
# Name: 123, dtype: object
# <class 'pandas.core.series.Series'>
# 124
# Team         CHC
# League        NL
# Year        2008
# RS           855
# RA           671
# W             97
# G            161
# Playoffs       1
# Name: 124, dtype: object
# <class 'pandas.core.series.Series'>
# 125
# Team         CHW
# League        AL
# Year        2008
# RS           811
# RA           729
# W             89
# G            163
# Playoffs       1
# Name: 125, dtype: object
# <class 'pandas.core.series.Series'>
# 126
# Team         CIN
# League        NL
# Year        2008
# RS           704
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 126, dtype: object
# <class 'pandas.core.series.Series'>
# 127
# Team         CLE
# League        AL
# Year        2008
# RS           805
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 127, dtype: object
# <class 'pandas.core.series.Series'>
# 128
# Team         COL
# League        NL
# Year        2008
# RS           747
# RA           822
# W             74
# G            162
# Playoffs       0
# Name: 128, dtype: object
# <class 'pandas.core.series.Series'>
# 129
# Team         DET
# League        AL
# Year        2008
# RS           821
# RA           857
# W             74
# G            162
# Playoffs       0
# Name: 129, dtype: object
# <class 'pandas.core.series.Series'>
# 130
# Team         FLA
# League        NL
# Year        2008
# RS           770
# RA           767
# W             84
# G            161
# Playoffs       0
# Name: 130, dtype: object
# <class 'pandas.core.series.Series'>
# 131
# Team         HOU
# League        NL
# Year        2008
# RS           712
# RA           743
# W             86
# G            161
# Playoffs       0
# Name: 131, dtype: object
# <class 'pandas.core.series.Series'>
# 132
# Team         KCR
# League        AL
# Year        2008
# RS           691
# RA           781
# W             75
# G            162
# Playoffs       0
# Name: 132, dtype: object
# <class 'pandas.core.series.Series'>
# 133
# Team         LAA
# League        AL
# Year        2008
# RS           765
# RA           697
# W            100
# G            162
# Playoffs       1
# Name: 133, dtype: object
# <class 'pandas.core.series.Series'>
# 134
# Team         LAD
# League        NL
# Year        2008
# RS           700
# RA           648
# W             84
# G            162
# Playoffs       1
# Name: 134, dtype: object
# <class 'pandas.core.series.Series'>
# 135
# Team         MIL
# League        NL
# Year        2008
# RS           750
# RA           689
# W             90
# G            162
# Playoffs       1
# Name: 135, dtype: object
# <class 'pandas.core.series.Series'>
# 136
# Team         MIN
# League        AL
# Year        2008
# RS           829
# RA           745
# W             88
# G            163
# Playoffs       0
# Name: 136, dtype: object
# <class 'pandas.core.series.Series'>
# 137
# Team         NYM
# League        NL
# Year        2008
# RS           799
# RA           715
# W             89
# G            162
# Playoffs       0
# Name: 137, dtype: object
# <class 'pandas.core.series.Series'>
# 138
# Team         NYY
# League        AL
# Year        2008
# RS           789
# RA           727
# W             89
# G            162
# Playoffs       0
# Name: 138, dtype: object
# <class 'pandas.core.series.Series'>
# 139
# Team         OAK
# League        AL
# Year        2008
# RS           646
# RA           690
# W             75
# G            161
# Playoffs       0
# Name: 139, dtype: object
# <class 'pandas.core.series.Series'>
# 140
# Team         PHI
# League        NL
# Year        2008
# RS           799
# RA           680
# W             92
# G            162
# Playoffs       1
# Name: 140, dtype: object
# <class 'pandas.core.series.Series'>
# 141
# Team         PIT
# League        NL
# Year        2008
# RS           735
# RA           884
# W             67
# G            162
# Playoffs       0
# Name: 141, dtype: object
# <class 'pandas.core.series.Series'>
# 142
# Team         SDP
# League        NL
# Year        2008
# RS           637
# RA           764
# W             63
# G            162
# Playoffs       0
# Name: 142, dtype: object
# <class 'pandas.core.series.Series'>
# 143
# Team         SEA
# League        AL
# Year        2008
# RS           671
# RA           811
# W             61
# G            162
# Playoffs       0
# Name: 143, dtype: object
# <class 'pandas.core.series.Series'>
# 144
# Team         SFG
# League        NL
# Year        2008
# RS           640
# RA           759
# W             72
# G            162
# Playoffs       0
# Name: 144, dtype: object
# <class 'pandas.core.series.Series'>
# 145
# Team         STL
# League        NL
# Year        2008
# RS           779
# RA           725
# W             86
# G            162
# Playoffs       0
# Name: 145, dtype: object
# <class 'pandas.core.series.Series'>
# 146
# Team         TBR
# League        AL
# Year        2008
# RS           774
# RA           671
# W             97
# G            162
# Playoffs       1
# Name: 146, dtype: object
# <class 'pandas.core.series.Series'>
# 147
# Team         TEX
# League        AL
# Year        2008
# RS           901
# RA           967
# W             79
# G            162
# Playoffs       0
# Name: 147, dtype: object
# <class 'pandas.core.series.Series'>
# 148
# Team         TOR
# League        AL
# Year        2008
# RS           714
# RA           610
# W             86
# G            162
# Playoffs       0
# Name: 148, dtype: object
# <class 'pandas.core.series.Series'>
# 149
# Team         WSN
# League        NL
# Year        2008
# RS           641
# RA           825
# W             59
# G            161
# Playoffs       0
# Name: 149, dtype: object
# <class 'pandas.core.series.Series'>
# 150
# Team         ARI
# League        NL
# Year        2007
# RS           712
# RA           732
# W             90
# G            162
# Playoffs       1
# Name: 150, dtype: object
# <class 'pandas.core.series.Series'>
# 151
# Team         ATL
# League        NL
# Year        2007
# RS           810
# RA           733
# W             84
# G            162
# Playoffs       0
# Name: 151, dtype: object
# <class 'pandas.core.series.Series'>
# 152
# Team         BAL
# League        AL
# Year        2007
# RS           756
# RA           868
# W             69
# G            162
# Playoffs       0
# Name: 152, dtype: object
# <class 'pandas.core.series.Series'>
# 153
# Team         BOS
# League        AL
# Year        2007
# RS           867
# RA           657
# W             96
# G            162
# Playoffs       1
# Name: 153, dtype: object
# <class 'pandas.core.series.Series'>
# 154
# Team         CHC
# League        NL
# Year        2007
# RS           752
# RA           690
# W             85
# G            162
# Playoffs       1
# Name: 154, dtype: object
# <class 'pandas.core.series.Series'>
# 155
# Team         CHW
# League        AL
# Year        2007
# RS           693
# RA           839
# W             72
# G            162
# Playoffs       0
# Name: 155, dtype: object
# <class 'pandas.core.series.Series'>
# 156
# Team         CIN
# League        NL
# Year        2007
# RS           783
# RA           853
# W             72
# G            162
# Playoffs       0
# Name: 156, dtype: object
# <class 'pandas.core.series.Series'>
# 157
# Team         CLE
# League        AL
# Year        2007
# RS           811
# RA           704
# W             96
# G            162
# Playoffs       1
# Name: 157, dtype: object
# <class 'pandas.core.series.Series'>
# 158
# Team         COL
# League        NL
# Year        2007
# RS           860
# RA           758
# W             90
# G            163
# Playoffs       1
# Name: 158, dtype: object
# <class 'pandas.core.series.Series'>
# 159
# Team         DET
# League        AL
# Year        2007
# RS           887
# RA           797
# W             88
# G            162
# Playoffs       0
# Name: 159, dtype: object
# <class 'pandas.core.series.Series'>
# 160
# Team         FLA
# League        NL
# Year        2007
# RS           790
# RA           891
# W             71
# G            162
# Playoffs       0
# Name: 160, dtype: object
# <class 'pandas.core.series.Series'>
# 161
# Team         HOU
# League        NL
# Year        2007
# RS           723
# RA           813
# W             73
# G            162
# Playoffs       0
# Name: 161, dtype: object
# <class 'pandas.core.series.Series'>
# 162
# Team         KCR
# League        AL
# Year        2007
# RS           706
# RA           778
# W             69
# G            162
# Playoffs       0
# Name: 162, dtype: object
# <class 'pandas.core.series.Series'>
# 163
# Team         LAA
# League        AL
# Year        2007
# RS           822
# RA           731
# W             94
# G            162
# Playoffs       1
# Name: 163, dtype: object
# <class 'pandas.core.series.Series'>
# 164
# Team         LAD
# League        NL
# Year        2007
# RS           735
# RA           727
# W             82
# G            162
# Playoffs       0
# Name: 164, dtype: object
# <class 'pandas.core.series.Series'>
# 165
# Team         MIL
# League        NL
# Year        2007
# RS           801
# RA           776
# W             83
# G            162
# Playoffs       0
# Name: 165, dtype: object
# <class 'pandas.core.series.Series'>
# 166
# Team         MIN
# League        AL
# Year        2007
# RS           718
# RA           725
# W             79
# G            162
# Playoffs       0
# Name: 166, dtype: object
# <class 'pandas.core.series.Series'>
# 167
# Team         NYM
# League        NL
# Year        2007
# RS           804
# RA           750
# W             88
# G            162
# Playoffs       0
# Name: 167, dtype: object
# <class 'pandas.core.series.Series'>
# 168
# Team         NYY
# League        AL
# Year        2007
# RS           968
# RA           777
# W             94
# G            162
# Playoffs       1
# Name: 168, dtype: object
# <class 'pandas.core.series.Series'>
# 169
# Team         OAK
# League        AL
# Year        2007
# RS           741
# RA           758
# W             76
# G            162
# Playoffs       0
# Name: 169, dtype: object
# <class 'pandas.core.series.Series'>
# 170
# Team         PHI
# League        NL
# Year        2007
# RS           892
# RA           821
# W             89
# G            162
# Playoffs       1
# Name: 170, dtype: object
# <class 'pandas.core.series.Series'>
# 171
# Team         PIT
# League        NL
# Year        2007
# RS           724
# RA           846
# W             68
# G            162
# Playoffs       0
# Name: 171, dtype: object
# <class 'pandas.core.series.Series'>
# 172
# Team         SDP
# League        NL
# Year        2007
# RS           741
# RA           666
# W             89
# G            163
# Playoffs       0
# Name: 172, dtype: object
# <class 'pandas.core.series.Series'>
# 173
# Team         SEA
# League        AL
# Year        2007
# RS           794
# RA           813
# W             88
# G            162
# Playoffs       0
# Name: 173, dtype: object
# <class 'pandas.core.series.Series'>
# 174
# Team         SFG
# League        NL
# Year        2007
# RS           683
# RA           720
# W             71
# G            162
# Playoffs       0
# Name: 174, dtype: object
# <class 'pandas.core.series.Series'>
# 175
# Team         STL
# League        NL
# Year        2007
# RS           725
# RA           829
# W             78
# G            162
# Playoffs       0
# Name: 175, dtype: object
# <class 'pandas.core.series.Series'>
# 176
# Team         TBD
# League        AL
# Year        2007
# RS           782
# RA           944
# W             66
# G            162
# Playoffs       0
# Name: 176, dtype: object
# <class 'pandas.core.series.Series'>
# 177
# Team         TEX
# League        AL
# Year        2007
# RS           816
# RA           844
# W             75
# G            162
# Playoffs       0
# Name: 177, dtype: object
# <class 'pandas.core.series.Series'>
# 178
# Team         TOR
# League        AL
# Year        2007
# RS           753
# RA           699
# W             83
# G            162
# Playoffs       0
# Name: 178, dtype: object
# <class 'pandas.core.series.Series'>
# 179
# Team         WSN
# League        NL
# Year        2007
# RS           673
# RA           783
# W             73
# G            162
# Playoffs       0
# Name: 179, dtype: object
# <class 'pandas.core.series.Series'>
# 180
# Team         ARI
# League        NL
# Year        2006
# RS           773
# RA           788
# W             76
# G            162
# Playoffs       0
# Name: 180, dtype: object
# <class 'pandas.core.series.Series'>
# 181
# Team         ATL
# League        NL
# Year        2006
# RS           849
# RA           805
# W             79
# G            162
# Playoffs       0
# Name: 181, dtype: object
# <class 'pandas.core.series.Series'>
# 182
# Team         BAL
# League        AL
# Year        2006
# RS           768
# RA           899
# W             70
# G            162
# Playoffs       0
# Name: 182, dtype: object
# <class 'pandas.core.series.Series'>
# 183
# Team         BOS
# League        AL
# Year        2006
# RS           820
# RA           825
# W             86
# G            162
# Playoffs       0
# Name: 183, dtype: object
# <class 'pandas.core.series.Series'>
# 184
# Team         CHC
# League        NL
# Year        2006
# RS           716
# RA           834
# W             66
# G            162
# Playoffs       0
# Name: 184, dtype: object
# <class 'pandas.core.series.Series'>
# 185
# Team         CHW
# League        AL
# Year        2006
# RS           868
# RA           794
# W             90
# G            162
# Playoffs       0
# Name: 185, dtype: object
# <class 'pandas.core.series.Series'>
# 186
# Team         CIN
# League        NL
# Year        2006
# RS           749
# RA           801
# W             80
# G            162
# Playoffs       0
# Name: 186, dtype: object
# <class 'pandas.core.series.Series'>
# 187
# Team         CLE
# League        AL
# Year        2006
# RS           870
# RA           782
# W             78
# G            162
# Playoffs       0
# Name: 187, dtype: object
# <class 'pandas.core.series.Series'>
# 188
# Team         COL
# League        NL
# Year        2006
# RS           813
# RA           812
# W             76
# G            162
# Playoffs       0
# Name: 188, dtype: object
# <class 'pandas.core.series.Series'>
# 189
# Team         DET
# League        AL
# Year        2006
# RS           822
# RA           675
# W             95
# G            162
# Playoffs       1
# Name: 189, dtype: object
# <class 'pandas.core.series.Series'>
# 190
# Team         FLA
# League        NL
# Year        2006
# RS           758
# RA           772
# W             78
# G            162
# Playoffs       0
# Name: 190, dtype: object
# <class 'pandas.core.series.Series'>
# 191
# Team         HOU
# League        NL
# Year        2006
# RS           735
# RA           719
# W             82
# G            162
# Playoffs       0
# Name: 191, dtype: object
# <class 'pandas.core.series.Series'>
# 192
# Team         KCR
# League        AL
# Year        2006
# RS           757
# RA           971
# W             62
# G            162
# Playoffs       0
# Name: 192, dtype: object
# <class 'pandas.core.series.Series'>
# 193
# Team         LAA
# League        AL
# Year        2006
# RS           766
# RA           732
# W             89
# G            162
# Playoffs       0
# Name: 193, dtype: object
# <class 'pandas.core.series.Series'>
# 194
# Team         LAD
# League        NL
# Year        2006
# RS           820
# RA           751
# W             88
# G            162
# Playoffs       1
# Name: 194, dtype: object
# <class 'pandas.core.series.Series'>
# 195
# Team         MIL
# League        NL
# Year        2006
# RS           730
# RA           833
# W             75
# G            162
# Playoffs       0
# Name: 195, dtype: object
# <class 'pandas.core.series.Series'>
# 196
# Team         MIN
# League        AL
# Year        2006
# RS           801
# RA           683
# W             96
# G            162
# Playoffs       1
# Name: 196, dtype: object
# <class 'pandas.core.series.Series'>
# 197
# Team         NYM
# League        NL
# Year        2006
# RS           834
# RA           731
# W             97
# G            162
# Playoffs       1
# Name: 197, dtype: object
# <class 'pandas.core.series.Series'>
# 198
# Team         NYY
# League        AL
# Year        2006
# RS           930
# RA           767
# W             97
# G            162
# Playoffs       1
# Name: 198, dtype: object
# <class 'pandas.core.series.Series'>
# 199
# Team         OAK
# League        AL
# Year        2006
# RS           771
# RA           727
# W             93
# G            162
# Playoffs       1
# Name: 199, dtype: object
# <class 'pandas.core.series.Series'>
# 200
# Team         PHI
# League        NL
# Year        2006
# RS           865
# RA           812
# W             85
# G            162
# Playoffs       0
# Name: 200, dtype: object
# <class 'pandas.core.series.Series'>
# 201
# Team         PIT
# League        NL
# Year        2006
# RS           691
# RA           797
# W             67
# G            162
# Playoffs       0
# Name: 201, dtype: object
# <class 'pandas.core.series.Series'>
# 202
# Team         SDP
# League        NL
# Year        2006
# RS           731
# RA           679
# W             88
# G            162
# Playoffs       1
# Name: 202, dtype: object
# <class 'pandas.core.series.Series'>
# 203
# Team         SEA
# League        AL
# Year        2006
# RS           756
# RA           792
# W             78
# G            162
# Playoffs       0
# Name: 203, dtype: object
# <class 'pandas.core.series.Series'>
# 204
# Team         SFG
# League        NL
# Year        2006
# RS           746
# RA           790
# W             76
# G            161
# Playoffs       0
# Name: 204, dtype: object
# <class 'pandas.core.series.Series'>
# 205
# Team         STL
# League        NL
# Year        2006
# RS           781
# RA           762
# W             83
# G            161
# Playoffs       1
# Name: 205, dtype: object
# <class 'pandas.core.series.Series'>
# 206
# Team         TBD
# League        AL
# Year        2006
# RS           689
# RA           856
# W             61
# G            162
# Playoffs       0
# Name: 206, dtype: object
# <class 'pandas.core.series.Series'>
# 207
# Team         TEX
# League        AL
# Year        2006
# RS           835
# RA           784
# W             80
# G            162
# Playoffs       0
# Name: 207, dtype: object
# <class 'pandas.core.series.Series'>
# 208
# Team         TOR
# League        AL
# Year        2006
# RS           809
# RA           754
# W             87
# G            162
# Playoffs       0
# Name: 208, dtype: object
# <class 'pandas.core.series.Series'>
# 209
# Team         WSN
# League        NL
# Year        2006
# RS           746
# RA           872
# W             71
# G            162
# Playoffs       0
# Name: 209, dtype: object
# <class 'pandas.core.series.Series'>
# 210
# Team         ARI
# League        NL
# Year        2005
# RS           696
# RA           856
# W             77
# G            162
# Playoffs       0
# Name: 210, dtype: object
# <class 'pandas.core.series.Series'>
# 211
# Team         ATL
# League        NL
# Year        2005
# RS           769
# RA           674
# W             90
# G            162
# Playoffs       1
# Name: 211, dtype: object
# <class 'pandas.core.series.Series'>
# 212
# Team         BAL
# League        AL
# Year        2005
# RS           729
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 212, dtype: object
# <class 'pandas.core.series.Series'>
# 213
# Team         BOS
# League        AL
# Year        2005
# RS           910
# RA           805
# W             95
# G            162
# Playoffs       1
# Name: 213, dtype: object
# <class 'pandas.core.series.Series'>
# 214
# Team         CHC
# League        NL
# Year        2005
# RS           703
# RA           714
# W             79
# G            162
# Playoffs       0
# Name: 214, dtype: object
# <class 'pandas.core.series.Series'>
# 215
# Team         CHW
# League        AL
# Year        2005
# RS           741
# RA           645
# W             99
# G            162
# Playoffs       1
# Name: 215, dtype: object
# <class 'pandas.core.series.Series'>
# 216
# Team         CIN
# League        NL
# Year        2005
# RS           820
# RA           889
# W             73
# G            163
# Playoffs       0
# Name: 216, dtype: object
# <class 'pandas.core.series.Series'>
# 217
# Team         CLE
# League        AL
# Year        2005
# RS           790
# RA           642
# W             93
# G            162
# Playoffs       0
# Name: 217, dtype: object
# <class 'pandas.core.series.Series'>
# 218
# Team         COL
# League        NL
# Year        2005
# RS           740
# RA           862
# W             67
# G            162
# Playoffs       0
# Name: 218, dtype: object
# <class 'pandas.core.series.Series'>
# 219
# Team         DET
# League        AL
# Year        2005
# RS           723
# RA           787
# W             71
# G            162
# Playoffs       0
# Name: 219, dtype: object
# <class 'pandas.core.series.Series'>
# 220
# Team         FLA
# League        NL
# Year        2005
# RS           717
# RA           732
# W             83
# G            162
# Playoffs       0
# Name: 220, dtype: object
# <class 'pandas.core.series.Series'>
# 221
# Team         HOU
# League        NL
# Year        2005
# RS           693
# RA           609
# W             89
# G            163
# Playoffs       1
# Name: 221, dtype: object
# <class 'pandas.core.series.Series'>
# 222
# Team         KCR
# League        AL
# Year        2005
# RS           701
# RA           935
# W             56
# G            162
# Playoffs       0
# Name: 222, dtype: object
# <class 'pandas.core.series.Series'>
# 223
# Team         LAA
# League        AL
# Year        2005
# RS           761
# RA           643
# W             95
# G            162
# Playoffs       1
# Name: 223, dtype: object
# <class 'pandas.core.series.Series'>
# 224
# Team         LAD
# League        NL
# Year        2005
# RS           685
# RA           755
# W             71
# G            162
# Playoffs       0
# Name: 224, dtype: object
# <class 'pandas.core.series.Series'>
# 225
# Team         MIL
# League        NL
# Year        2005
# RS           726
# RA           697
# W             81
# G            162
# Playoffs       0
# Name: 225, dtype: object
# <class 'pandas.core.series.Series'>
# 226
# Team         MIN
# League        AL
# Year        2005
# RS           688
# RA           662
# W             83
# G            162
# Playoffs       0
# Name: 226, dtype: object
# <class 'pandas.core.series.Series'>
# 227
# Team         NYM
# League        NL
# Year        2005
# RS           722
# RA           648
# W             83
# G            162
# Playoffs       0
# Name: 227, dtype: object
# <class 'pandas.core.series.Series'>
# 228
# Team         NYY
# League        AL
# Year        2005
# RS           886
# RA           789
# W             95
# G            162
# Playoffs       1
# Name: 228, dtype: object
# <class 'pandas.core.series.Series'>
# 229
# Team         OAK
# League        AL
# Year        2005
# RS           772
# RA           658
# W             88
# G            162
# Playoffs       0
# Name: 229, dtype: object
# <class 'pandas.core.series.Series'>
# 230
# Team         PHI
# League        NL
# Year        2005
# RS           807
# RA           726
# W             88
# G            162
# Playoffs       0
# Name: 230, dtype: object
# <class 'pandas.core.series.Series'>
# 231
# Team         PIT
# League        NL
# Year        2005
# RS           680
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 231, dtype: object
# <class 'pandas.core.series.Series'>
# 232
# Team         SDP
# League        NL
# Year        2005
# RS           684
# RA           726
# W             82
# G            162
# Playoffs       1
# Name: 232, dtype: object
# <class 'pandas.core.series.Series'>
# 233
# Team         SEA
# League        AL
# Year        2005
# RS           699
# RA           751
# W             69
# G            162
# Playoffs       0
# Name: 233, dtype: object
# <class 'pandas.core.series.Series'>
# 234
# Team         SFG
# League        NL
# Year        2005
# RS           649
# RA           745
# W             75
# G            162
# Playoffs       0
# Name: 234, dtype: object
# <class 'pandas.core.series.Series'>
# 235
# Team         STL
# League        NL
# Year        2005
# RS           805
# RA           634
# W            100
# G            162
# Playoffs       1
# Name: 235, dtype: object
# <class 'pandas.core.series.Series'>
# 236
# Team         TBD
# League        AL
# Year        2005
# RS           750
# RA           936
# W             67
# G            162
# Playoffs       0
# Name: 236, dtype: object
# <class 'pandas.core.series.Series'>
# 237
# Team         TEX
# League        AL
# Year        2005
# RS           865
# RA           858
# W             79
# G            162
# Playoffs       0
# Name: 237, dtype: object
# <class 'pandas.core.series.Series'>
# 238
# Team         TOR
# League        AL
# Year        2005
# RS           775
# RA           705
# W             80
# G            162
# Playoffs       0
# Name: 238, dtype: object
# <class 'pandas.core.series.Series'>
# 239
# Team         WSN
# League        NL
# Year        2005
# RS           639
# RA           673
# W             81
# G            162
# Playoffs       0
# Name: 239, dtype: object
# ...
# Year        1965
# RS           669
# RA           791
# W             62
# G            162
# Playoffs       0
# Name: 1153, dtype: object
# <class 'pandas.core.series.Series'>
# 1154
# Team         CAL
# League        AL
# Year        1965
# RS           527
# RA           569
# W             75
# G            162
# Playoffs       0
# Name: 1154, dtype: object
# <class 'pandas.core.series.Series'>
# 1155
# Team         CHC
# League        NL
# Year        1965
# RS           635
# RA           723
# W             72
# G            164
# Playoffs       0
# Name: 1155, dtype: object
# <class 'pandas.core.series.Series'>
# 1156
# Team         CHW
# League        AL
# Year        1965
# RS           647
# RA           555
# W             95
# G            162
# Playoffs       0
# Name: 1156, dtype: object
# <class 'pandas.core.series.Series'>
# 1157
# Team         CIN
# League        NL
# Year        1965
# RS           825
# RA           704
# W             89
# G            162
# Playoffs       0
# Name: 1157, dtype: object
# <class 'pandas.core.series.Series'>
# 1158
# Team         CLE
# League        AL
# Year        1965
# RS           663
# RA           613
# W             87
# G            162
# Playoffs       0
# Name: 1158, dtype: object
# <class 'pandas.core.series.Series'>
# 1159
# Team         DET
# League        AL
# Year        1965
# RS           680
# RA           602
# W             89
# G            162
# Playoffs       0
# Name: 1159, dtype: object
# <class 'pandas.core.series.Series'>
# 1160
# Team         HOU
# League        NL
# Year        1965
# RS           569
# RA           711
# W             65
# G            162
# Playoffs       0
# Name: 1160, dtype: object
# <class 'pandas.core.series.Series'>
# 1161
# Team         KCA
# League        AL
# Year        1965
# RS           585
# RA           755
# W             59
# G            162
# Playoffs       0
# Name: 1161, dtype: object
# <class 'pandas.core.series.Series'>
# 1162
# Team         LAD
# League        NL
# Year        1965
# RS           608
# RA           521
# W             97
# G            162
# Playoffs       1
# Name: 1162, dtype: object
# <class 'pandas.core.series.Series'>
# 1163
# Team         MIN
# League        AL
# Year        1965
# RS           774
# RA           600
# W            102
# G            162
# Playoffs       1
# Name: 1163, dtype: object
# <class 'pandas.core.series.Series'>
# 1164
# Team         MLN
# League        NL
# Year        1965
# RS           708
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 1164, dtype: object
# <class 'pandas.core.series.Series'>
# 1165
# Team         NYM
# League        NL
# Year        1965
# RS           495
# RA           752
# W             50
# G            164
# Playoffs       0
# Name: 1165, dtype: object
# <class 'pandas.core.series.Series'>
# 1166
# Team         NYY
# League        AL
# Year        1965
# RS           611
# RA           604
# W             77
# G            162
# Playoffs       0
# Name: 1166, dtype: object
# <class 'pandas.core.series.Series'>
# 1167
# Team         PHI
# League        NL
# Year        1965
# RS           654
# RA           667
# W             85
# G            162
# Playoffs       0
# Name: 1167, dtype: object
# <class 'pandas.core.series.Series'>
# 1168
# Team         PIT
# League        NL
# Year        1965
# RS           675
# RA           580
# W             90
# G            163
# Playoffs       0
# Name: 1168, dtype: object
# <class 'pandas.core.series.Series'>
# 1169
# Team         SFG
# League        NL
# Year        1965
# RS           682
# RA           593
# W             95
# G            163
# Playoffs       0
# Name: 1169, dtype: object
# <class 'pandas.core.series.Series'>
# 1170
# Team         STL
# League        NL
# Year        1965
# RS           707
# RA           674
# W             80
# G            162
# Playoffs       0
# Name: 1170, dtype: object
# <class 'pandas.core.series.Series'>
# 1171
# Team         WSA
# League        AL
# Year        1965
# RS           591
# RA           721
# W             70
# G            162
# Playoffs       0
# Name: 1171, dtype: object
# <class 'pandas.core.series.Series'>
# 1172
# Team         BAL
# League        AL
# Year        1964
# RS           679
# RA           567
# W             97
# G            163
# Playoffs       0
# Name: 1172, dtype: object
# <class 'pandas.core.series.Series'>
# 1173
# Team         BOS
# League        AL
# Year        1964
# RS           688
# RA           793
# W             72
# G            162
# Playoffs       0
# Name: 1173, dtype: object
# <class 'pandas.core.series.Series'>
# 1174
# Team         CHC
# League        NL
# Year        1964
# RS           649
# RA           724
# W             76
# G            162
# Playoffs       0
# Name: 1174, dtype: object
# <class 'pandas.core.series.Series'>
# 1175
# Team         CHW
# League        AL
# Year        1964
# RS           642
# RA           501
# W             98
# G            162
# Playoffs       0
# Name: 1175, dtype: object
# <class 'pandas.core.series.Series'>
# 1176
# Team         CIN
# League        NL
# Year        1964
# RS           660
# RA           566
# W             92
# G            163
# Playoffs       0
# Name: 1176, dtype: object
# <class 'pandas.core.series.Series'>
# 1177
# Team         CLE
# League        AL
# Year        1964
# RS           689
# RA           693
# W             79
# G            164
# Playoffs       0
# Name: 1177, dtype: object
# <class 'pandas.core.series.Series'>
# 1178
# Team         DET
# League        AL
# Year        1964
# RS           699
# RA           678
# W             85
# G            163
# Playoffs       0
# Name: 1178, dtype: object
# <class 'pandas.core.series.Series'>
# 1179
# Team         HOU
# League        NL
# Year        1964
# RS           495
# RA           628
# W             66
# G            162
# Playoffs       0
# Name: 1179, dtype: object
# <class 'pandas.core.series.Series'>
# 1180
# Team         KCA
# League        AL
# Year        1964
# RS           621
# RA           836
# W             57
# G            163
# Playoffs       0
# Name: 1180, dtype: object
# <class 'pandas.core.series.Series'>
# 1181
# Team         LAA
# League        AL
# Year        1964
# RS           544
# RA           551
# W             82
# G            162
# Playoffs       0
# Name: 1181, dtype: object
# <class 'pandas.core.series.Series'>
# 1182
# Team         LAD
# League        NL
# Year        1964
# RS           614
# RA           572
# W             80
# G            164
# Playoffs       0
# Name: 1182, dtype: object
# <class 'pandas.core.series.Series'>
# 1183
# Team         MIN
# League        AL
# Year        1964
# RS           737
# RA           678
# W             79
# G            163
# Playoffs       0
# Name: 1183, dtype: object
# <class 'pandas.core.series.Series'>
# 1184
# Team         MLN
# League        NL
# Year        1964
# RS           803
# RA           744
# W             88
# G            162
# Playoffs       0
# Name: 1184, dtype: object
# <class 'pandas.core.series.Series'>
# 1185
# Team         NYM
# League        NL
# Year        1964
# RS           569
# RA           776
# W             53
# G            163
# Playoffs       0
# Name: 1185, dtype: object
# <class 'pandas.core.series.Series'>
# 1186
# Team         NYY
# League        AL
# Year        1964
# RS           730
# RA           577
# W             99
# G            164
# Playoffs       1
# Name: 1186, dtype: object
# <class 'pandas.core.series.Series'>
# 1187
# Team         PHI
# League        NL
# Year        1964
# RS           693
# RA           632
# W             92
# G            162
# Playoffs       0
# Name: 1187, dtype: object
# <class 'pandas.core.series.Series'>
# 1188
# Team         PIT
# League        NL
# Year        1964
# RS           663
# RA           636
# W             80
# G            162
# Playoffs       0
# Name: 1188, dtype: object
# <class 'pandas.core.series.Series'>
# 1189
# Team         SFG
# League        NL
# Year        1964
# RS           656
# RA           587
# W             90
# G            162
# Playoffs       0
# Name: 1189, dtype: object
# <class 'pandas.core.series.Series'>
# 1190
# Team         STL
# League        NL
# Year        1964
# RS           715
# RA           652
# W             93
# G            162
# Playoffs       1
# Name: 1190, dtype: object
# <class 'pandas.core.series.Series'>
# 1191
# Team         WSA
# League        AL
# Year        1964
# RS           578
# RA           733
# W             62
# G            162
# Playoffs       0
# Name: 1191, dtype: object
# <class 'pandas.core.series.Series'>
# 1192
# Team         BAL
# League        AL
# Year        1963
# RS           644
# RA           621
# W             86
# G            162
# Playoffs       0
# Name: 1192, dtype: object
# <class 'pandas.core.series.Series'>
# 1193
# Team         BOS
# League        AL
# Year        1963
# RS           666
# RA           704
# W             76
# G            161
# Playoffs       0
# Name: 1193, dtype: object
# <class 'pandas.core.series.Series'>
# 1194
# Team         CHC
# League        NL
# Year        1963
# RS           570
# RA           578
# W             82
# G            162
# Playoffs       0
# Name: 1194, dtype: object
# <class 'pandas.core.series.Series'>
# 1195
# Team         CHW
# League        AL
# Year        1963
# RS           683
# RA           544
# W             94
# G            162
# Playoffs       0
# Name: 1195, dtype: object
# <class 'pandas.core.series.Series'>
# 1196
# Team         CIN
# League        NL
# Year        1963
# RS           648
# RA           594
# W             86
# G            162
# Playoffs       0
# Name: 1196, dtype: object
# <class 'pandas.core.series.Series'>
# 1197
# Team         CLE
# League        AL
# Year        1963
# RS           635
# RA           702
# W             79
# G            162
# Playoffs       0
# Name: 1197, dtype: object
# <class 'pandas.core.series.Series'>
# 1198
# Team         DET
# League        AL
# Year        1963
# RS           700
# RA           703
# W             79
# G            162
# Playoffs       0
# Name: 1198, dtype: object
# <class 'pandas.core.series.Series'>
# 1199
# Team         HOU
# League        NL
# Year        1963
# RS           464
# RA           640
# W             66
# G            162
# Playoffs       0
# Name: 1199, dtype: object
# <class 'pandas.core.series.Series'>
# 1200
# Team         KCA
# League        AL
# Year        1963
# RS           615
# RA           704
# W             73
# G            162
# Playoffs       0
# Name: 1200, dtype: object
# <class 'pandas.core.series.Series'>
# 1201
# Team         LAA
# League        AL
# Year        1963
# RS           597
# RA           660
# W             70
# G            161
# Playoffs       0
# Name: 1201, dtype: object
# <class 'pandas.core.series.Series'>
# 1202
# Team         LAD
# League        NL
# Year        1963
# RS           640
# RA           550
# W             99
# G            163
# Playoffs       1
# Name: 1202, dtype: object
# <class 'pandas.core.series.Series'>
# 1203
# Team         MIN
# League        AL
# Year        1963
# RS           767
# RA           602
# W             91
# G            161
# Playoffs       0
# Name: 1203, dtype: object
# <class 'pandas.core.series.Series'>
# 1204
# Team         MLN
# League        NL
# Year        1963
# RS           677
# RA           603
# W             84
# G            163
# Playoffs       0
# Name: 1204, dtype: object
# <class 'pandas.core.series.Series'>
# 1205
# Team         NYM
# League        NL
# Year        1963
# RS           501
# RA           774
# W             51
# G            162
# Playoffs       0
# Name: 1205, dtype: object
# <class 'pandas.core.series.Series'>
# 1206
# Team         NYY
# League        AL
# Year        1963
# RS           714
# RA           547
# W            104
# G            161
# Playoffs       1
# Name: 1206, dtype: object
# <class 'pandas.core.series.Series'>
# 1207
# Team         PHI
# League        NL
# Year        1963
# RS           642
# RA           578
# W             87
# G            162
# Playoffs       0
# Name: 1207, dtype: object
# <class 'pandas.core.series.Series'>
# 1208
# Team         PIT
# League        NL
# Year        1963
# RS           567
# RA           595
# W             74
# G            162
# Playoffs       0
# Name: 1208, dtype: object
# <class 'pandas.core.series.Series'>
# 1209
# Team         SFG
# League        NL
# Year        1963
# RS           725
# RA           641
# W             88
# G            162
# Playoffs       0
# Name: 1209, dtype: object
# <class 'pandas.core.series.Series'>
# 1210
# Team         STL
# League        NL
# Year        1963
# RS           747
# RA           628
# W             93
# G            162
# Playoffs       0
# Name: 1210, dtype: object
# <class 'pandas.core.series.Series'>
# 1211
# Team         WSA
# League        AL
# Year        1963
# RS           578
# RA           812
# W             56
# G            162
# Playoffs       0
# Name: 1211, dtype: object
# <class 'pandas.core.series.Series'>
# 1212
# Team         BAL
# League        AL
# Year        1962
# RS           652
# RA           680
# W             77
# G            162
# Playoffs       0
# Name: 1212, dtype: object
# <class 'pandas.core.series.Series'>
# 1213
# Team         BOS
# League        AL
# Year        1962
# RS           707
# RA           756
# W             76
# G            160
# Playoffs       0
# Name: 1213, dtype: object
# <class 'pandas.core.series.Series'>
# 1214
# Team         CHC
# League        NL
# Year        1962
# RS           632
# RA           827
# W             59
# G            162
# Playoffs       0
# Name: 1214, dtype: object
# <class 'pandas.core.series.Series'>
# 1215
# Team         CHW
# League        AL
# Year        1962
# RS           707
# RA           658
# W             85
# G            162
# Playoffs       0
# Name: 1215, dtype: object
# <class 'pandas.core.series.Series'>
# 1216
# Team         CIN
# League        NL
# Year        1962
# RS           802
# RA           685
# W             98
# G            162
# Playoffs       0
# Name: 1216, dtype: object
# <class 'pandas.core.series.Series'>
# 1217
# Team         CLE
# League        AL
# Year        1962
# RS           682
# RA           745
# W             80
# G            162
# Playoffs       0
# Name: 1217, dtype: object
# <class 'pandas.core.series.Series'>
# 1218
# Team         DET
# League        AL
# Year        1962
# RS           758
# RA           692
# W             85
# G            161
# Playoffs       0
# Name: 1218, dtype: object
# <class 'pandas.core.series.Series'>
# 1219
# Team         HOU
# League        NL
# Year        1962
# RS           592
# RA           717
# W             64
# G            162
# Playoffs       0
# Name: 1219, dtype: object
# <class 'pandas.core.series.Series'>
# 1220
# Team         KCA
# League        AL
# Year        1962
# RS           745
# RA           837
# W             72
# G            162
# Playoffs       0
# Name: 1220, dtype: object
# <class 'pandas.core.series.Series'>
# 1221
# Team         LAA
# League        AL
# Year        1962
# RS           718
# RA           706
# W             86
# G            162
# Playoffs       0
# Name: 1221, dtype: object
# <class 'pandas.core.series.Series'>
# 1222
# Team         LAD
# League        NL
# Year        1962
# RS           842
# RA           697
# W            102
# G            165
# Playoffs       0
# Name: 1222, dtype: object
# <class 'pandas.core.series.Series'>
# 1223
# Team         MIN
# League        AL
# Year        1962
# RS           798
# RA           713
# W             91
# G            163
# Playoffs       0
# Name: 1223, dtype: object
# <class 'pandas.core.series.Series'>
# 1224
# Team         MLN
# League        NL
# Year        1962
# RS           730
# RA           665
# W             86
# G            162
# Playoffs       0
# Name: 1224, dtype: object
# <class 'pandas.core.series.Series'>
# 1225
# Team         NYM
# League        NL
# Year        1962
# RS           617
# RA           948
# W             40
# G            161
# Playoffs       0
# Name: 1225, dtype: object
# <class 'pandas.core.series.Series'>
# 1226
# Team         NYY
# League        AL
# Year        1962
# RS           817
# RA           680
# W             96
# G            162
# Playoffs       1
# Name: 1226, dtype: object
# <class 'pandas.core.series.Series'>
# 1227
# Team         PHI
# League        NL
# Year        1962
# RS           705
# RA           759
# W             81
# G            161
# Playoffs       0
# Name: 1227, dtype: object
# <class 'pandas.core.series.Series'>
# 1228
# Team         PIT
# League        NL
# Year        1962
# RS           706
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1228, dtype: object
# <class 'pandas.core.series.Series'>
# 1229
# Team         SFG
# League        NL
# Year        1962
# RS           878
# RA           690
# W            103
# G            165
# Playoffs       1
# Name: 1229, dtype: object
# <class 'pandas.core.series.Series'>
# 1230
# Team         STL
# League        NL
# Year        1962
# RS           774
# RA           664
# W             84
# G            163
# Playoffs       0
# Name: 1230, dtype: object
# <class 'pandas.core.series.Series'>
# 1231
# Team         WSA
# League        AL
# Year        1962
# RS           599
# RA           716
# W             60
# G            162
# Playoffs       0
# Name: 1231, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# Use one variable instead of two to store the result of .iterrows()
for row_tuple in pit_df.iterrows():
    print(row_tuple)
# Out:
# (0, Team         ARI
# League        NL
# Year        2012
# RS           734
# RA           688
# W             81
# G            162
# Playoffs       0
# Name: 0, dtype: object)
# (1, Team         ATL
# League        NL
# Year        2012
# RS           700
# RA           600
# W             94
# G            162
# Playoffs       1
# Name: 1, dtype: object)
# (2, Team         BAL
# League        AL
# Year        2012
# RS           712
# RA           705
# W             93
# G            162
# Playoffs       1
# Name: 2, dtype: object)
# (3, Team         BOS
# League        AL
# Year        2012
# RS           734
# RA           806
# W             69
# G            162
# Playoffs       0
# Name: 3, dtype: object)
# (4, Team         CHC
# League        NL
# Year        2012
# RS           613
# RA           759
# W             61
# G            162
# Playoffs       0
# Name: 4, dtype: object)
# (5, Team         CHW
# League        AL
# Year        2012
# RS           748
# RA           676
# W             85
# G            162
# Playoffs       0
# Name: 5, dtype: object)
# (6, Team         CIN
# League        NL
# Year        2012
# RS           669
# RA           588
# W             97
# G            162
# Playoffs       1
# Name: 6, dtype: object)
# (7, Team         CLE
# League        AL
# Year        2012
# RS           667
# RA           845
# W             68
# G            162
# Playoffs       0
# Name: 7, dtype: object)
# (8, Team         COL
# League        NL
# Year        2012
# RS           758
# RA           890
# W             64
# G            162
# Playoffs       0
# Name: 8, dtype: object)
# (9, Team         DET
# League        AL
# Year        2012
# RS           726
# RA           670
# W             88
# G            162
# Playoffs       1
# Name: 9, dtype: object)
# (10, Team         HOU
# League        NL
# Year        2012
# RS           583
# RA           794
# W             55
# G            162
# Playoffs       0
# Name: 10, dtype: object)
# (11, Team         KCR
# League        AL
# Year        2012
# RS           676
# RA           746
# W             72
# G            162
# Playoffs       0
# Name: 11, dtype: object)
# (12, Team         LAA
# League        AL
# Year        2012
# RS           767
# RA           699
# W             89
# G            162
# Playoffs       0
# Name: 12, dtype: object)
# (13, Team         LAD
# League        NL
# Year        2012
# RS           637
# RA           597
# W             86
# G            162
# Playoffs       0
# Name: 13, dtype: object)
# (14, Team         MIA
# League        NL
# Year        2012
# RS           609
# RA           724
# W             69
# G            162
# Playoffs       0
# Name: 14, dtype: object)
# (15, Team         MIL
# League        NL
# Year        2012
# RS           776
# RA           733
# W             83
# G            162
# Playoffs       0
# Name: 15, dtype: object)
# (16, Team         MIN
# League        AL
# Year        2012
# RS           701
# RA           832
# W             66
# G            162
# Playoffs       0
# Name: 16, dtype: object)
# (17, Team         NYM
# League        NL
# Year        2012
# RS           650
# RA           709
# W             74
# G            162
# Playoffs       0
# Name: 17, dtype: object)
# (18, Team         NYY
# League        AL
# Year        2012
# RS           804
# RA           668
# W             95
# G            162
# Playoffs       1
# Name: 18, dtype: object)
# (19, Team         OAK
# League        AL
# Year        2012
# RS           713
# RA           614
# W             94
# G            162
# Playoffs       1
# Name: 19, dtype: object)
# (20, Team         PHI
# League        NL
# Year        2012
# RS           684
# RA           680
# W             81
# G            162
# Playoffs       0
# Name: 20, dtype: object)
# (21, Team         PIT
# League        NL
# Year        2012
# RS           651
# RA           674
# W             79
# G            162
# Playoffs       0
# Name: 21, dtype: object)
# (22, Team         SDP
# League        NL
# Year        2012
# RS           651
# RA           710
# W             76
# G            162
# Playoffs       0
# Name: 22, dtype: object)
# (23, Team         SEA
# League        AL
# Year        2012
# RS           619
# RA           651
# W             75
# G            162
# Playoffs       0
# Name: 23, dtype: object)
# (24, Team         SFG
# League        NL
# Year        2012
# RS           718
# RA           649
# W             94
# G            162
# Playoffs       1
# Name: 24, dtype: object)
# (25, Team         STL
# League        NL
# Year        2012
# RS           765
# RA           648
# W             88
# G            162
# Playoffs       1
# Name: 25, dtype: object)
# (26, Team         TBR
# League        AL
# Year        2012
# RS           697
# RA           577
# W             90
# G            162
# Playoffs       0
# Name: 26, dtype: object)
# (27, Team         TEX
# League        AL
# Year        2012
# RS           808
# RA           707
# W             93
# G            162
# Playoffs       1
# Name: 27, dtype: object)
# (28, Team         TOR
# League        AL
# Year        2012
# RS           716
# RA           784
# W             73
# G            162
# Playoffs       0
# Name: 28, dtype: object)
# (29, Team         WSN
# League        NL
# Year        2012
# RS           731
# RA           594
# W             98
# G            162
# Playoffs       1
# Name: 29, dtype: object)
# (30, Team         ARI
# League        NL
# Year        2011
# RS           731
# RA           662
# W             94
# G            162
# Playoffs       1
# Name: 30, dtype: object)
# (31, Team         ATL
# League        NL
# Year        2011
# RS           641
# RA           605
# W             89
# G            162
# Playoffs       0
# Name: 31, dtype: object)
# (32, Team         BAL
# League        AL
# Year        2011
# RS           708
# RA           860
# W             69
# G            162
# Playoffs       0
# Name: 32, dtype: object)
# (33, Team         BOS
# League        AL
# Year        2011
# RS           875
# RA           737
# W             90
# G            162
# Playoffs       0
# Name: 33, dtype: object)
# (34, Team         CHC
# League        NL
# Year        2011
# RS           654
# RA           756
# W             71
# G            162
# Playoffs       0
# Name: 34, dtype: object)
# (35, Team         CHW
# League        AL
# Year        2011
# RS           654
# RA           706
# W             79
# G            162
# Playoffs       0
# Name: 35, dtype: object)
# (36, Team         CIN
# League        NL
# Year        2011
# RS           735
# RA           720
# W             79
# G            162
# Playoffs       0
# Name: 36, dtype: object)
# (37, Team         CLE
# League        AL
# Year        2011
# RS           704
# RA           760
# W             80
# G            162
# Playoffs       0
# Name: 37, dtype: object)
# (38, Team         COL
# League        NL
# Year        2011
# RS           735
# RA           774
# W             73
# G            162
# Playoffs       0
# Name: 38, dtype: object)
# (39, Team         DET
# League        AL
# Year        2011
# RS           787
# RA           711
# W             95
# G            162
# Playoffs       1
# Name: 39, dtype: object)
# (40, Team         FLA
# League        NL
# Year        2011
# RS           625
# RA           702
# W             72
# G            162
# Playoffs       0
# Name: 40, dtype: object)
# (41, Team         HOU
# League        NL
# Year        2011
# RS           615
# RA           796
# W             56
# G            162
# Playoffs       0
# Name: 41, dtype: object)
# (42, Team         KCR
# League        AL
# Year        2011
# RS           730
# RA           762
# W             71
# G            162
# Playoffs       0
# Name: 42, dtype: object)
# (43, Team         LAA
# League        AL
# Year        2011
# RS           667
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 43, dtype: object)
# (44, Team         LAD
# League        NL
# Year        2011
# RS           644
# RA           612
# W             82
# G            161
# Playoffs       0
# Name: 44, dtype: object)
# (45, Team         MIL
# League        NL
# Year        2011
# RS           721
# RA           638
# W             96
# G            162
# Playoffs       1
# Name: 45, dtype: object)
# (46, Team         MIN
# League        AL
# Year        2011
# RS           619
# RA           804
# W             63
# G            162
# Playoffs       0
# Name: 46, dtype: object)
# (47, Team         NYM
# League        NL
# Year        2011
# RS           718
# RA           742
# W             77
# G            162
# Playoffs       0
# Name: 47, dtype: object)
# (48, Team         NYY
# League        AL
# Year        2011
# RS           867
# RA           657
# W             97
# G            162
# Playoffs       1
# Name: 48, dtype: object)
# (49, Team         OAK
# League        AL
# Year        2011
# RS           645
# RA           679
# W             74
# G            162
# Playoffs       0
# Name: 49, dtype: object)
# (50, Team         PHI
# League        NL
# Year        2011
# RS           713
# RA           529
# W            102
# G            162
# Playoffs       1
# Name: 50, dtype: object)
# (51, Team         PIT
# League        NL
# Year        2011
# RS           610
# RA           712
# W             72
# G            162
# Playoffs       0
# Name: 51, dtype: object)
# (52, Team         SDP
# League        NL
# Year        2011
# RS           593
# RA           611
# W             71
# G            162
# Playoffs       0
# Name: 52, dtype: object)
# (53, Team         SEA
# League        AL
# Year        2011
# RS           556
# RA           675
# W             67
# G            162
# Playoffs       0
# Name: 53, dtype: object)
# (54, Team         SFG
# League        NL
# Year        2011
# RS           570
# RA           578
# W             86
# G            162
# Playoffs       0
# Name: 54, dtype: object)
# (55, Team         STL
# League        NL
# Year        2011
# RS           762
# RA           692
# W             90
# G            162
# Playoffs       1
# Name: 55, dtype: object)
# (56, Team         TBR
# League        AL
# Year        2011
# RS           707
# RA           614
# W             91
# G            162
# Playoffs       1
# Name: 56, dtype: object)
# (57, Team         TEX
# League        AL
# Year        2011
# RS           855
# RA           677
# W             96
# G            162
# Playoffs       1
# Name: 57, dtype: object)
# (58, Team         TOR
# League        AL
# Year        2011
# RS           743
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 58, dtype: object)
# (59, Team         WSN
# League        NL
# Year        2011
# RS           624
# RA           643
# W             80
# G            161
# Playoffs       0
# Name: 59, dtype: object)
# (60, Team         ARI
# League        NL
# Year        2010
# RS           713
# RA           836
# W             65
# G            162
# Playoffs       0
# Name: 60, dtype: object)
# (61, Team         ATL
# League        NL
# Year        2010
# RS           738
# RA           629
# W             91
# G            162
# Playoffs       1
# Name: 61, dtype: object)
# (62, Team         BAL
# League        AL
# Year        2010
# RS           613
# RA           785
# W             66
# G            162
# Playoffs       0
# Name: 62, dtype: object)
# (63, Team         BOS
# League        AL
# Year        2010
# RS           818
# RA           744
# W             89
# G            162
# Playoffs       0
# Name: 63, dtype: object)
# (64, Team         CHC
# League        NL
# Year        2010
# RS           685
# RA           767
# W             75
# G            162
# Playoffs       0
# Name: 64, dtype: object)
# (65, Team         CHW
# League        AL
# Year        2010
# RS           752
# RA           704
# W             88
# G            162
# Playoffs       0
# Name: 65, dtype: object)
# (66, Team         CIN
# League        NL
# Year        2010
# RS           790
# RA           685
# W             91
# G            162
# Playoffs       1
# Name: 66, dtype: object)
# (67, Team         CLE
# League        AL
# Year        2010
# RS           646
# RA           752
# W             69
# G            162
# Playoffs       0
# Name: 67, dtype: object)
# (68, Team         COL
# League        NL
# Year        2010
# RS           770
# RA           717
# W             83
# G            162
# Playoffs       0
# Name: 68, dtype: object)
# (69, Team         DET
# League        AL
# Year        2010
# RS           751
# RA           743
# W             81
# G            162
# Playoffs       0
# Name: 69, dtype: object)
# (70, Team         FLA
# League        NL
# Year        2010
# RS           719
# RA           717
# W             80
# G            162
# Playoffs       0
# Name: 70, dtype: object)
# (71, Team         HOU
# League        NL
# Year        2010
# RS           611
# RA           729
# W             76
# G            162
# Playoffs       0
# Name: 71, dtype: object)
# (72, Team         KCR
# League        AL
# Year        2010
# RS           676
# RA           845
# W             67
# G            162
# Playoffs       0
# Name: 72, dtype: object)
# (73, Team         LAA
# League        AL
# Year        2010
# RS           681
# RA           702
# W             80
# G            162
# Playoffs       0
# Name: 73, dtype: object)
# (74, Team         LAD
# League        NL
# Year        2010
# RS           667
# RA           692
# W             80
# G            162
# Playoffs       0
# Name: 74, dtype: object)
# (75, Team         MIL
# League        NL
# Year        2010
# RS           750
# RA           804
# W             77
# G            162
# Playoffs       0
# Name: 75, dtype: object)
# (76, Team         MIN
# League        AL
# Year        2010
# RS           781
# RA           671
# W             94
# G            162
# Playoffs       1
# Name: 76, dtype: object)
# (77, Team         NYM
# League        NL
# Year        2010
# RS           656
# RA           652
# W             79
# G            162
# Playoffs       0
# Name: 77, dtype: object)
# (78, Team         NYY
# League        AL
# Year        2010
# RS           859
# RA           693
# W             95
# G            162
# Playoffs       1
# Name: 78, dtype: object)
# (79, Team         OAK
# League        AL
# Year        2010
# RS           663
# RA           626
# W             81
# G            162
# Playoffs       0
# Name: 79, dtype: object)
# (80, Team         PHI
# League        NL
# Year        2010
# RS           772
# RA           640
# W             97
# G            162
# Playoffs       1
# Name: 80, dtype: object)
# (81, Team         PIT
# League        NL
# Year        2010
# RS           587
# RA           866
# W             57
# G            162
# Playoffs       0
# Name: 81, dtype: object)
# (82, Team         SDP
# League        NL
# Year        2010
# RS           665
# RA           581
# W             90
# G            162
# Playoffs       0
# Name: 82, dtype: object)
# (83, Team         SEA
# League        AL
# Year        2010
# RS           513
# RA           698
# W             61
# G            162
# Playoffs       0
# Name: 83, dtype: object)
# (84, Team         SFG
# League        NL
# Year        2010
# RS           697
# RA           583
# W             92
# G            162
# Playoffs       1
# Name: 84, dtype: object)
# (85, Team         STL
# League        NL
# Year        2010
# RS           736
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 85, dtype: object)
# (86, Team         TBR
# League        AL
# Year        2010
# RS           802
# RA           649
# W             96
# G            162
# Playoffs       1
# Name: 86, dtype: object)
# (87, Team         TEX
# League        AL
# Year        2010
# RS           787
# RA           687
# W             90
# G            162
# Playoffs       1
# Name: 87, dtype: object)
# (88, Team         TOR
# League        AL
# Year        2010
# RS           755
# RA           728
# W             85
# G            162
# Playoffs       0
# Name: 88, dtype: object)
# (89, Team         WSN
# League        NL
# Year        2010
# RS           655
# RA           742
# W             69
# G            162
# Playoffs       0
# Name: 89, dtype: object)
# (90, Team         ARI
# League        NL
# Year        2009
# RS           720
# RA           782
# W             70
# G            162
# Playoffs       0
# Name: 90, dtype: object)
# (91, Team         ATL
# League        NL
# Year        2009
# RS           735
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 91, dtype: object)
# (92, Team         BAL
# League        AL
# Year        2009
# RS           741
# RA           876
# W             64
# G            162
# Playoffs       0
# Name: 92, dtype: object)
# (93, Team         BOS
# League        AL
# Year        2009
# RS           872
# RA           736
# W             95
# G            162
# Playoffs       1
# Name: 93, dtype: object)
# (94, Team         CHC
# League        NL
# Year        2009
# RS           707
# RA           672
# W             83
# G            161
# Playoffs       0
# Name: 94, dtype: object)
# (95, Team         CHW
# League        AL
# Year        2009
# RS           724
# RA           732
# W             79
# G            162
# Playoffs       0
# Name: 95, dtype: object)
# (96, Team         CIN
# League        NL
# Year        2009
# RS           673
# RA           723
# W             78
# G            162
# Playoffs       0
# Name: 96, dtype: object)
# (97, Team         CLE
# League        AL
# Year        2009
# RS           773
# RA           865
# W             65
# G            162
# Playoffs       0
# Name: 97, dtype: object)
# (98, Team         COL
# League        NL
# Year        2009
# RS           804
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 98, dtype: object)
# (99, Team         DET
# League        AL
# Year        2009
# RS           743
# RA           745
# W             86
# G            163
# Playoffs       0
# Name: 99, dtype: object)
# (100, Team         FLA
# League        NL
# Year        2009
# RS           772
# RA           766
# W             87
# G            162
# Playoffs       0
# Name: 100, dtype: object)
# (101, Team         HOU
# League        NL
# Year        2009
# RS           643
# RA           770
# W             74
# G            162
# Playoffs       0
# Name: 101, dtype: object)
# (102, Team         KCR
# League        AL
# Year        2009
# RS           686
# RA           842
# W             65
# G            162
# Playoffs       0
# Name: 102, dtype: object)
# (103, Team         LAA
# League        AL
# Year        2009
# RS           883
# RA           761
# W             97
# G            162
# Playoffs       1
# Name: 103, dtype: object)
# (104, Team         LAD
# League        NL
# Year        2009
# RS           780
# RA           611
# W             95
# G            162
# Playoffs       1
# Name: 104, dtype: object)
# (105, Team         MIL
# League        NL
# Year        2009
# RS           785
# RA           818
# W             80
# G            162
# Playoffs       0
# Name: 105, dtype: object)
# (106, Team         MIN
# League        AL
# Year        2009
# RS           817
# RA           765
# W             87
# G            163
# Playoffs       1
# Name: 106, dtype: object)
# (107, Team         NYM
# League        NL
# Year        2009
# RS           671
# RA           757
# W             70
# G            162
# Playoffs       0
# Name: 107, dtype: object)
# (108, Team         NYY
# League        AL
# Year        2009
# RS           915
# RA           753
# W            103
# G            162
# Playoffs       1
# Name: 108, dtype: object)
# (109, Team         OAK
# League        AL
# Year        2009
# RS           759
# RA           761
# W             75
# G            162
# Playoffs       0
# Name: 109, dtype: object)
# (110, Team         PHI
# League        NL
# Year        2009
# RS           820
# RA           709
# W             93
# G            162
# Playoffs       1
# Name: 110, dtype: object)
# (111, Team         PIT
# League        NL
# Year        2009
# RS           636
# RA           768
# W             62
# G            161
# Playoffs       0
# Name: 111, dtype: object)
# (112, Team         SDP
# League        NL
# Year        2009
# RS           638
# RA           769
# W             75
# G            162
# Playoffs       0
# Name: 112, dtype: object)
# (113, Team         SEA
# League        AL
# Year        2009
# RS           640
# RA           692
# W             85
# G            162
# Playoffs       0
# Name: 113, dtype: object)
# (114, Team         SFG
# League        NL
# Year        2009
# RS           657
# RA           611
# W             88
# G            162
# Playoffs       0
# Name: 114, dtype: object)
# (115, Team         STL
# League        NL
# Year        2009
# RS           730
# RA           640
# W             91
# G            162
# Playoffs       1
# Name: 115, dtype: object)
# (116, Team         TBR
# League        AL
# Year        2009
# RS           803
# RA           754
# W             84
# G            162
# Playoffs       0
# Name: 116, dtype: object)
# (117, Team         TEX
# League        AL
# Year        2009
# RS           784
# RA           740
# W             87
# G            162
# Playoffs       0
# Name: 117, dtype: object)
# (118, Team         TOR
# League        AL
# Year        2009
# RS           798
# RA           771
# W             75
# G            162
# Playoffs       0
# Name: 118, dtype: object)
# (119, Team         WSN
# League        NL
# Year        2009
# RS           710
# RA           874
# W             59
# G            162
# Playoffs       0
# Name: 119, dtype: object)
# (120, Team         ARI
# League        NL
# Year        2008
# RS           720
# RA           706
# W             82
# G            162
# Playoffs       0
# Name: 120, dtype: object)
# (121, Team         ATL
# League        NL
# Year        2008
# RS           753
# RA           778
# W             72
# G            162
# Playoffs       0
# Name: 121, dtype: object)
# (122, Team         BAL
# League        AL
# Year        2008
# RS           782
# RA           869
# W             68
# G            161
# Playoffs       0
# Name: 122, dtype: object)
# (123, Team         BOS
# League        AL
# Year        2008
# RS           845
# RA           694
# W             95
# G            162
# Playoffs       1
# Name: 123, dtype: object)
# (124, Team         CHC
# League        NL
# Year        2008
# RS           855
# RA           671
# W             97
# G            161
# Playoffs       1
# Name: 124, dtype: object)
# (125, Team         CHW
# League        AL
# Year        2008
# RS           811
# RA           729
# W             89
# G            163
# Playoffs       1
# Name: 125, dtype: object)
# (126, Team         CIN
# League        NL
# Year        2008
# RS           704
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 126, dtype: object)
# (127, Team         CLE
# League        AL
# Year        2008
# RS           805
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 127, dtype: object)
# (128, Team         COL
# League        NL
# Year        2008
# RS           747
# RA           822
# W             74
# G            162
# Playoffs       0
# Name: 128, dtype: object)
# (129, Team         DET
# League        AL
# Year        2008
# RS           821
# RA           857
# W             74
# G            162
# Playoffs       0
# Name: 129, dtype: object)
# (130, Team         FLA
# League        NL
# Year        2008
# RS           770
# RA           767
# W             84
# G            161
# Playoffs       0
# Name: 130, dtype: object)
# (131, Team         HOU
# League        NL
# Year        2008
# RS           712
# RA           743
# W             86
# G            161
# Playoffs       0
# Name: 131, dtype: object)
# (132, Team         KCR
# League        AL
# Year        2008
# RS           691
# RA           781
# W             75
# G            162
# Playoffs       0
# Name: 132, dtype: object)
# (133, Team         LAA
# League        AL
# Year        2008
# RS           765
# RA           697
# W            100
# G            162
# Playoffs       1
# Name: 133, dtype: object)
# (134, Team         LAD
# League        NL
# Year        2008
# RS           700
# RA           648
# W             84
# G            162
# Playoffs       1
# Name: 134, dtype: object)
# (135, Team         MIL
# League        NL
# Year        2008
# RS           750
# RA           689
# W             90
# G            162
# Playoffs       1
# Name: 135, dtype: object)
# (136, Team         MIN
# League        AL
# Year        2008
# RS           829
# RA           745
# W             88
# G            163
# Playoffs       0
# Name: 136, dtype: object)
# (137, Team         NYM
# League        NL
# Year        2008
# RS           799
# RA           715
# W             89
# G            162
# Playoffs       0
# Name: 137, dtype: object)
# (138, Team         NYY
# League        AL
# Year        2008
# RS           789
# RA           727
# W             89
# G            162
# Playoffs       0
# Name: 138, dtype: object)
# (139, Team         OAK
# League        AL
# Year        2008
# RS           646
# RA           690
# W             75
# G            161
# Playoffs       0
# Name: 139, dtype: object)
# (140, Team         PHI
# League        NL
# Year        2008
# RS           799
# RA           680
# W             92
# G            162
# Playoffs       1
# Name: 140, dtype: object)
# (141, Team         PIT
# League        NL
# Year        2008
# RS           735
# RA           884
# W             67
# G            162
# Playoffs       0
# Name: 141, dtype: object)
# (142, Team         SDP
# League        NL
# Year        2008
# RS           637
# RA           764
# W             63
# G            162
# Playoffs       0
# Name: 142, dtype: object)
# (143, Team         SEA
# League        AL
# Year        2008
# RS           671
# RA           811
# W             61
# G            162
# Playoffs       0
# Name: 143, dtype: object)
# (144, Team         SFG
# League        NL
# Year        2008
# RS           640
# RA           759
# W             72
# G            162
# Playoffs       0
# Name: 144, dtype: object)
# (145, Team         STL
# League        NL
# Year        2008
# RS           779
# RA           725
# W             86
# G            162
# Playoffs       0
# Name: 145, dtype: object)
# (146, Team         TBR
# League        AL
# Year        2008
# RS           774
# RA           671
# W             97
# G            162
# Playoffs       1
# Name: 146, dtype: object)
# (147, Team         TEX
# League        AL
# Year        2008
# RS           901
# RA           967
# W             79
# G            162
# Playoffs       0
# Name: 147, dtype: object)
# (148, Team         TOR
# League        AL
# Year        2008
# RS           714
# RA           610
# W             86
# G            162
# Playoffs       0
# Name: 148, dtype: object)
# (149, Team         WSN
# League        NL
# Year        2008
# RS           641
# RA           825
# W             59
# G            161
# Playoffs       0
# Name: 149, dtype: object)
# (150, Team         ARI
# League        NL
# Year        2007
# RS           712
# RA           732
# W             90
# G            162
# Playoffs       1
# Name: 150, dtype: object)
# (151, Team         ATL
# League        NL
# Year        2007
# RS           810
# RA           733
# W             84
# G            162
# Playoffs       0
# Name: 151, dtype: object)
# (152, Team         BAL
# League        AL
# Year        2007
# RS           756
# RA           868
# W             69
# G            162
# Playoffs       0
# Name: 152, dtype: object)
# (153, Team         BOS
# League        AL
# Year        2007
# RS           867
# RA           657
# W             96
# G            162
# Playoffs       1
# Name: 153, dtype: object)
# (154, Team         CHC
# League        NL
# Year        2007
# RS           752
# RA           690
# W             85
# G            162
# Playoffs       1
# Name: 154, dtype: object)
# (155, Team         CHW
# League        AL
# Year        2007
# RS           693
# RA           839
# W             72
# G            162
# Playoffs       0
# Name: 155, dtype: object)
# (156, Team         CIN
# League        NL
# Year        2007
# RS           783
# RA           853
# W             72
# G            162
# Playoffs       0
# Name: 156, dtype: object)
# (157, Team         CLE
# League        AL
# Year        2007
# RS           811
# RA           704
# W             96
# G            162
# Playoffs       1
# Name: 157, dtype: object)
# (158, Team         COL
# League        NL
# Year        2007
# RS           860
# RA           758
# W             90
# G            163
# Playoffs       1
# Name: 158, dtype: object)
# (159, Team         DET
# League        AL
# Year        2007
# RS           887
# RA           797
# W             88
# G            162
# Playoffs       0
# Name: 159, dtype: object)
# (160, Team         FLA
# League        NL
# Year        2007
# RS           790
# RA           891
# W             71
# G            162
# Playoffs       0
# Name: 160, dtype: object)
# (161, Team         HOU
# League        NL
# Year        2007
# RS           723
# RA           813
# W             73
# G            162
# Playoffs       0
# Name: 161, dtype: object)
# (162, Team         KCR
# League        AL
# Year        2007
# RS           706
# RA           778
# W             69
# G            162
# Playoffs       0
# Name: 162, dtype: object)
# (163, Team         LAA
# League        AL
# Year        2007
# RS           822
# RA           731
# W             94
# G            162
# Playoffs       1
# Name: 163, dtype: object)
# (164, Team         LAD
# League        NL
# Year        2007
# RS           735
# RA           727
# W             82
# G            162
# Playoffs       0
# Name: 164, dtype: object)
# (165, Team         MIL
# League        NL
# Year        2007
# RS           801
# RA           776
# W             83
# G            162
# Playoffs       0
# Name: 165, dtype: object)
# (166, Team         MIN
# League        AL
# Year        2007
# RS           718
# RA           725
# W             79
# G            162
# Playoffs       0
# Name: 166, dtype: object)
# (167, Team         NYM
# League        NL
# Year        2007
# RS           804
# RA           750
# W             88
# G            162
# Playoffs       0
# Name: 167, dtype: object)
# (168, Team         NYY
# League        AL
# Year        2007
# RS           968
# RA           777
# W             94
# G            162
# Playoffs       1
# Name: 168, dtype: object)
# (169, Team         OAK
# League        AL
# Year        2007
# RS           741
# RA           758
# W             76
# G            162
# Playoffs       0
# Name: 169, dtype: object)
# (170, Team         PHI
# League        NL
# Year        2007
# RS           892
# RA           821
# W             89
# G            162
# Playoffs       1
# Name: 170, dtype: object)
# (171, Team         PIT
# League        NL
# Year        2007
# RS           724
# RA           846
# W             68
# G            162
# Playoffs       0
# Name: 171, dtype: object)
# (172, Team         SDP
# League        NL
# Year        2007
# RS           741
# RA           666
# W             89
# G            163
# Playoffs       0
# Name: 172, dtype: object)
# (173, Team         SEA
# League        AL
# Year        2007
# RS           794
# RA           813
# W             88
# G            162
# Playoffs       0
# Name: 173, dtype: object)
# (174, Team         SFG
# League        NL
# Year        2007
# RS           683
# RA           720
# W             71
# G            162
# Playoffs       0
# Name: 174, dtype: object)
# (175, Team         STL
# League        NL
# Year        2007
# RS           725
# RA           829
# W             78
# G            162
# Playoffs       0
# Name: 175, dtype: object)
# (176, Team         TBD
# League        AL
# Year        2007
# RS           782
# RA           944
# W             66
# G            162
# Playoffs       0
# Name: 176, dtype: object)
# (177, Team         TEX
# League        AL
# Year        2007
# RS           816
# RA           844
# W             75
# G            162
# Playoffs       0
# Name: 177, dtype: object)
# (178, Team         TOR
# League        AL
# Year        2007
# RS           753
# RA           699
# W             83
# G            162
# Playoffs       0
# Name: 178, dtype: object)
# (179, Team         WSN
# League        NL
# Year        2007
# RS           673
# RA           783
# W             73
# G            162
# Playoffs       0
# Name: 179, dtype: object)
# (180, Team         ARI
# League        NL
# Year        2006
# RS           773
# RA           788
# W             76
# G            162
# Playoffs       0
# Name: 180, dtype: object)
# (181, Team         ATL
# League        NL
# Year        2006
# RS           849
# RA           805
# W             79
# G            162
# Playoffs       0
# Name: 181, dtype: object)
# (182, Team         BAL
# League        AL
# Year        2006
# RS           768
# RA           899
# W             70
# G            162
# Playoffs       0
# Name: 182, dtype: object)
# (183, Team         BOS
# League        AL
# Year        2006
# RS           820
# RA           825
# W             86
# G            162
# Playoffs       0
# Name: 183, dtype: object)
# (184, Team         CHC
# League        NL
# Year        2006
# RS           716
# RA           834
# W             66
# G            162
# Playoffs       0
# Name: 184, dtype: object)
# (185, Team         CHW
# League        AL
# Year        2006
# RS           868
# RA           794
# W             90
# G            162
# Playoffs       0
# Name: 185, dtype: object)
# (186, Team         CIN
# League        NL
# Year        2006
# RS           749
# RA           801
# W             80
# G            162
# Playoffs       0
# Name: 186, dtype: object)
# (187, Team         CLE
# League        AL
# Year        2006
# RS           870
# RA           782
# W             78
# G            162
# Playoffs       0
# Name: 187, dtype: object)
# (188, Team         COL
# League        NL
# Year        2006
# RS           813
# RA           812
# W             76
# G            162
# Playoffs       0
# Name: 188, dtype: object)
# (189, Team         DET
# League        AL
# Year        2006
# RS           822
# RA           675
# W             95
# G            162
# Playoffs       1
# Name: 189, dtype: object)
# (190, Team         FLA
# League        NL
# Year        2006
# RS           758
# RA           772
# W             78
# G            162
# Playoffs       0
# Name: 190, dtype: object)
# (191, Team         HOU
# League        NL
# Year        2006
# RS           735
# RA           719
# W             82
# G            162
# Playoffs       0
# Name: 191, dtype: object)
# (192, Team         KCR
# League        AL
# Year        2006
# RS           757
# RA           971
# W             62
# G            162
# Playoffs       0
# Name: 192, dtype: object)
# (193, Team         LAA
# League        AL
# Year        2006
# RS           766
# RA           732
# W             89
# G            162
# Playoffs       0
# Name: 193, dtype: object)
# (194, Team         LAD
# League        NL
# Year        2006
# RS           820
# RA           751
# W             88
# G            162
# Playoffs       1
# Name: 194, dtype: object)
# (195, Team         MIL
# League        NL
# Year        2006
# RS           730
# RA           833
# W             75
# G            162
# Playoffs       0
# Name: 195, dtype: object)
# (196, Team         MIN
# League        AL
# Year        2006
# RS           801
# RA           683
# W             96
# G            162
# Playoffs       1
# Name: 196, dtype: object)
# (197, Team         NYM
# League        NL
# Year        2006
# RS           834
# RA           731
# W             97
# G            162
# Playoffs       1
# Name: 197, dtype: object)
# (198, Team         NYY
# League        AL
# Year        2006
# RS           930
# RA           767
# W             97
# G            162
# Playoffs       1
# Name: 198, dtype: object)
# (199, Team         OAK
# League        AL
# Year        2006
# RS           771
# RA           727
# W             93
# G            162
# Playoffs       1
# Name: 199, dtype: object)
# (200, Team         PHI
# League        NL
# Year        2006
# RS           865
# RA           812
# W             85
# G            162
# Playoffs       0
# Name: 200, dtype: object)
# (201, Team         PIT
# League        NL
# Year        2006
# RS           691
# RA           797
# W             67
# G            162
# Playoffs       0
# Name: 201, dtype: object)
# (202, Team         SDP
# League        NL
# Year        2006
# RS           731
# RA           679
# W             88
# G            162
# Playoffs       1
# Name: 202, dtype: object)
# (203, Team         SEA
# League        AL
# Year        2006
# RS           756
# RA           792
# W             78
# G            162
# Playoffs       0
# Name: 203, dtype: object)
# (204, Team         SFG
# League        NL
# Year        2006
# RS           746
# RA           790
# W             76
# G            161
# Playoffs       0
# Name: 204, dtype: object)
# (205, Team         STL
# League        NL
# Year        2006
# RS           781
# RA           762
# W             83
# G            161
# Playoffs       1
# Name: 205, dtype: object)
# (206, Team         TBD
# League        AL
# Year        2006
# RS           689
# RA           856
# W             61
# G            162
# Playoffs       0
# Name: 206, dtype: object)
# (207, Team         TEX
# League        AL
# Year        2006
# RS           835
# RA           784
# W             80
# G            162
# Playoffs       0
# Name: 207, dtype: object)
# (208, Team         TOR
# League        AL
# Year        2006
# RS           809
# RA           754
# W             87
# G            162
# Playoffs       0
# Name: 208, dtype: object)
# (209, Team         WSN
# League        NL
# Year        2006
# RS           746
# RA           872
# W             71
# G            162
# Playoffs       0
# Name: 209, dtype: object)
# (210, Team         ARI
# League        NL
# Year        2005
# RS           696
# RA           856
# W             77
# G            162
# Playoffs       0
# Name: 210, dtype: object)
# (211, Team         ATL
# League        NL
# Year        2005
# RS           769
# RA           674
# W             90
# G            162
# Playoffs       1
# Name: 211, dtype: object)
# (212, Team         BAL
# League        AL
# Year        2005
# RS           729
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 212, dtype: object)
# (213, Team         BOS
# League        AL
# Year        2005
# RS           910
# RA           805
# W             95
# G            162
# Playoffs       1
# Name: 213, dtype: object)
# (214, Team         CHC
# League        NL
# Year        2005
# RS           703
# RA           714
# W             79
# G            162
# Playoffs       0
# Name: 214, dtype: object)
# (215, Team         CHW
# League        AL
# Year        2005
# RS           741
# RA           645
# W             99
# G            162
# Playoffs       1
# Name: 215, dtype: object)
# (216, Team         CIN
# League        NL
# Year        2005
# RS           820
# RA           889
# W             73
# G            163
# Playoffs       0
# Name: 216, dtype: object)
# (217, Team         CLE
# League        AL
# Year        2005
# RS           790
# RA           642
# W             93
# G            162
# Playoffs       0
# Name: 217, dtype: object)
# (218, Team         COL
# League        NL
# Year        2005
# RS           740
# RA           862
# W             67
# G            162
# Playoffs       0
# Name: 218, dtype: object)
# (219, Team         DET
# League        AL
# Year        2005
# RS           723
# RA           787
# W             71
# G            162
# Playoffs       0
# Name: 219, dtype: object)
# (220, Team         FLA
# League        NL
# Year        2005
# RS           717
# RA           732
# W             83
# G            162
# Playoffs       0
# Name: 220, dtype: object)
# (221, Team         HOU
# League        NL
# Year        2005
# RS           693
# RA           609
# W             89
# G            163
# Playoffs       1
# Name: 221, dtype: object)
# (222, Team         KCR
# League        AL
# Year        2005
# RS           701
# RA           935
# W             56
# G            162
# Playoffs       0
# Name: 222, dtype: object)
# (223, Team         LAA
# League        AL
# Year        2005
# RS           761
# RA           643
# W             95
# G            162
# Playoffs       1
# Name: 223, dtype: object)
# (224, Team         LAD
# League        NL
# Year        2005
# RS           685
# RA           755
# W             71
# G            162
# Playoffs       0
# Name: 224, dtype: object)
# (225, Team         MIL
# League        NL
# Year        2005
# RS           726
# RA           697
# W             81
# G            162
# Playoffs       0
# Name: 225, dtype: object)
# (226, Team         MIN
# League        AL
# Year        2005
# RS           688
# RA           662
# W             83
# G            162
# Playoffs       0
# Name: 226, dtype: object)
# (227, Team         NYM
# League        NL
# Year        2005
# RS           722
# RA           648
# W             83
# G            162
# Playoffs       0
# Name: 227, dtype: object)
# (228, Team         NYY
# League        AL
# Year        2005
# RS           886
# RA           789
# W             95
# G            162
# Playoffs       1
# Name: 228, dtype: object)
# (229, Team         OAK
# League        AL
# Year        2005
# RS           772
# RA           658
# W             88
# G            162
# Playoffs       0
# Name: 229, dtype: object)
# (230, Team         PHI
# League        NL
# Year        2005
# RS           807
# RA           726
# W             88
# G            162
# Playoffs       0
# Name: 230, dtype: object)
# (231, Team         PIT
# League        NL
# Year        2005
# RS           680
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 231, dtype: object)
# (232, Team         SDP
# League        NL
# Year        2005
# RS           684
# RA           726
# W             82
# G            162
# Playoffs       1
# Name: 232, dtype: object)
# (233, Team         SEA
# League        AL
# Year        2005
# RS           699
# RA           751
# W             69
# G            162
# Playoffs       0
# Name: 233, dtype: object)
# (234, Team         SFG
# League        NL
# Year        2005
# RS           649
# RA           745
# W             75
# G            162
# Playoffs       0
# Name: 234, dtype: object)
# (235, Team         STL
# League        NL
# Year        2005
# RS           805
# RA           634
# W            100
# G            162
# Playoffs       1
# Name: 235, dtype: object)
# (236, Team         TBD
# League        AL
# Year        2005
# RS           750
# RA           936
# W             67
# G            162
# Playoffs       0
# Name: 236, dtype: object)
# (237, Team         TEX
# League        AL
# Year        2005
# RS           865
# RA           858
# W             79
# G            162
# Playoffs       0
# Name: 237, dtype: object)
# (238, Team         TOR
# League        AL
# Year        2005
# RS           775
# RA           705
# W             80
# G            162
# Playoffs       0
# Name: 238, dtype: object)
# (239, Team         WSN
# League        NL
# Year        2005
# RS           639
# RA           673
# W             81
# G            162
# Playoffs       0
# Name: 239, dtype: object)
# (240, Team         ANA
# League        AL
# Year        2004
# RS           836
# RA           734
# W             92
# G            162
# Playoffs       1
# Name: 240, dtype: object)
# (241, Team         ARI
# League        NL
# Year        2004
# RS           615
# RA           899
# W             51
# G            162
# Playoffs       0
# Name: 241, dtype: object)
# (242, Team         ATL
# League        NL
# Year        2004
# RS           803
# RA           668
# W             96
# G            162
# Playoffs       1
# Name: 242, dtype: object)
# (243, Team         BAL
# League        AL
# Year        2004
# RS           842
# RA           830
# W             78
# G            162
# Playoffs       0
# Name: 243, dtype: object)
# (244, Team         BOS
# League        AL
# Year        2004
# RS           949
# RA           768
# W             98
# G            162
# Playoffs       1
# Name: 244, dtype: object)
# (245, Team         CHC
# League        NL
# Year        2004
# RS           789
# RA           665
# W             89
# G            162
# Playoffs       0
# Name: 245, dtype: object)
# (246, Team         CHW
# League        AL
# Year        2004
# RS           865
# RA           831
# W             83
# G            162
# Playoffs       0
# Name: 246, dtype: object)
# (247, Team         CIN
# League        NL
# Year        2004
# RS           750
# RA           907
# W             76
# G            162
# Playoffs       0
# Name: 247, dtype: object)
# (248, Team         CLE
# League        AL
# Year        2004
# RS           858
# RA           857
# W             80
# G            162
# Playoffs       0
# Name: 248, dtype: object)
# (249, Team         COL
# League        NL
# Year        2004
# RS           833
# RA           923
# W             68
# G            162
# Playoffs       0
# Name: 249, dtype: object)
# (250, Team         DET
# League        AL
# Year        2004
# RS           827
# RA           844
# W             72
# G            162
# Playoffs       0
# Name: 250, dtype: object)
# (251, Team         FLA
# League        NL
# Year        2004
# RS           718
# RA           700
# W             83
# G            162
# Playoffs       0
# Name: 251, dtype: object)
# (252, Team         HOU
# League        NL
# Year        2004
# RS           803
# RA           698
# W             92
# G            162
# Playoffs       1
# Name: 252, dtype: object)
# (253, Team         KCR
# League        AL
# Year        2004
# RS           720
# RA           905
# W             58
# G            162
# Playoffs       0
# Name: 253, dtype: object)
# (254, Team         LAD
# League        NL
# Year        2004
# RS           761
# RA           684
# W             93
# G            162
# Playoffs       1
# Name: 254, dtype: object)
# (255, Team         MIL
# League        NL
# Year        2004
# RS           634
# RA           757
# W             67
# G            161
# Playoffs       0
# Name: 255, dtype: object)
# (256, Team         MIN
# League        AL
# Year        2004
# RS           780
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 256, dtype: object)
# (257, Team         MON
# League        NL
# Year        2004
# RS           635
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 257, dtype: object)
# (258, Team         NYM
# League        NL
# Year        2004
# RS           684
# RA           731
# W             71
# G            162
# Playoffs       0
# Name: 258, dtype: object)
# (259, Team         NYY
# League        AL
# Year        2004
# RS           897
# RA           808
# W            101
# G            162
# Playoffs       1
# Name: 259, dtype: object)
# (260, Team         OAK
# League        AL
# Year        2004
# RS           793
# RA           742
# W             91
# G            162
# Playoffs       0
# Name: 260, dtype: object)
# (261, Team         PHI
# League        NL
# Year        2004
# RS           840
# RA           781
# W             86
# G            162
# Playoffs       0
# Name: 261, dtype: object)
# (262, Team         PIT
# League        NL
# Year        2004
# RS           680
# RA           744
# W             72
# G            161
# Playoffs       0
# Name: 262, dtype: object)
# (263, Team         SDP
# League        NL
# Year        2004
# RS           768
# RA           705
# W             87
# G            162
# Playoffs       0
# Name: 263, dtype: object)
# (264, Team         SEA
# League        AL
# Year        2004
# RS           698
# RA           823
# W             63
# G            162
# Playoffs       0
# Name: 264, dtype: object)
# (265, Team         SFG
# League        NL
# Year        2004
# RS           850
# RA           770
# W             91
# G            162
# Playoffs       0
# Name: 265, dtype: object)
# (266, Team         STL
# League        NL
# Year        2004
# RS           855
# RA           659
# W            105
# G            162
# Playoffs       1
# Name: 266, dtype: object)
# (267, Team         TBD
# League        AL
# Year        2004
# RS           714
# RA           842
# W             70
# G            161
# Playoffs       0
# Name: 267, dtype: object)
# (268, Team         TEX
# League        AL
# Year        2004
# RS           860
# RA           794
# W             89
# G            162
# Playoffs       0
# Name: 268, dtype: object)
# (269, Team         TOR
# League        AL
# Year        2004
# RS           719
# RA           823
# W             67
# G            161
# Playoffs       0
# Name: 269, dtype: object)
# (270, Team         ANA
# League        AL
# Year        2003
# RS           736
# RA           743
# W             77
# G            162
# Playoffs       0
# Name: 270, dtype: object)
# (271, Team         ARI
# League        NL
# Year        2003
# RS           717
# RA           685
# W             84
# G            162
# Playoffs       0
# Name: 271, dtype: object)
# (272, Team         ATL
# League        NL
# Year        2003
# RS           907
# RA           740
# W            101
# G            162
# Playoffs       1
# Name: 272, dtype: object)
# (273, Team         BAL
# League        AL
# Year        2003
# RS           743
# RA           820
# W             71
# G            163
# Playoffs       0
# Name: 273, dtype: object)
# (274, Team         BOS
# League        AL
# Year        2003
# RS           961
# RA           809
# W             95
# G            162
# Playoffs       1
# Name: 274, dtype: object)
# (275, Team         CHC
# League        NL
# Year        2003
# RS           724
# RA           683
# W             88
# G            162
# Playoffs       1
# Name: 275, dtype: object)
# (276, Team         CHW
# League        AL
# Year        2003
# RS           791
# RA           715
# W             86
# G            162
# Playoffs       0
# Name: 276, dtype: object)
# (277, Team         CIN
# League        NL
# Year        2003
# RS           694
# RA           886
# W             69
# G            162
# Playoffs       0
# Name: 277, dtype: object)
# (278, Team         CLE
# League        AL
# Year        2003
# RS           699
# RA           778
# W             68
# G            162
# Playoffs       0
# Name: 278, dtype: object)
# (279, Team         COL
# League        NL
# Year        2003
# RS           853
# RA           892
# W             74
# G            162
# Playoffs       0
# Name: 279, dtype: object)
# (280, Team         DET
# League        AL
# Year        2003
# RS           591
# RA           928
# W             43
# G            162
# Playoffs       0
# Name: 280, dtype: object)
# (281, Team         FLA
# League        NL
# Year        2003
# RS           751
# RA           692
# W             91
# G            162
# Playoffs       1
# Name: 281, dtype: object)
# (282, Team         HOU
# League        NL
# Year        2003
# RS           805
# RA           677
# W             87
# G            162
# Playoffs       0
# Name: 282, dtype: object)
# (283, Team         KCR
# League        AL
# Year        2003
# RS           836
# RA           867
# W             83
# G            162
# Playoffs       0
# Name: 283, dtype: object)
# (284, Team         LAD
# League        NL
# Year        2003
# RS           574
# RA           556
# W             85
# G            162
# Playoffs       0
# Name: 284, dtype: object)
# (285, Team         MIL
# League        NL
# Year        2003
# RS           714
# RA           873
# W             68
# G            162
# Playoffs       0
# Name: 285, dtype: object)
# (286, Team         MIN
# League        AL
# Year        2003
# RS           801
# RA           758
# W             90
# G            162
# Playoffs       1
# Name: 286, dtype: object)
# ...
# (1138, Team         CIN
# League        NL
# Year        1966
# RS           692
# RA           702
# W             76
# G            160
# Playoffs       0
# Name: 1138, dtype: object)
# (1139, Team         CLE
# League        AL
# Year        1966
# RS           574
# RA           586
# W             81
# G            162
# Playoffs       0
# Name: 1139, dtype: object)
# (1140, Team         DET
# League        AL
# Year        1966
# RS           719
# RA           698
# W             88
# G            162
# Playoffs       0
# Name: 1140, dtype: object)
# (1141, Team         HOU
# League        NL
# Year        1966
# RS           612
# RA           695
# W             72
# G            163
# Playoffs       0
# Name: 1141, dtype: object)
# (1142, Team         KCA
# League        AL
# Year        1966
# RS           564
# RA           648
# W             74
# G            160
# Playoffs       0
# Name: 1142, dtype: object)
# (1143, Team         LAD
# League        NL
# Year        1966
# RS           606
# RA           490
# W             95
# G            162
# Playoffs       1
# Name: 1143, dtype: object)
# (1144, Team         MIN
# League        AL
# Year        1966
# RS           663
# RA           581
# W             89
# G            162
# Playoffs       0
# Name: 1144, dtype: object)
# (1145, Team         NYM
# League        NL
# Year        1966
# RS           587
# RA           761
# W             66
# G            161
# Playoffs       0
# Name: 1145, dtype: object)
# (1146, Team         NYY
# League        AL
# Year        1966
# RS           611
# RA           612
# W             70
# G            160
# Playoffs       0
# Name: 1146, dtype: object)
# (1147, Team         PHI
# League        NL
# Year        1966
# RS           696
# RA           640
# W             87
# G            162
# Playoffs       0
# Name: 1147, dtype: object)
# (1148, Team         PIT
# League        NL
# Year        1966
# RS           759
# RA           641
# W             92
# G            162
# Playoffs       0
# Name: 1148, dtype: object)
# (1149, Team         SFG
# League        NL
# Year        1966
# RS           675
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1149, dtype: object)
# (1150, Team         STL
# League        NL
# Year        1966
# RS           571
# RA           577
# W             83
# G            162
# Playoffs       0
# Name: 1150, dtype: object)
# (1151, Team         WSA
# League        AL
# Year        1966
# RS           557
# RA           659
# W             71
# G            159
# Playoffs       0
# Name: 1151, dtype: object)
# (1152, Team         BAL
# League        AL
# Year        1965
# RS           641
# RA           578
# W             94
# G            162
# Playoffs       0
# Name: 1152, dtype: object)
# (1153, Team         BOS
# League        AL
# Year        1965
# RS           669
# RA           791
# W             62
# G            162
# Playoffs       0
# Name: 1153, dtype: object)
# (1154, Team         CAL
# League        AL
# Year        1965
# RS           527
# RA           569
# W             75
# G            162
# Playoffs       0
# Name: 1154, dtype: object)
# (1155, Team         CHC
# League        NL
# Year        1965
# RS           635
# RA           723
# W             72
# G            164
# Playoffs       0
# Name: 1155, dtype: object)
# (1156, Team         CHW
# League        AL
# Year        1965
# RS           647
# RA           555
# W             95
# G            162
# Playoffs       0
# Name: 1156, dtype: object)
# (1157, Team         CIN
# League        NL
# Year        1965
# RS           825
# RA           704
# W             89
# G            162
# Playoffs       0
# Name: 1157, dtype: object)
# (1158, Team         CLE
# League        AL
# Year        1965
# RS           663
# RA           613
# W             87
# G            162
# Playoffs       0
# Name: 1158, dtype: object)
# (1159, Team         DET
# League        AL
# Year        1965
# RS           680
# RA           602
# W             89
# G            162
# Playoffs       0
# Name: 1159, dtype: object)
# (1160, Team         HOU
# League        NL
# Year        1965
# RS           569
# RA           711
# W             65
# G            162
# Playoffs       0
# Name: 1160, dtype: object)
# (1161, Team         KCA
# League        AL
# Year        1965
# RS           585
# RA           755
# W             59
# G            162
# Playoffs       0
# Name: 1161, dtype: object)
# (1162, Team         LAD
# League        NL
# Year        1965
# RS           608
# RA           521
# W             97
# G            162
# Playoffs       1
# Name: 1162, dtype: object)
# (1163, Team         MIN
# League        AL
# Year        1965
# RS           774
# RA           600
# W            102
# G            162
# Playoffs       1
# Name: 1163, dtype: object)
# (1164, Team         MLN
# League        NL
# Year        1965
# RS           708
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 1164, dtype: object)
# (1165, Team         NYM
# League        NL
# Year        1965
# RS           495
# RA           752
# W             50
# G            164
# Playoffs       0
# Name: 1165, dtype: object)
# (1166, Team         NYY
# League        AL
# Year        1965
# RS           611
# RA           604
# W             77
# G            162
# Playoffs       0
# Name: 1166, dtype: object)
# (1167, Team         PHI
# League        NL
# Year        1965
# RS           654
# RA           667
# W             85
# G            162
# Playoffs       0
# Name: 1167, dtype: object)
# (1168, Team         PIT
# League        NL
# Year        1965
# RS           675
# RA           580
# W             90
# G            163
# Playoffs       0
# Name: 1168, dtype: object)
# (1169, Team         SFG
# League        NL
# Year        1965
# RS           682
# RA           593
# W             95
# G            163
# Playoffs       0
# Name: 1169, dtype: object)
# (1170, Team         STL
# League        NL
# Year        1965
# RS           707
# RA           674
# W             80
# G            162
# Playoffs       0
# Name: 1170, dtype: object)
# (1171, Team         WSA
# League        AL
# Year        1965
# RS           591
# RA           721
# W             70
# G            162
# Playoffs       0
# Name: 1171, dtype: object)
# (1172, Team         BAL
# League        AL
# Year        1964
# RS           679
# RA           567
# W             97
# G            163
# Playoffs       0
# Name: 1172, dtype: object)
# (1173, Team         BOS
# League        AL
# Year        1964
# RS           688
# RA           793
# W             72
# G            162
# Playoffs       0
# Name: 1173, dtype: object)
# (1174, Team         CHC
# League        NL
# Year        1964
# RS           649
# RA           724
# W             76
# G            162
# Playoffs       0
# Name: 1174, dtype: object)
# (1175, Team         CHW
# League        AL
# Year        1964
# RS           642
# RA           501
# W             98
# G            162
# Playoffs       0
# Name: 1175, dtype: object)
# (1176, Team         CIN
# League        NL
# Year        1964
# RS           660
# RA           566
# W             92
# G            163
# Playoffs       0
# Name: 1176, dtype: object)
# (1177, Team         CLE
# League        AL
# Year        1964
# RS           689
# RA           693
# W             79
# G            164
# Playoffs       0
# Name: 1177, dtype: object)
# (1178, Team         DET
# League        AL
# Year        1964
# RS           699
# RA           678
# W             85
# G            163
# Playoffs       0
# Name: 1178, dtype: object)
# (1179, Team         HOU
# League        NL
# Year        1964
# RS           495
# RA           628
# W             66
# G            162
# Playoffs       0
# Name: 1179, dtype: object)
# (1180, Team         KCA
# League        AL
# Year        1964
# RS           621
# RA           836
# W             57
# G            163
# Playoffs       0
# Name: 1180, dtype: object)
# (1181, Team         LAA
# League        AL
# Year        1964
# RS           544
# RA           551
# W             82
# G            162
# Playoffs       0
# Name: 1181, dtype: object)
# (1182, Team         LAD
# League        NL
# Year        1964
# RS           614
# RA           572
# W             80
# G            164
# Playoffs       0
# Name: 1182, dtype: object)
# (1183, Team         MIN
# League        AL
# Year        1964
# RS           737
# RA           678
# W             79
# G            163
# Playoffs       0
# Name: 1183, dtype: object)
# (1184, Team         MLN
# League        NL
# Year        1964
# RS           803
# RA           744
# W             88
# G            162
# Playoffs       0
# Name: 1184, dtype: object)
# (1185, Team         NYM
# League        NL
# Year        1964
# RS           569
# RA           776
# W             53
# G            163
# Playoffs       0
# Name: 1185, dtype: object)
# (1186, Team         NYY
# League        AL
# Year        1964
# RS           730
# RA           577
# W             99
# G            164
# Playoffs       1
# Name: 1186, dtype: object)
# (1187, Team         PHI
# League        NL
# Year        1964
# RS           693
# RA           632
# W             92
# G            162
# Playoffs       0
# Name: 1187, dtype: object)
# (1188, Team         PIT
# League        NL
# Year        1964
# RS           663
# RA           636
# W             80
# G            162
# Playoffs       0
# Name: 1188, dtype: object)
# (1189, Team         SFG
# League        NL
# Year        1964
# RS           656
# RA           587
# W             90
# G            162
# Playoffs       0
# Name: 1189, dtype: object)
# (1190, Team         STL
# League        NL
# Year        1964
# RS           715
# RA           652
# W             93
# G            162
# Playoffs       1
# Name: 1190, dtype: object)
# (1191, Team         WSA
# League        AL
# Year        1964
# RS           578
# RA           733
# W             62
# G            162
# Playoffs       0
# Name: 1191, dtype: object)
# (1192, Team         BAL
# League        AL
# Year        1963
# RS           644
# RA           621
# W             86
# G            162
# Playoffs       0
# Name: 1192, dtype: object)
# (1193, Team         BOS
# League        AL
# Year        1963
# RS           666
# RA           704
# W             76
# G            161
# Playoffs       0
# Name: 1193, dtype: object)
# (1194, Team         CHC
# League        NL
# Year        1963
# RS           570
# RA           578
# W             82
# G            162
# Playoffs       0
# Name: 1194, dtype: object)
# (1195, Team         CHW
# League        AL
# Year        1963
# RS           683
# RA           544
# W             94
# G            162
# Playoffs       0
# Name: 1195, dtype: object)
# (1196, Team         CIN
# League        NL
# Year        1963
# RS           648
# RA           594
# W             86
# G            162
# Playoffs       0
# Name: 1196, dtype: object)
# (1197, Team         CLE
# League        AL
# Year        1963
# RS           635
# RA           702
# W             79
# G            162
# Playoffs       0
# Name: 1197, dtype: object)
# (1198, Team         DET
# League        AL
# Year        1963
# RS           700
# RA           703
# W             79
# G            162
# Playoffs       0
# Name: 1198, dtype: object)
# (1199, Team         HOU
# League        NL
# Year        1963
# RS           464
# RA           640
# W             66
# G            162
# Playoffs       0
# Name: 1199, dtype: object)
# (1200, Team         KCA
# League        AL
# Year        1963
# RS           615
# RA           704
# W             73
# G            162
# Playoffs       0
# Name: 1200, dtype: object)
# (1201, Team         LAA
# League        AL
# Year        1963
# RS           597
# RA           660
# W             70
# G            161
# Playoffs       0
# Name: 1201, dtype: object)
# (1202, Team         LAD
# League        NL
# Year        1963
# RS           640
# RA           550
# W             99
# G            163
# Playoffs       1
# Name: 1202, dtype: object)
# (1203, Team         MIN
# League        AL
# Year        1963
# RS           767
# RA           602
# W             91
# G            161
# Playoffs       0
# Name: 1203, dtype: object)
# (1204, Team         MLN
# League        NL
# Year        1963
# RS           677
# RA           603
# W             84
# G            163
# Playoffs       0
# Name: 1204, dtype: object)
# (1205, Team         NYM
# League        NL
# Year        1963
# RS           501
# RA           774
# W             51
# G            162
# Playoffs       0
# Name: 1205, dtype: object)
# (1206, Team         NYY
# League        AL
# Year        1963
# RS           714
# RA           547
# W            104
# G            161
# Playoffs       1
# Name: 1206, dtype: object)
# (1207, Team         PHI
# League        NL
# Year        1963
# RS           642
# RA           578
# W             87
# G            162
# Playoffs       0
# Name: 1207, dtype: object)
# (1208, Team         PIT
# League        NL
# Year        1963
# RS           567
# RA           595
# W             74
# G            162
# Playoffs       0
# Name: 1208, dtype: object)
# (1209, Team         SFG
# League        NL
# Year        1963
# RS           725
# RA           641
# W             88
# G            162
# Playoffs       0
# Name: 1209, dtype: object)
# (1210, Team         STL
# League        NL
# Year        1963
# RS           747
# RA           628
# W             93
# G            162
# Playoffs       0
# Name: 1210, dtype: object)
# (1211, Team         WSA
# League        AL
# Year        1963
# RS           578
# RA           812
# W             56
# G            162
# Playoffs       0
# Name: 1211, dtype: object)
# (1212, Team         BAL
# League        AL
# Year        1962
# RS           652
# RA           680
# W             77
# G            162
# Playoffs       0
# Name: 1212, dtype: object)
# (1213, Team         BOS
# League        AL
# Year        1962
# RS           707
# RA           756
# W             76
# G            160
# Playoffs       0
# Name: 1213, dtype: object)
# (1214, Team         CHC
# League        NL
# Year        1962
# RS           632
# RA           827
# W             59
# G            162
# Playoffs       0
# Name: 1214, dtype: object)
# (1215, Team         CHW
# League        AL
# Year        1962
# RS           707
# RA           658
# W             85
# G            162
# Playoffs       0
# Name: 1215, dtype: object)
# (1216, Team         CIN
# League        NL
# Year        1962
# RS           802
# RA           685
# W             98
# G            162
# Playoffs       0
# Name: 1216, dtype: object)
# (1217, Team         CLE
# League        AL
# Year        1962
# RS           682
# RA           745
# W             80
# G            162
# Playoffs       0
# Name: 1217, dtype: object)
# (1218, Team         DET
# League        AL
# Year        1962
# RS           758
# RA           692
# W             85
# G            161
# Playoffs       0
# Name: 1218, dtype: object)
# (1219, Team         HOU
# League        NL
# Year        1962
# RS           592
# RA           717
# W             64
# G            162
# Playoffs       0
# Name: 1219, dtype: object)
# (1220, Team         KCA
# League        AL
# Year        1962
# RS           745
# RA           837
# W             72
# G            162
# Playoffs       0
# Name: 1220, dtype: object)
# (1221, Team         LAA
# League        AL
# Year        1962
# RS           718
# RA           706
# W             86
# G            162
# Playoffs       0
# Name: 1221, dtype: object)
# (1222, Team         LAD
# League        NL
# Year        1962
# RS           842
# RA           697
# W            102
# G            165
# Playoffs       0
# Name: 1222, dtype: object)
# (1223, Team         MIN
# League        AL
# Year        1962
# RS           798
# RA           713
# W             91
# G            163
# Playoffs       0
# Name: 1223, dtype: object)
# (1224, Team         MLN
# League        NL
# Year        1962
# RS           730
# RA           665
# W             86
# G            162
# Playoffs       0
# Name: 1224, dtype: object)
# (1225, Team         NYM
# League        NL
# Year        1962
# RS           617
# RA           948
# W             40
# G            161
# Playoffs       0
# Name: 1225, dtype: object)
# (1226, Team         NYY
# League        AL
# Year        1962
# RS           817
# RA           680
# W             96
# G            162
# Playoffs       1
# Name: 1226, dtype: object)
# (1227, Team         PHI
# League        NL
# Year        1962
# RS           705
# RA           759
# W             81
# G            161
# Playoffs       0
# Name: 1227, dtype: object)
# (1228, Team         PIT
# League        NL
# Year        1962
# RS           706
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1228, dtype: object)
# (1229, Team         SFG
# League        NL
# Year        1962
# RS           878
# RA           690
# W            103
# G            165
# Playoffs       1
# Name: 1229, dtype: object)
# (1230, Team         STL
# League        NL
# Year        1962
# RS           774
# RA           664
# W             84
# G            163
# Playoffs       0
# Name: 1230, dtype: object)
# (1231, Team         WSA
# League        AL
# Year        1962
# RS           599
# RA           716
# W             60
# G            162
# Playoffs       0
# Name: 1231, dtype: object)

# %%
# Print the row and type of each row
for row_tuple in pit_df.iterrows():
    print(row_tuple)
    print(type(row_tuple))
# Out:
# (0, Team         ARI
# League        NL
# Year        2012
# RS           734
# RA           688
# W             81
# G            162
# Playoffs       0
# Name: 0, dtype: object)
# <class 'tuple'>
# (1, Team         ATL
# League        NL
# Year        2012
# RS           700
# RA           600
# W             94
# G            162
# Playoffs       1
# Name: 1, dtype: object)
# <class 'tuple'>
# (2, Team         BAL
# League        AL
# Year        2012
# RS           712
# RA           705
# W             93
# G            162
# Playoffs       1
# Name: 2, dtype: object)
# <class 'tuple'>
# (3, Team         BOS
# League        AL
# Year        2012
# RS           734
# RA           806
# W             69
# G            162
# Playoffs       0
# Name: 3, dtype: object)
# <class 'tuple'>
# (4, Team         CHC
# League        NL
# Year        2012
# RS           613
# RA           759
# W             61
# G            162
# Playoffs       0
# Name: 4, dtype: object)
# <class 'tuple'>
# (5, Team         CHW
# League        AL
# Year        2012
# RS           748
# RA           676
# W             85
# G            162
# Playoffs       0
# Name: 5, dtype: object)
# <class 'tuple'>
# (6, Team         CIN
# League        NL
# Year        2012
# RS           669
# RA           588
# W             97
# G            162
# Playoffs       1
# Name: 6, dtype: object)
# <class 'tuple'>
# (7, Team         CLE
# League        AL
# Year        2012
# RS           667
# RA           845
# W             68
# G            162
# Playoffs       0
# Name: 7, dtype: object)
# <class 'tuple'>
# (8, Team         COL
# League        NL
# Year        2012
# RS           758
# RA           890
# W             64
# G            162
# Playoffs       0
# Name: 8, dtype: object)
# <class 'tuple'>
# (9, Team         DET
# League        AL
# Year        2012
# RS           726
# RA           670
# W             88
# G            162
# Playoffs       1
# Name: 9, dtype: object)
# <class 'tuple'>
# (10, Team         HOU
# League        NL
# Year        2012
# RS           583
# RA           794
# W             55
# G            162
# Playoffs       0
# Name: 10, dtype: object)
# <class 'tuple'>
# (11, Team         KCR
# League        AL
# Year        2012
# RS           676
# RA           746
# W             72
# G            162
# Playoffs       0
# Name: 11, dtype: object)
# <class 'tuple'>
# (12, Team         LAA
# League        AL
# Year        2012
# RS           767
# RA           699
# W             89
# G            162
# Playoffs       0
# Name: 12, dtype: object)
# <class 'tuple'>
# (13, Team         LAD
# League        NL
# Year        2012
# RS           637
# RA           597
# W             86
# G            162
# Playoffs       0
# Name: 13, dtype: object)
# <class 'tuple'>
# (14, Team         MIA
# League        NL
# Year        2012
# RS           609
# RA           724
# W             69
# G            162
# Playoffs       0
# Name: 14, dtype: object)
# <class 'tuple'>
# (15, Team         MIL
# League        NL
# Year        2012
# RS           776
# RA           733
# W             83
# G            162
# Playoffs       0
# Name: 15, dtype: object)
# <class 'tuple'>
# (16, Team         MIN
# League        AL
# Year        2012
# RS           701
# RA           832
# W             66
# G            162
# Playoffs       0
# Name: 16, dtype: object)
# <class 'tuple'>
# (17, Team         NYM
# League        NL
# Year        2012
# RS           650
# RA           709
# W             74
# G            162
# Playoffs       0
# Name: 17, dtype: object)
# <class 'tuple'>
# (18, Team         NYY
# League        AL
# Year        2012
# RS           804
# RA           668
# W             95
# G            162
# Playoffs       1
# Name: 18, dtype: object)
# <class 'tuple'>
# (19, Team         OAK
# League        AL
# Year        2012
# RS           713
# RA           614
# W             94
# G            162
# Playoffs       1
# Name: 19, dtype: object)
# <class 'tuple'>
# (20, Team         PHI
# League        NL
# Year        2012
# RS           684
# RA           680
# W             81
# G            162
# Playoffs       0
# Name: 20, dtype: object)
# <class 'tuple'>
# (21, Team         PIT
# League        NL
# Year        2012
# RS           651
# RA           674
# W             79
# G            162
# Playoffs       0
# Name: 21, dtype: object)
# <class 'tuple'>
# (22, Team         SDP
# League        NL
# Year        2012
# RS           651
# RA           710
# W             76
# G            162
# Playoffs       0
# Name: 22, dtype: object)
# <class 'tuple'>
# (23, Team         SEA
# League        AL
# Year        2012
# RS           619
# RA           651
# W             75
# G            162
# Playoffs       0
# Name: 23, dtype: object)
# <class 'tuple'>
# (24, Team         SFG
# League        NL
# Year        2012
# RS           718
# RA           649
# W             94
# G            162
# Playoffs       1
# Name: 24, dtype: object)
# <class 'tuple'>
# (25, Team         STL
# League        NL
# Year        2012
# RS           765
# RA           648
# W             88
# G            162
# Playoffs       1
# Name: 25, dtype: object)
# <class 'tuple'>
# (26, Team         TBR
# League        AL
# Year        2012
# RS           697
# RA           577
# W             90
# G            162
# Playoffs       0
# Name: 26, dtype: object)
# <class 'tuple'>
# (27, Team         TEX
# League        AL
# Year        2012
# RS           808
# RA           707
# W             93
# G            162
# Playoffs       1
# Name: 27, dtype: object)
# <class 'tuple'>
# (28, Team         TOR
# League        AL
# Year        2012
# RS           716
# RA           784
# W             73
# G            162
# Playoffs       0
# Name: 28, dtype: object)
# <class 'tuple'>
# (29, Team         WSN
# League        NL
# Year        2012
# RS           731
# RA           594
# W             98
# G            162
# Playoffs       1
# Name: 29, dtype: object)
# <class 'tuple'>
# (30, Team         ARI
# League        NL
# Year        2011
# RS           731
# RA           662
# W             94
# G            162
# Playoffs       1
# Name: 30, dtype: object)
# <class 'tuple'>
# (31, Team         ATL
# League        NL
# Year        2011
# RS           641
# RA           605
# W             89
# G            162
# Playoffs       0
# Name: 31, dtype: object)
# <class 'tuple'>
# (32, Team         BAL
# League        AL
# Year        2011
# RS           708
# RA           860
# W             69
# G            162
# Playoffs       0
# Name: 32, dtype: object)
# <class 'tuple'>
# (33, Team         BOS
# League        AL
# Year        2011
# RS           875
# RA           737
# W             90
# G            162
# Playoffs       0
# Name: 33, dtype: object)
# <class 'tuple'>
# (34, Team         CHC
# League        NL
# Year        2011
# RS           654
# RA           756
# W             71
# G            162
# Playoffs       0
# Name: 34, dtype: object)
# <class 'tuple'>
# (35, Team         CHW
# League        AL
# Year        2011
# RS           654
# RA           706
# W             79
# G            162
# Playoffs       0
# Name: 35, dtype: object)
# <class 'tuple'>
# (36, Team         CIN
# League        NL
# Year        2011
# RS           735
# RA           720
# W             79
# G            162
# Playoffs       0
# Name: 36, dtype: object)
# <class 'tuple'>
# (37, Team         CLE
# League        AL
# Year        2011
# RS           704
# RA           760
# W             80
# G            162
# Playoffs       0
# Name: 37, dtype: object)
# <class 'tuple'>
# (38, Team         COL
# League        NL
# Year        2011
# RS           735
# RA           774
# W             73
# G            162
# Playoffs       0
# Name: 38, dtype: object)
# <class 'tuple'>
# (39, Team         DET
# League        AL
# Year        2011
# RS           787
# RA           711
# W             95
# G            162
# Playoffs       1
# Name: 39, dtype: object)
# <class 'tuple'>
# (40, Team         FLA
# League        NL
# Year        2011
# RS           625
# RA           702
# W             72
# G            162
# Playoffs       0
# Name: 40, dtype: object)
# <class 'tuple'>
# (41, Team         HOU
# League        NL
# Year        2011
# RS           615
# RA           796
# W             56
# G            162
# Playoffs       0
# Name: 41, dtype: object)
# <class 'tuple'>
# (42, Team         KCR
# League        AL
# Year        2011
# RS           730
# RA           762
# W             71
# G            162
# Playoffs       0
# Name: 42, dtype: object)
# <class 'tuple'>
# (43, Team         LAA
# League        AL
# Year        2011
# RS           667
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 43, dtype: object)
# <class 'tuple'>
# (44, Team         LAD
# League        NL
# Year        2011
# RS           644
# RA           612
# W             82
# G            161
# Playoffs       0
# Name: 44, dtype: object)
# <class 'tuple'>
# (45, Team         MIL
# League        NL
# Year        2011
# RS           721
# RA           638
# W             96
# G            162
# Playoffs       1
# Name: 45, dtype: object)
# <class 'tuple'>
# (46, Team         MIN
# League        AL
# Year        2011
# RS           619
# RA           804
# W             63
# G            162
# Playoffs       0
# Name: 46, dtype: object)
# <class 'tuple'>
# (47, Team         NYM
# League        NL
# Year        2011
# RS           718
# RA           742
# W             77
# G            162
# Playoffs       0
# Name: 47, dtype: object)
# <class 'tuple'>
# (48, Team         NYY
# League        AL
# Year        2011
# RS           867
# RA           657
# W             97
# G            162
# Playoffs       1
# Name: 48, dtype: object)
# <class 'tuple'>
# (49, Team         OAK
# League        AL
# Year        2011
# RS           645
# RA           679
# W             74
# G            162
# Playoffs       0
# Name: 49, dtype: object)
# <class 'tuple'>
# (50, Team         PHI
# League        NL
# Year        2011
# RS           713
# RA           529
# W            102
# G            162
# Playoffs       1
# Name: 50, dtype: object)
# <class 'tuple'>
# (51, Team         PIT
# League        NL
# Year        2011
# RS           610
# RA           712
# W             72
# G            162
# Playoffs       0
# Name: 51, dtype: object)
# <class 'tuple'>
# (52, Team         SDP
# League        NL
# Year        2011
# RS           593
# RA           611
# W             71
# G            162
# Playoffs       0
# Name: 52, dtype: object)
# <class 'tuple'>
# (53, Team         SEA
# League        AL
# Year        2011
# RS           556
# RA           675
# W             67
# G            162
# Playoffs       0
# Name: 53, dtype: object)
# <class 'tuple'>
# (54, Team         SFG
# League        NL
# Year        2011
# RS           570
# RA           578
# W             86
# G            162
# Playoffs       0
# Name: 54, dtype: object)
# <class 'tuple'>
# (55, Team         STL
# League        NL
# Year        2011
# RS           762
# RA           692
# W             90
# G            162
# Playoffs       1
# Name: 55, dtype: object)
# <class 'tuple'>
# (56, Team         TBR
# League        AL
# Year        2011
# RS           707
# RA           614
# W             91
# G            162
# Playoffs       1
# Name: 56, dtype: object)
# <class 'tuple'>
# (57, Team         TEX
# League        AL
# Year        2011
# RS           855
# RA           677
# W             96
# G            162
# Playoffs       1
# Name: 57, dtype: object)
# <class 'tuple'>
# (58, Team         TOR
# League        AL
# Year        2011
# RS           743
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 58, dtype: object)
# <class 'tuple'>
# (59, Team         WSN
# League        NL
# Year        2011
# RS           624
# RA           643
# W             80
# G            161
# Playoffs       0
# Name: 59, dtype: object)
# <class 'tuple'>
# (60, Team         ARI
# League        NL
# Year        2010
# RS           713
# RA           836
# W             65
# G            162
# Playoffs       0
# Name: 60, dtype: object)
# <class 'tuple'>
# (61, Team         ATL
# League        NL
# Year        2010
# RS           738
# RA           629
# W             91
# G            162
# Playoffs       1
# Name: 61, dtype: object)
# <class 'tuple'>
# (62, Team         BAL
# League        AL
# Year        2010
# RS           613
# RA           785
# W             66
# G            162
# Playoffs       0
# Name: 62, dtype: object)
# <class 'tuple'>
# (63, Team         BOS
# League        AL
# Year        2010
# RS           818
# RA           744
# W             89
# G            162
# Playoffs       0
# Name: 63, dtype: object)
# <class 'tuple'>
# (64, Team         CHC
# League        NL
# Year        2010
# RS           685
# RA           767
# W             75
# G            162
# Playoffs       0
# Name: 64, dtype: object)
# <class 'tuple'>
# (65, Team         CHW
# League        AL
# Year        2010
# RS           752
# RA           704
# W             88
# G            162
# Playoffs       0
# Name: 65, dtype: object)
# <class 'tuple'>
# (66, Team         CIN
# League        NL
# Year        2010
# RS           790
# RA           685
# W             91
# G            162
# Playoffs       1
# Name: 66, dtype: object)
# <class 'tuple'>
# (67, Team         CLE
# League        AL
# Year        2010
# RS           646
# RA           752
# W             69
# G            162
# Playoffs       0
# Name: 67, dtype: object)
# <class 'tuple'>
# (68, Team         COL
# League        NL
# Year        2010
# RS           770
# RA           717
# W             83
# G            162
# Playoffs       0
# Name: 68, dtype: object)
# <class 'tuple'>
# (69, Team         DET
# League        AL
# Year        2010
# RS           751
# RA           743
# W             81
# G            162
# Playoffs       0
# Name: 69, dtype: object)
# <class 'tuple'>
# (70, Team         FLA
# League        NL
# Year        2010
# RS           719
# RA           717
# W             80
# G            162
# Playoffs       0
# Name: 70, dtype: object)
# <class 'tuple'>
# (71, Team         HOU
# League        NL
# Year        2010
# RS           611
# RA           729
# W             76
# G            162
# Playoffs       0
# Name: 71, dtype: object)
# <class 'tuple'>
# (72, Team         KCR
# League        AL
# Year        2010
# RS           676
# RA           845
# W             67
# G            162
# Playoffs       0
# Name: 72, dtype: object)
# <class 'tuple'>
# (73, Team         LAA
# League        AL
# Year        2010
# RS           681
# RA           702
# W             80
# G            162
# Playoffs       0
# Name: 73, dtype: object)
# <class 'tuple'>
# (74, Team         LAD
# League        NL
# Year        2010
# RS           667
# RA           692
# W             80
# G            162
# Playoffs       0
# Name: 74, dtype: object)
# <class 'tuple'>
# (75, Team         MIL
# League        NL
# Year        2010
# RS           750
# RA           804
# W             77
# G            162
# Playoffs       0
# Name: 75, dtype: object)
# <class 'tuple'>
# (76, Team         MIN
# League        AL
# Year        2010
# RS           781
# RA           671
# W             94
# G            162
# Playoffs       1
# Name: 76, dtype: object)
# <class 'tuple'>
# (77, Team         NYM
# League        NL
# Year        2010
# RS           656
# RA           652
# W             79
# G            162
# Playoffs       0
# Name: 77, dtype: object)
# <class 'tuple'>
# (78, Team         NYY
# League        AL
# Year        2010
# RS           859
# RA           693
# W             95
# G            162
# Playoffs       1
# Name: 78, dtype: object)
# <class 'tuple'>
# (79, Team         OAK
# League        AL
# Year        2010
# RS           663
# RA           626
# W             81
# G            162
# Playoffs       0
# Name: 79, dtype: object)
# <class 'tuple'>
# (80, Team         PHI
# League        NL
# Year        2010
# RS           772
# RA           640
# W             97
# G            162
# Playoffs       1
# Name: 80, dtype: object)
# <class 'tuple'>
# (81, Team         PIT
# League        NL
# Year        2010
# RS           587
# RA           866
# W             57
# G            162
# Playoffs       0
# Name: 81, dtype: object)
# <class 'tuple'>
# (82, Team         SDP
# League        NL
# Year        2010
# RS           665
# RA           581
# W             90
# G            162
# Playoffs       0
# Name: 82, dtype: object)
# <class 'tuple'>
# (83, Team         SEA
# League        AL
# Year        2010
# RS           513
# RA           698
# W             61
# G            162
# Playoffs       0
# Name: 83, dtype: object)
# <class 'tuple'>
# (84, Team         SFG
# League        NL
# Year        2010
# RS           697
# RA           583
# W             92
# G            162
# Playoffs       1
# Name: 84, dtype: object)
# <class 'tuple'>
# (85, Team         STL
# League        NL
# Year        2010
# RS           736
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 85, dtype: object)
# <class 'tuple'>
# (86, Team         TBR
# League        AL
# Year        2010
# RS           802
# RA           649
# W             96
# G            162
# Playoffs       1
# Name: 86, dtype: object)
# <class 'tuple'>
# (87, Team         TEX
# League        AL
# Year        2010
# RS           787
# RA           687
# W             90
# G            162
# Playoffs       1
# Name: 87, dtype: object)
# <class 'tuple'>
# (88, Team         TOR
# League        AL
# Year        2010
# RS           755
# RA           728
# W             85
# G            162
# Playoffs       0
# Name: 88, dtype: object)
# <class 'tuple'>
# (89, Team         WSN
# League        NL
# Year        2010
# RS           655
# RA           742
# W             69
# G            162
# Playoffs       0
# Name: 89, dtype: object)
# <class 'tuple'>
# (90, Team         ARI
# League        NL
# Year        2009
# RS           720
# RA           782
# W             70
# G            162
# Playoffs       0
# Name: 90, dtype: object)
# <class 'tuple'>
# (91, Team         ATL
# League        NL
# Year        2009
# RS           735
# RA           641
# W             86
# G            162
# Playoffs       0
# Name: 91, dtype: object)
# <class 'tuple'>
# (92, Team         BAL
# League        AL
# Year        2009
# RS           741
# RA           876
# W             64
# G            162
# Playoffs       0
# Name: 92, dtype: object)
# <class 'tuple'>
# (93, Team         BOS
# League        AL
# Year        2009
# RS           872
# RA           736
# W             95
# G            162
# Playoffs       1
# Name: 93, dtype: object)
# <class 'tuple'>
# (94, Team         CHC
# League        NL
# Year        2009
# RS           707
# RA           672
# W             83
# G            161
# Playoffs       0
# Name: 94, dtype: object)
# <class 'tuple'>
# (95, Team         CHW
# League        AL
# Year        2009
# RS           724
# RA           732
# W             79
# G            162
# Playoffs       0
# Name: 95, dtype: object)
# <class 'tuple'>
# (96, Team         CIN
# League        NL
# Year        2009
# RS           673
# RA           723
# W             78
# G            162
# Playoffs       0
# Name: 96, dtype: object)
# <class 'tuple'>
# (97, Team         CLE
# League        AL
# Year        2009
# RS           773
# RA           865
# W             65
# G            162
# Playoffs       0
# Name: 97, dtype: object)
# <class 'tuple'>
# (98, Team         COL
# League        NL
# Year        2009
# RS           804
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 98, dtype: object)
# <class 'tuple'>
# (99, Team         DET
# League        AL
# Year        2009
# RS           743
# RA           745
# W             86
# G            163
# Playoffs       0
# Name: 99, dtype: object)
# <class 'tuple'>
# (100, Team         FLA
# League        NL
# Year        2009
# RS           772
# RA           766
# W             87
# G            162
# Playoffs       0
# Name: 100, dtype: object)
# <class 'tuple'>
# (101, Team         HOU
# League        NL
# Year        2009
# RS           643
# RA           770
# W             74
# G            162
# Playoffs       0
# Name: 101, dtype: object)
# <class 'tuple'>
# (102, Team         KCR
# League        AL
# Year        2009
# RS           686
# RA           842
# W             65
# G            162
# Playoffs       0
# Name: 102, dtype: object)
# <class 'tuple'>
# (103, Team         LAA
# League        AL
# Year        2009
# RS           883
# RA           761
# W             97
# G            162
# Playoffs       1
# Name: 103, dtype: object)
# <class 'tuple'>
# (104, Team         LAD
# League        NL
# Year        2009
# RS           780
# RA           611
# W             95
# G            162
# Playoffs       1
# Name: 104, dtype: object)
# <class 'tuple'>
# (105, Team         MIL
# League        NL
# Year        2009
# RS           785
# RA           818
# W             80
# G            162
# Playoffs       0
# Name: 105, dtype: object)
# <class 'tuple'>
# (106, Team         MIN
# League        AL
# Year        2009
# RS           817
# RA           765
# W             87
# G            163
# Playoffs       1
# Name: 106, dtype: object)
# <class 'tuple'>
# (107, Team         NYM
# League        NL
# Year        2009
# RS           671
# RA           757
# W             70
# G            162
# Playoffs       0
# Name: 107, dtype: object)
# <class 'tuple'>
# (108, Team         NYY
# League        AL
# Year        2009
# RS           915
# RA           753
# W            103
# G            162
# Playoffs       1
# Name: 108, dtype: object)
# <class 'tuple'>
# (109, Team         OAK
# League        AL
# Year        2009
# RS           759
# RA           761
# W             75
# G            162
# Playoffs       0
# Name: 109, dtype: object)
# <class 'tuple'>
# (110, Team         PHI
# League        NL
# Year        2009
# RS           820
# RA           709
# W             93
# G            162
# Playoffs       1
# Name: 110, dtype: object)
# <class 'tuple'>
# (111, Team         PIT
# League        NL
# Year        2009
# RS           636
# RA           768
# W             62
# G            161
# Playoffs       0
# Name: 111, dtype: object)
# <class 'tuple'>
# (112, Team         SDP
# League        NL
# Year        2009
# RS           638
# RA           769
# W             75
# G            162
# Playoffs       0
# Name: 112, dtype: object)
# <class 'tuple'>
# (113, Team         SEA
# League        AL
# Year        2009
# RS           640
# RA           692
# W             85
# G            162
# Playoffs       0
# Name: 113, dtype: object)
# <class 'tuple'>
# (114, Team         SFG
# League        NL
# Year        2009
# RS           657
# RA           611
# W             88
# G            162
# Playoffs       0
# Name: 114, dtype: object)
# <class 'tuple'>
# (115, Team         STL
# League        NL
# Year        2009
# RS           730
# RA           640
# W             91
# G            162
# Playoffs       1
# Name: 115, dtype: object)
# <class 'tuple'>
# (116, Team         TBR
# League        AL
# Year        2009
# RS           803
# RA           754
# W             84
# G            162
# Playoffs       0
# Name: 116, dtype: object)
# <class 'tuple'>
# (117, Team         TEX
# League        AL
# Year        2009
# RS           784
# RA           740
# W             87
# G            162
# Playoffs       0
# Name: 117, dtype: object)
# <class 'tuple'>
# (118, Team         TOR
# League        AL
# Year        2009
# RS           798
# RA           771
# W             75
# G            162
# Playoffs       0
# Name: 118, dtype: object)
# <class 'tuple'>
# (119, Team         WSN
# League        NL
# Year        2009
# RS           710
# RA           874
# W             59
# G            162
# Playoffs       0
# Name: 119, dtype: object)
# <class 'tuple'>
# (120, Team         ARI
# League        NL
# Year        2008
# RS           720
# RA           706
# W             82
# G            162
# Playoffs       0
# Name: 120, dtype: object)
# <class 'tuple'>
# (121, Team         ATL
# League        NL
# Year        2008
# RS           753
# RA           778
# W             72
# G            162
# Playoffs       0
# Name: 121, dtype: object)
# <class 'tuple'>
# (122, Team         BAL
# League        AL
# Year        2008
# RS           782
# RA           869
# W             68
# G            161
# Playoffs       0
# Name: 122, dtype: object)
# <class 'tuple'>
# (123, Team         BOS
# League        AL
# Year        2008
# RS           845
# RA           694
# W             95
# G            162
# Playoffs       1
# Name: 123, dtype: object)
# <class 'tuple'>
# (124, Team         CHC
# League        NL
# Year        2008
# RS           855
# RA           671
# W             97
# G            161
# Playoffs       1
# Name: 124, dtype: object)
# <class 'tuple'>
# (125, Team         CHW
# League        AL
# Year        2008
# RS           811
# RA           729
# W             89
# G            163
# Playoffs       1
# Name: 125, dtype: object)
# <class 'tuple'>
# (126, Team         CIN
# League        NL
# Year        2008
# RS           704
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 126, dtype: object)
# <class 'tuple'>
# (127, Team         CLE
# League        AL
# Year        2008
# RS           805
# RA           761
# W             81
# G            162
# Playoffs       0
# Name: 127, dtype: object)
# <class 'tuple'>
# (128, Team         COL
# League        NL
# Year        2008
# RS           747
# RA           822
# W             74
# G            162
# Playoffs       0
# Name: 128, dtype: object)
# <class 'tuple'>
# (129, Team         DET
# League        AL
# Year        2008
# RS           821
# RA           857
# W             74
# G            162
# Playoffs       0
# Name: 129, dtype: object)
# <class 'tuple'>
# (130, Team         FLA
# League        NL
# Year        2008
# RS           770
# RA           767
# W             84
# G            161
# Playoffs       0
# Name: 130, dtype: object)
# <class 'tuple'>
# (131, Team         HOU
# League        NL
# Year        2008
# RS           712
# RA           743
# W             86
# G            161
# Playoffs       0
# Name: 131, dtype: object)
# <class 'tuple'>
# (132, Team         KCR
# League        AL
# Year        2008
# RS           691
# RA           781
# W             75
# G            162
# Playoffs       0
# Name: 132, dtype: object)
# <class 'tuple'>
# (133, Team         LAA
# League        AL
# Year        2008
# RS           765
# RA           697
# W            100
# G            162
# Playoffs       1
# Name: 133, dtype: object)
# <class 'tuple'>
# (134, Team         LAD
# League        NL
# Year        2008
# RS           700
# RA           648
# W             84
# G            162
# Playoffs       1
# Name: 134, dtype: object)
# <class 'tuple'>
# (135, Team         MIL
# League        NL
# Year        2008
# RS           750
# RA           689
# W             90
# G            162
# Playoffs       1
# Name: 135, dtype: object)
# <class 'tuple'>
# (136, Team         MIN
# League        AL
# Year        2008
# RS           829
# RA           745
# W             88
# G            163
# Playoffs       0
# Name: 136, dtype: object)
# <class 'tuple'>
# (137, Team         NYM
# League        NL
# Year        2008
# RS           799
# RA           715
# W             89
# G            162
# Playoffs       0
# Name: 137, dtype: object)
# <class 'tuple'>
# (138, Team         NYY
# League        AL
# Year        2008
# RS           789
# RA           727
# W             89
# G            162
# Playoffs       0
# Name: 138, dtype: object)
# <class 'tuple'>
# (139, Team         OAK
# League        AL
# Year        2008
# RS           646
# RA           690
# W             75
# G            161
# Playoffs       0
# Name: 139, dtype: object)
# <class 'tuple'>
# (140, Team         PHI
# League        NL
# Year        2008
# RS           799
# RA           680
# W             92
# G            162
# Playoffs       1
# Name: 140, dtype: object)
# <class 'tuple'>
# (141, Team         PIT
# League        NL
# Year        2008
# RS           735
# RA           884
# W             67
# G            162
# Playoffs       0
# Name: 141, dtype: object)
# <class 'tuple'>
# (142, Team         SDP
# League        NL
# Year        2008
# RS           637
# RA           764
# W             63
# G            162
# Playoffs       0
# Name: 142, dtype: object)
# <class 'tuple'>
# (143, Team         SEA
# League        AL
# Year        2008
# RS           671
# RA           811
# W             61
# G            162
# Playoffs       0
# Name: 143, dtype: object)
# <class 'tuple'>
# (144, Team         SFG
# League        NL
# Year        2008
# RS           640
# RA           759
# W             72
# G            162
# Playoffs       0
# Name: 144, dtype: object)
# <class 'tuple'>
# (145, Team         STL
# League        NL
# Year        2008
# RS           779
# RA           725
# W             86
# G            162
# Playoffs       0
# Name: 145, dtype: object)
# <class 'tuple'>
# (146, Team         TBR
# League        AL
# Year        2008
# RS           774
# RA           671
# W             97
# G            162
# Playoffs       1
# Name: 146, dtype: object)
# <class 'tuple'>
# (147, Team         TEX
# League        AL
# Year        2008
# RS           901
# RA           967
# W             79
# G            162
# Playoffs       0
# Name: 147, dtype: object)
# <class 'tuple'>
# (148, Team         TOR
# League        AL
# Year        2008
# RS           714
# RA           610
# W             86
# G            162
# Playoffs       0
# Name: 148, dtype: object)
# <class 'tuple'>
# (149, Team         WSN
# League        NL
# Year        2008
# RS           641
# RA           825
# W             59
# G            161
# Playoffs       0
# Name: 149, dtype: object)
# <class 'tuple'>
# (150, Team         ARI
# League        NL
# Year        2007
# RS           712
# RA           732
# W             90
# G            162
# Playoffs       1
# Name: 150, dtype: object)
# <class 'tuple'>
# (151, Team         ATL
# League        NL
# Year        2007
# RS           810
# RA           733
# W             84
# G            162
# Playoffs       0
# Name: 151, dtype: object)
# <class 'tuple'>
# (152, Team         BAL
# League        AL
# Year        2007
# RS           756
# RA           868
# W             69
# G            162
# Playoffs       0
# Name: 152, dtype: object)
# <class 'tuple'>
# (153, Team         BOS
# League        AL
# Year        2007
# RS           867
# RA           657
# W             96
# G            162
# Playoffs       1
# Name: 153, dtype: object)
# <class 'tuple'>
# (154, Team         CHC
# League        NL
# Year        2007
# RS           752
# RA           690
# W             85
# G            162
# Playoffs       1
# Name: 154, dtype: object)
# <class 'tuple'>
# (155, Team         CHW
# League        AL
# Year        2007
# RS           693
# RA           839
# W             72
# G            162
# Playoffs       0
# Name: 155, dtype: object)
# <class 'tuple'>
# (156, Team         CIN
# League        NL
# Year        2007
# RS           783
# RA           853
# W             72
# G            162
# Playoffs       0
# Name: 156, dtype: object)
# <class 'tuple'>
# (157, Team         CLE
# League        AL
# Year        2007
# RS           811
# RA           704
# W             96
# G            162
# Playoffs       1
# Name: 157, dtype: object)
# <class 'tuple'>
# (158, Team         COL
# League        NL
# Year        2007
# RS           860
# RA           758
# W             90
# G            163
# Playoffs       1
# Name: 158, dtype: object)
# <class 'tuple'>
# (159, Team         DET
# League        AL
# Year        2007
# RS           887
# RA           797
# W             88
# G            162
# Playoffs       0
# Name: 159, dtype: object)
# <class 'tuple'>
# (160, Team         FLA
# League        NL
# Year        2007
# RS           790
# RA           891
# W             71
# G            162
# Playoffs       0
# Name: 160, dtype: object)
# <class 'tuple'>
# (161, Team         HOU
# League        NL
# Year        2007
# RS           723
# RA           813
# W             73
# G            162
# Playoffs       0
# Name: 161, dtype: object)
# <class 'tuple'>
# (162, Team         KCR
# League        AL
# Year        2007
# RS           706
# RA           778
# W             69
# G            162
# Playoffs       0
# Name: 162, dtype: object)
# <class 'tuple'>
# (163, Team         LAA
# League        AL
# Year        2007
# RS           822
# RA           731
# W             94
# G            162
# Playoffs       1
# Name: 163, dtype: object)
# <class 'tuple'>
# (164, Team         LAD
# League        NL
# Year        2007
# RS           735
# RA           727
# W             82
# G            162
# Playoffs       0
# Name: 164, dtype: object)
# <class 'tuple'>
# (165, Team         MIL
# League        NL
# Year        2007
# RS           801
# RA           776
# W             83
# G            162
# Playoffs       0
# Name: 165, dtype: object)
# <class 'tuple'>
# (166, Team         MIN
# League        AL
# Year        2007
# RS           718
# RA           725
# W             79
# G            162
# Playoffs       0
# Name: 166, dtype: object)
# <class 'tuple'>
# (167, Team         NYM
# League        NL
# Year        2007
# RS           804
# RA           750
# W             88
# G            162
# Playoffs       0
# Name: 167, dtype: object)
# <class 'tuple'>
# (168, Team         NYY
# League        AL
# Year        2007
# RS           968
# RA           777
# W             94
# G            162
# Playoffs       1
# Name: 168, dtype: object)
# <class 'tuple'>
# (169, Team         OAK
# League        AL
# Year        2007
# RS           741
# RA           758
# W             76
# G            162
# Playoffs       0
# Name: 169, dtype: object)
# <class 'tuple'>
# (170, Team         PHI
# League        NL
# Year        2007
# RS           892
# RA           821
# W             89
# G            162
# Playoffs       1
# Name: 170, dtype: object)
# <class 'tuple'>
# (171, Team         PIT
# League        NL
# Year        2007
# RS           724
# RA           846
# W             68
# G            162
# Playoffs       0
# Name: 171, dtype: object)
# <class 'tuple'>
# (172, Team         SDP
# League        NL
# Year        2007
# RS           741
# RA           666
# W             89
# G            163
# Playoffs       0
# Name: 172, dtype: object)
# <class 'tuple'>
# (173, Team         SEA
# League        AL
# Year        2007
# RS           794
# RA           813
# W             88
# G            162
# Playoffs       0
# Name: 173, dtype: object)
# <class 'tuple'>
# (174, Team         SFG
# League        NL
# Year        2007
# RS           683
# RA           720
# W             71
# G            162
# Playoffs       0
# Name: 174, dtype: object)
# <class 'tuple'>
# (175, Team         STL
# League        NL
# Year        2007
# RS           725
# RA           829
# W             78
# G            162
# Playoffs       0
# Name: 175, dtype: object)
# <class 'tuple'>
# (176, Team         TBD
# League        AL
# Year        2007
# RS           782
# RA           944
# W             66
# G            162
# Playoffs       0
# Name: 176, dtype: object)
# <class 'tuple'>
# (177, Team         TEX
# League        AL
# Year        2007
# RS           816
# RA           844
# W             75
# G            162
# Playoffs       0
# Name: 177, dtype: object)
# <class 'tuple'>
# (178, Team         TOR
# League        AL
# Year        2007
# RS           753
# RA           699
# W             83
# G            162
# Playoffs       0
# Name: 178, dtype: object)
# <class 'tuple'>
# (179, Team         WSN
# League        NL
# Year        2007
# RS           673
# RA           783
# W             73
# G            162
# Playoffs       0
# Name: 179, dtype: object)
# <class 'tuple'>
# (180, Team         ARI
# League        NL
# Year        2006
# RS           773
# RA           788
# W             76
# G            162
# Playoffs       0
# Name: 180, dtype: object)
# <class 'tuple'>
# (181, Team         ATL
# League        NL
# Year        2006
# RS           849
# RA           805
# W             79
# G            162
# Playoffs       0
# Name: 181, dtype: object)
# <class 'tuple'>
# (182, Team         BAL
# League        AL
# Year        2006
# RS           768
# RA           899
# W             70
# G            162
# Playoffs       0
# Name: 182, dtype: object)
# <class 'tuple'>
# (183, Team         BOS
# League        AL
# Year        2006
# RS           820
# RA           825
# W             86
# G            162
# Playoffs       0
# Name: 183, dtype: object)
# <class 'tuple'>
# (184, Team         CHC
# League        NL
# Year        2006
# RS           716
# RA           834
# W             66
# G            162
# Playoffs       0
# Name: 184, dtype: object)
# <class 'tuple'>
# (185, Team         CHW
# League        AL
# Year        2006
# RS           868
# RA           794
# W             90
# G            162
# Playoffs       0
# Name: 185, dtype: object)
# <class 'tuple'>
# (186, Team         CIN
# League        NL
# Year        2006
# RS           749
# RA           801
# W             80
# G            162
# Playoffs       0
# Name: 186, dtype: object)
# <class 'tuple'>
# (187, Team         CLE
# League        AL
# Year        2006
# RS           870
# RA           782
# W             78
# G            162
# Playoffs       0
# Name: 187, dtype: object)
# <class 'tuple'>
# (188, Team         COL
# League        NL
# Year        2006
# RS           813
# RA           812
# W             76
# G            162
# Playoffs       0
# Name: 188, dtype: object)
# <class 'tuple'>
# (189, Team         DET
# League        AL
# Year        2006
# RS           822
# RA           675
# W             95
# G            162
# Playoffs       1
# Name: 189, dtype: object)
# <class 'tuple'>
# (190, Team         FLA
# League        NL
# Year        2006
# RS           758
# RA           772
# W             78
# G            162
# Playoffs       0
# Name: 190, dtype: object)
# <class 'tuple'>
# (191, Team         HOU
# League        NL
# Year        2006
# RS           735
# RA           719
# W             82
# G            162
# Playoffs       0
# Name: 191, dtype: object)
# <class 'tuple'>
# (192, Team         KCR
# League        AL
# Year        2006
# RS           757
# RA           971
# W             62
# G            162
# Playoffs       0
# Name: 192, dtype: object)
# <class 'tuple'>
# (193, Team         LAA
# League        AL
# Year        2006
# RS           766
# RA           732
# W             89
# G            162
# Playoffs       0
# Name: 193, dtype: object)
# <class 'tuple'>
# (194, Team         LAD
# League        NL
# Year        2006
# RS           820
# RA           751
# W             88
# G            162
# Playoffs       1
# Name: 194, dtype: object)
# <class 'tuple'>
# (195, Team         MIL
# League        NL
# Year        2006
# RS           730
# RA           833
# W             75
# G            162
# Playoffs       0
# Name: 195, dtype: object)
# <class 'tuple'>
# (196, Team         MIN
# League        AL
# Year        2006
# RS           801
# RA           683
# W             96
# G            162
# Playoffs       1
# Name: 196, dtype: object)
# <class 'tuple'>
# (197, Team         NYM
# League        NL
# Year        2006
# RS           834
# RA           731
# W             97
# G            162
# Playoffs       1
# Name: 197, dtype: object)
# <class 'tuple'>
# (198, Team         NYY
# League        AL
# Year        2006
# RS           930
# RA           767
# W             97
# G            162
# Playoffs       1
# Name: 198, dtype: object)
# <class 'tuple'>
# (199, Team         OAK
# League        AL
# Year        2006
# RS           771
# RA           727
# W             93
# G            162
# Playoffs       1
# Name: 199, dtype: object)
# <class 'tuple'>
# (200, Team         PHI
# League        NL
# Year        2006
# RS           865
# RA           812
# W             85
# G            162
# Playoffs       0
# Name: 200, dtype: object)
# <class 'tuple'>
# (201, Team         PIT
# League        NL
# Year        2006
# RS           691
# RA           797
# W             67
# G            162
# Playoffs       0
# Name: 201, dtype: object)
# <class 'tuple'>
# (202, Team         SDP
# League        NL
# Year        2006
# RS           731
# RA           679
# W             88
# G            162
# Playoffs       1
# Name: 202, dtype: object)
# <class 'tuple'>
# (203, Team         SEA
# League        AL
# Year        2006
# RS           756
# RA           792
# W             78
# G            162
# Playoffs       0
# Name: 203, dtype: object)
# <class 'tuple'>
# (204, Team         SFG
# League        NL
# Year        2006
# RS           746
# RA           790
# W             76
# G            161
# Playoffs       0
# Name: 204, dtype: object)
# <class 'tuple'>
# (205, Team         STL
# League        NL
# Year        2006
# RS           781
# RA           762
# W             83
# G            161
# Playoffs       1
# Name: 205, dtype: object)
# <class 'tuple'>
# (206, Team         TBD
# League        AL
# Year        2006
# RS           689
# RA           856
# W             61
# G            162
# Playoffs       0
# Name: 206, dtype: object)
# <class 'tuple'>
# (207, Team         TEX
# League        AL
# Year        2006
# RS           835
# RA           784
# W             80
# G            162
# Playoffs       0
# Name: 207, dtype: object)
# <class 'tuple'>
# (208, Team         TOR
# League        AL
# Year        2006
# RS           809
# RA           754
# W             87
# G            162
# Playoffs       0
# Name: 208, dtype: object)
# <class 'tuple'>
# (209, Team         WSN
# League        NL
# Year        2006
# RS           746
# RA           872
# W             71
# G            162
# Playoffs       0
# Name: 209, dtype: object)
# <class 'tuple'>
# (210, Team         ARI
# League        NL
# Year        2005
# RS           696
# RA           856
# W             77
# G            162
# Playoffs       0
# Name: 210, dtype: object)
# <class 'tuple'>
# (211, Team         ATL
# League        NL
# Year        2005
# RS           769
# RA           674
# W             90
# G            162
# Playoffs       1
# Name: 211, dtype: object)
# <class 'tuple'>
# (212, Team         BAL
# League        AL
# Year        2005
# RS           729
# RA           800
# W             74
# G            162
# Playoffs       0
# Name: 212, dtype: object)
# <class 'tuple'>
# (213, Team         BOS
# League        AL
# Year        2005
# RS           910
# RA           805
# W             95
# G            162
# Playoffs       1
# Name: 213, dtype: object)
# <class 'tuple'>
# (214, Team         CHC
# League        NL
# Year        2005
# RS           703
# RA           714
# W             79
# G            162
# Playoffs       0
# Name: 214, dtype: object)
# <class 'tuple'>
# (215, Team         CHW
# League        AL
# Year        2005
# RS           741
# RA           645
# W             99
# G            162
# Playoffs       1
# Name: 215, dtype: object)
# <class 'tuple'>
# (216, Team         CIN
# League        NL
# Year        2005
# RS           820
# RA           889
# W             73
# G            163
# Playoffs       0
# Name: 216, dtype: object)
# <class 'tuple'>
# (217, Team         CLE
# League        AL
# Year        2005
# RS           790
# RA           642
# W             93
# G            162
# Playoffs       0
# Name: 217, dtype: object)
# <class 'tuple'>
# (218, Team         COL
# League        NL
# Year        2005
# RS           740
# RA           862
# W             67
# G            162
# Playoffs       0
# Name: 218, dtype: object)
# <class 'tuple'>
# (219, Team         DET
# League        AL
# Year        2005
# RS           723
# RA           787
# W             71
# G            162
# Playoffs       0
# Name: 219, dtype: object)
# <class 'tuple'>
# (220, Team         FLA
# League        NL
# Year        2005
# RS           717
# RA           732
# W             83
# G            162
# Playoffs       0
# Name: 220, dtype: object)
# <class 'tuple'>
# (221, Team         HOU
# League        NL
# Year        2005
# RS           693
# RA           609
# W             89
# G            163
# Playoffs       1
# Name: 221, dtype: object)
# <class 'tuple'>
# (222, Team         KCR
# League        AL
# Year        2005
# RS           701
# RA           935
# W             56
# G            162
# Playoffs       0
# Name: 222, dtype: object)
# <class 'tuple'>
# (223, Team         LAA
# League        AL
# Year        2005
# RS           761
# RA           643
# W             95
# G            162
# Playoffs       1
# Name: 223, dtype: object)
# <class 'tuple'>
# (224, Team         LAD
# League        NL
# Year        2005
# RS           685
# RA           755
# W             71
# G            162
# Playoffs       0
# Name: 224, dtype: object)
# <class 'tuple'>
# (225, Team         MIL
# League        NL
# Year        2005
# RS           726
# RA           697
# W             81
# G            162
# Playoffs       0
# Name: 225, dtype: object)
# <class 'tuple'>
# (226, Team         MIN
# League        AL
# Year        2005
# RS           688
# RA           662
# W             83
# G            162
# Playoffs       0
# Name: 226, dtype: object)
# <class 'tuple'>
# (227, Team         NYM
# League        NL
# Year        2005
# RS           722
# RA           648
# W             83
# G            162
# Playoffs       0
# Name: 227, dtype: object)
# <class 'tuple'>
# (228, Team         NYY
# League        AL
# Year        2005
# RS           886
# RA           789
# W             95
# G            162
# Playoffs       1
# Name: 228, dtype: object)
# <class 'tuple'>
# (229, Team         OAK
# League        AL
# Year        2005
# RS           772
# RA           658
# W             88
# G            162
# Playoffs       0
# Name: 229, dtype: object)
# <class 'tuple'>
# (230, Team         PHI
# League        NL
# Year        2005
# RS           807
# RA           726
# W             88
# G            162
# Playoffs       0
# Name: 230, dtype: object)
# <class 'tuple'>
# (231, Team         PIT
# League        NL
# Year        2005
# RS           680
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 231, dtype: object)
# <class 'tuple'>
# (232, Team         SDP
# League        NL
# Year        2005
# RS           684
# RA           726
# W             82
# G            162
# Playoffs       1
# Name: 232, dtype: object)
# <class 'tuple'>
# (233, Team         SEA
# League        AL
# Year        2005
# RS           699
# RA           751
# W             69
# G            162
# Playoffs       0
# Name: 233, dtype: object)
# <class 'tuple'>
# (234, Team         SFG
# League        NL
# Year        2005
# RS           649
# RA           745
# W             75
# G            162
# Playoffs       0
# Name: 234, dtype: object)
# <class 'tuple'>
# (235, Team         STL
# League        NL
# Year        2005
# RS           805
# RA           634
# W            100
# G            162
# Playoffs       1
# Name: 235, dtype: object)
# <class 'tuple'>
# (236, Team         TBD
# League        AL
# Year        2005
# RS           750
# RA           936
# W             67
# G            162
# Playoffs       0
# Name: 236, dtype: object)
# <class 'tuple'>
# (237, Team         TEX
# League        AL
# Year        2005
# RS           865
# RA           858
# W             79
# G            162
# Playoffs       0
# Name: 237, dtype: object)
# <class 'tuple'>
# (238, Team         TOR
# League        AL
# Year        2005
# RS           775
# RA           705
# W             80
# G            162
# Playoffs       0
# Name: 238, dtype: object)
# <class 'tuple'>
# (239, Team         WSN
# League        NL
# Year        2005
# RS           639
# RA           673
# W             81
# G            162
# Playoffs       0
# Name: 239, dtype: object)
# <class 'tuple'>
# (240, Team         ANA
# League        AL
# Year        2004
# RS           836
# RA           734
# W             92
# G            162
# Playoffs       1
# Name: 240, dtype: object)
# <class 'tuple'>
# (241, Team         ARI
# League        NL
# Year        2004
# RS           615
# RA           899
# W             51
# G            162
# Playoffs       0
# Name: 241, dtype: object)
# <class 'tuple'>
# (242, Team         ATL
# League        NL
# Year        2004
# RS           803
# RA           668
# W             96
# G            162
# Playoffs       1
# Name: 242, dtype: object)
# <class 'tuple'>
# (243, Team         BAL
# League        AL
# Year        2004
# RS           842
# RA           830
# W             78
# G            162
# Playoffs       0
# Name: 243, dtype: object)
# <class 'tuple'>
# (244, Team         BOS
# League        AL
# Year        2004
# RS           949
# RA           768
# W             98
# G            162
# Playoffs       1
# Name: 244, dtype: object)
# <class 'tuple'>
# (245, Team         CHC
# League        NL
# Year        2004
# RS           789
# RA           665
# W             89
# G            162
# Playoffs       0
# Name: 245, dtype: object)
# <class 'tuple'>
# (246, Team         CHW
# League        AL
# Year        2004
# RS           865
# RA           831
# W             83
# G            162
# Playoffs       0
# Name: 246, dtype: object)
# <class 'tuple'>
# (247, Team         CIN
# League        NL
# Year        2004
# RS           750
# RA           907
# W             76
# G            162
# Playoffs       0
# Name: 247, dtype: object)
# <class 'tuple'>
# (248, Team         CLE
# League        AL
# Year        2004
# RS           858
# RA           857
# W             80
# G            162
# Playoffs       0
# Name: 248, dtype: object)
# <class 'tuple'>
# (249, Team         COL
# League        NL
# Year        2004
# RS           833
# RA           923
# W             68
# G            162
# Playoffs       0
# Name: 249, dtype: object)
# <class 'tuple'>
# (250, Team         DET
# League        AL
# Year        2004
# RS           827
# RA           844
# W             72
# G            162
# Playoffs       0
# Name: 250, dtype: object)
# <class 'tuple'>
# (251, Team         FLA
# League        NL
# Year        2004
# RS           718
# RA           700
# W             83
# G            162
# Playoffs       0
# Name: 251, dtype: object)
# <class 'tuple'>
# (252, Team         HOU
# League        NL
# Year        2004
# RS           803
# RA           698
# W             92
# G            162
# Playoffs       1
# Name: 252, dtype: object)
# <class 'tuple'>
# (253, Team         KCR
# League        AL
# Year        2004
# RS           720
# RA           905
# W             58
# G            162
# Playoffs       0
# Name: 253, dtype: object)
# <class 'tuple'>
# (254, Team         LAD
# League        NL
# Year        2004
# RS           761
# RA           684
# W             93
# G            162
# Playoffs       1
# Name: 254, dtype: object)
# <class 'tuple'>
# (255, Team         MIL
# League        NL
# Year        2004
# RS           634
# RA           757
# W             67
# G            161
# Playoffs       0
# Name: 255, dtype: object)
# <class 'tuple'>
# (256, Team         MIN
# League        AL
# Year        2004
# RS           780
# RA           715
# W             92
# G            162
# Playoffs       1
# Name: 256, dtype: object)
# <class 'tuple'>
# (257, Team         MON
# League        NL
# Year        2004
# RS           635
# RA           769
# W             67
# G            162
# Playoffs       0
# Name: 257, dtype: object)
# <class 'tuple'>
# (258, Team         NYM
# League        NL
# Year        2004
# RS           684
# RA           731
# W             71
# G            162
# Playoffs       0
# Name: 258, dtype: object)
# <class 'tuple'>
# (259, Team         NYY
# League        AL
# Year        2004
# RS           897
# RA           808
# W            101
# G            162
# Playoffs       1
# Name: 259, dtype: object)
# <class 'tuple'>
# (260, Team         OAK
# League        AL
# Year        2004
# RS           793
# RA           742
# W             91
# G            162
# Playoffs       0
# Name: 260, dtype: object)
# <class 'tuple'>
# (261, Team         PHI
# League        NL
# Year        2004
# RS           840
# RA           781
# W             86
# G            162
# Playoffs       0
# Name: 261, dtype: object)
# <class 'tuple'>
# ...
# (1146, Team         NYY
# League        AL
# Year        1966
# RS           611
# RA           612
# W             70
# G            160
# Playoffs       0
# Name: 1146, dtype: object)
# <class 'tuple'>
# (1147, Team         PHI
# League        NL
# Year        1966
# RS           696
# RA           640
# W             87
# G            162
# Playoffs       0
# Name: 1147, dtype: object)
# <class 'tuple'>
# (1148, Team         PIT
# League        NL
# Year        1966
# RS           759
# RA           641
# W             92
# G            162
# Playoffs       0
# Name: 1148, dtype: object)
# <class 'tuple'>
# (1149, Team         SFG
# League        NL
# Year        1966
# RS           675
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1149, dtype: object)
# <class 'tuple'>
# (1150, Team         STL
# League        NL
# Year        1966
# RS           571
# RA           577
# W             83
# G            162
# Playoffs       0
# Name: 1150, dtype: object)
# <class 'tuple'>
# (1151, Team         WSA
# League        AL
# Year        1966
# RS           557
# RA           659
# W             71
# G            159
# Playoffs       0
# Name: 1151, dtype: object)
# <class 'tuple'>
# (1152, Team         BAL
# League        AL
# Year        1965
# RS           641
# RA           578
# W             94
# G            162
# Playoffs       0
# Name: 1152, dtype: object)
# <class 'tuple'>
# (1153, Team         BOS
# League        AL
# Year        1965
# RS           669
# RA           791
# W             62
# G            162
# Playoffs       0
# Name: 1153, dtype: object)
# <class 'tuple'>
# (1154, Team         CAL
# League        AL
# Year        1965
# RS           527
# RA           569
# W             75
# G            162
# Playoffs       0
# Name: 1154, dtype: object)
# <class 'tuple'>
# (1155, Team         CHC
# League        NL
# Year        1965
# RS           635
# RA           723
# W             72
# G            164
# Playoffs       0
# Name: 1155, dtype: object)
# <class 'tuple'>
# (1156, Team         CHW
# League        AL
# Year        1965
# RS           647
# RA           555
# W             95
# G            162
# Playoffs       0
# Name: 1156, dtype: object)
# <class 'tuple'>
# (1157, Team         CIN
# League        NL
# Year        1965
# RS           825
# RA           704
# W             89
# G            162
# Playoffs       0
# Name: 1157, dtype: object)
# <class 'tuple'>
# (1158, Team         CLE
# League        AL
# Year        1965
# RS           663
# RA           613
# W             87
# G            162
# Playoffs       0
# Name: 1158, dtype: object)
# <class 'tuple'>
# (1159, Team         DET
# League        AL
# Year        1965
# RS           680
# RA           602
# W             89
# G            162
# Playoffs       0
# Name: 1159, dtype: object)
# <class 'tuple'>
# (1160, Team         HOU
# League        NL
# Year        1965
# RS           569
# RA           711
# W             65
# G            162
# Playoffs       0
# Name: 1160, dtype: object)
# <class 'tuple'>
# (1161, Team         KCA
# League        AL
# Year        1965
# RS           585
# RA           755
# W             59
# G            162
# Playoffs       0
# Name: 1161, dtype: object)
# <class 'tuple'>
# (1162, Team         LAD
# League        NL
# Year        1965
# RS           608
# RA           521
# W             97
# G            162
# Playoffs       1
# Name: 1162, dtype: object)
# <class 'tuple'>
# (1163, Team         MIN
# League        AL
# Year        1965
# RS           774
# RA           600
# W            102
# G            162
# Playoffs       1
# Name: 1163, dtype: object)
# <class 'tuple'>
# (1164, Team         MLN
# League        NL
# Year        1965
# RS           708
# RA           633
# W             86
# G            162
# Playoffs       0
# Name: 1164, dtype: object)
# <class 'tuple'>
# (1165, Team         NYM
# League        NL
# Year        1965
# RS           495
# RA           752
# W             50
# G            164
# Playoffs       0
# Name: 1165, dtype: object)
# <class 'tuple'>
# (1166, Team         NYY
# League        AL
# Year        1965
# RS           611
# RA           604
# W             77
# G            162
# Playoffs       0
# Name: 1166, dtype: object)
# <class 'tuple'>
# (1167, Team         PHI
# League        NL
# Year        1965
# RS           654
# RA           667
# W             85
# G            162
# Playoffs       0
# Name: 1167, dtype: object)
# <class 'tuple'>
# (1168, Team         PIT
# League        NL
# Year        1965
# RS           675
# RA           580
# W             90
# G            163
# Playoffs       0
# Name: 1168, dtype: object)
# <class 'tuple'>
# (1169, Team         SFG
# League        NL
# Year        1965
# RS           682
# RA           593
# W             95
# G            163
# Playoffs       0
# Name: 1169, dtype: object)
# <class 'tuple'>
# (1170, Team         STL
# League        NL
# Year        1965
# RS           707
# RA           674
# W             80
# G            162
# Playoffs       0
# Name: 1170, dtype: object)
# <class 'tuple'>
# (1171, Team         WSA
# League        AL
# Year        1965
# RS           591
# RA           721
# W             70
# G            162
# Playoffs       0
# Name: 1171, dtype: object)
# <class 'tuple'>
# (1172, Team         BAL
# League        AL
# Year        1964
# RS           679
# RA           567
# W             97
# G            163
# Playoffs       0
# Name: 1172, dtype: object)
# <class 'tuple'>
# (1173, Team         BOS
# League        AL
# Year        1964
# RS           688
# RA           793
# W             72
# G            162
# Playoffs       0
# Name: 1173, dtype: object)
# <class 'tuple'>
# (1174, Team         CHC
# League        NL
# Year        1964
# RS           649
# RA           724
# W             76
# G            162
# Playoffs       0
# Name: 1174, dtype: object)
# <class 'tuple'>
# (1175, Team         CHW
# League        AL
# Year        1964
# RS           642
# RA           501
# W             98
# G            162
# Playoffs       0
# Name: 1175, dtype: object)
# <class 'tuple'>
# (1176, Team         CIN
# League        NL
# Year        1964
# RS           660
# RA           566
# W             92
# G            163
# Playoffs       0
# Name: 1176, dtype: object)
# <class 'tuple'>
# (1177, Team         CLE
# League        AL
# Year        1964
# RS           689
# RA           693
# W             79
# G            164
# Playoffs       0
# Name: 1177, dtype: object)
# <class 'tuple'>
# (1178, Team         DET
# League        AL
# Year        1964
# RS           699
# RA           678
# W             85
# G            163
# Playoffs       0
# Name: 1178, dtype: object)
# <class 'tuple'>
# (1179, Team         HOU
# League        NL
# Year        1964
# RS           495
# RA           628
# W             66
# G            162
# Playoffs       0
# Name: 1179, dtype: object)
# <class 'tuple'>
# (1180, Team         KCA
# League        AL
# Year        1964
# RS           621
# RA           836
# W             57
# G            163
# Playoffs       0
# Name: 1180, dtype: object)
# <class 'tuple'>
# (1181, Team         LAA
# League        AL
# Year        1964
# RS           544
# RA           551
# W             82
# G            162
# Playoffs       0
# Name: 1181, dtype: object)
# <class 'tuple'>
# (1182, Team         LAD
# League        NL
# Year        1964
# RS           614
# RA           572
# W             80
# G            164
# Playoffs       0
# Name: 1182, dtype: object)
# <class 'tuple'>
# (1183, Team         MIN
# League        AL
# Year        1964
# RS           737
# RA           678
# W             79
# G            163
# Playoffs       0
# Name: 1183, dtype: object)
# <class 'tuple'>
# (1184, Team         MLN
# League        NL
# Year        1964
# RS           803
# RA           744
# W             88
# G            162
# Playoffs       0
# Name: 1184, dtype: object)
# <class 'tuple'>
# (1185, Team         NYM
# League        NL
# Year        1964
# RS           569
# RA           776
# W             53
# G            163
# Playoffs       0
# Name: 1185, dtype: object)
# <class 'tuple'>
# (1186, Team         NYY
# League        AL
# Year        1964
# RS           730
# RA           577
# W             99
# G            164
# Playoffs       1
# Name: 1186, dtype: object)
# <class 'tuple'>
# (1187, Team         PHI
# League        NL
# Year        1964
# RS           693
# RA           632
# W             92
# G            162
# Playoffs       0
# Name: 1187, dtype: object)
# <class 'tuple'>
# (1188, Team         PIT
# League        NL
# Year        1964
# RS           663
# RA           636
# W             80
# G            162
# Playoffs       0
# Name: 1188, dtype: object)
# <class 'tuple'>
# (1189, Team         SFG
# League        NL
# Year        1964
# RS           656
# RA           587
# W             90
# G            162
# Playoffs       0
# Name: 1189, dtype: object)
# <class 'tuple'>
# (1190, Team         STL
# League        NL
# Year        1964
# RS           715
# RA           652
# W             93
# G            162
# Playoffs       1
# Name: 1190, dtype: object)
# <class 'tuple'>
# (1191, Team         WSA
# League        AL
# Year        1964
# RS           578
# RA           733
# W             62
# G            162
# Playoffs       0
# Name: 1191, dtype: object)
# <class 'tuple'>
# (1192, Team         BAL
# League        AL
# Year        1963
# RS           644
# RA           621
# W             86
# G            162
# Playoffs       0
# Name: 1192, dtype: object)
# <class 'tuple'>
# (1193, Team         BOS
# League        AL
# Year        1963
# RS           666
# RA           704
# W             76
# G            161
# Playoffs       0
# Name: 1193, dtype: object)
# <class 'tuple'>
# (1194, Team         CHC
# League        NL
# Year        1963
# RS           570
# RA           578
# W             82
# G            162
# Playoffs       0
# Name: 1194, dtype: object)
# <class 'tuple'>
# (1195, Team         CHW
# League        AL
# Year        1963
# RS           683
# RA           544
# W             94
# G            162
# Playoffs       0
# Name: 1195, dtype: object)
# <class 'tuple'>
# (1196, Team         CIN
# League        NL
# Year        1963
# RS           648
# RA           594
# W             86
# G            162
# Playoffs       0
# Name: 1196, dtype: object)
# <class 'tuple'>
# (1197, Team         CLE
# League        AL
# Year        1963
# RS           635
# RA           702
# W             79
# G            162
# Playoffs       0
# Name: 1197, dtype: object)
# <class 'tuple'>
# (1198, Team         DET
# League        AL
# Year        1963
# RS           700
# RA           703
# W             79
# G            162
# Playoffs       0
# Name: 1198, dtype: object)
# <class 'tuple'>
# (1199, Team         HOU
# League        NL
# Year        1963
# RS           464
# RA           640
# W             66
# G            162
# Playoffs       0
# Name: 1199, dtype: object)
# <class 'tuple'>
# (1200, Team         KCA
# League        AL
# Year        1963
# RS           615
# RA           704
# W             73
# G            162
# Playoffs       0
# Name: 1200, dtype: object)
# <class 'tuple'>
# (1201, Team         LAA
# League        AL
# Year        1963
# RS           597
# RA           660
# W             70
# G            161
# Playoffs       0
# Name: 1201, dtype: object)
# <class 'tuple'>
# (1202, Team         LAD
# League        NL
# Year        1963
# RS           640
# RA           550
# W             99
# G            163
# Playoffs       1
# Name: 1202, dtype: object)
# <class 'tuple'>
# (1203, Team         MIN
# League        AL
# Year        1963
# RS           767
# RA           602
# W             91
# G            161
# Playoffs       0
# Name: 1203, dtype: object)
# <class 'tuple'>
# (1204, Team         MLN
# League        NL
# Year        1963
# RS           677
# RA           603
# W             84
# G            163
# Playoffs       0
# Name: 1204, dtype: object)
# <class 'tuple'>
# (1205, Team         NYM
# League        NL
# Year        1963
# RS           501
# RA           774
# W             51
# G            162
# Playoffs       0
# Name: 1205, dtype: object)
# <class 'tuple'>
# (1206, Team         NYY
# League        AL
# Year        1963
# RS           714
# RA           547
# W            104
# G            161
# Playoffs       1
# Name: 1206, dtype: object)
# <class 'tuple'>
# (1207, Team         PHI
# League        NL
# Year        1963
# RS           642
# RA           578
# W             87
# G            162
# Playoffs       0
# Name: 1207, dtype: object)
# <class 'tuple'>
# (1208, Team         PIT
# League        NL
# Year        1963
# RS           567
# RA           595
# W             74
# G            162
# Playoffs       0
# Name: 1208, dtype: object)
# <class 'tuple'>
# (1209, Team         SFG
# League        NL
# Year        1963
# RS           725
# RA           641
# W             88
# G            162
# Playoffs       0
# Name: 1209, dtype: object)
# <class 'tuple'>
# (1210, Team         STL
# League        NL
# Year        1963
# RS           747
# RA           628
# W             93
# G            162
# Playoffs       0
# Name: 1210, dtype: object)
# <class 'tuple'>
# (1211, Team         WSA
# League        AL
# Year        1963
# RS           578
# RA           812
# W             56
# G            162
# Playoffs       0
# Name: 1211, dtype: object)
# <class 'tuple'>
# (1212, Team         BAL
# League        AL
# Year        1962
# RS           652
# RA           680
# W             77
# G            162
# Playoffs       0
# Name: 1212, dtype: object)
# <class 'tuple'>
# (1213, Team         BOS
# League        AL
# Year        1962
# RS           707
# RA           756
# W             76
# G            160
# Playoffs       0
# Name: 1213, dtype: object)
# <class 'tuple'>
# (1214, Team         CHC
# League        NL
# Year        1962
# RS           632
# RA           827
# W             59
# G            162
# Playoffs       0
# Name: 1214, dtype: object)
# <class 'tuple'>
# (1215, Team         CHW
# League        AL
# Year        1962
# RS           707
# RA           658
# W             85
# G            162
# Playoffs       0
# Name: 1215, dtype: object)
# <class 'tuple'>
# (1216, Team         CIN
# League        NL
# Year        1962
# RS           802
# RA           685
# W             98
# G            162
# Playoffs       0
# Name: 1216, dtype: object)
# <class 'tuple'>
# (1217, Team         CLE
# League        AL
# Year        1962
# RS           682
# RA           745
# W             80
# G            162
# Playoffs       0
# Name: 1217, dtype: object)
# <class 'tuple'>
# (1218, Team         DET
# League        AL
# Year        1962
# RS           758
# RA           692
# W             85
# G            161
# Playoffs       0
# Name: 1218, dtype: object)
# <class 'tuple'>
# (1219, Team         HOU
# League        NL
# Year        1962
# RS           592
# RA           717
# W             64
# G            162
# Playoffs       0
# Name: 1219, dtype: object)
# <class 'tuple'>
# (1220, Team         KCA
# League        AL
# Year        1962
# RS           745
# RA           837
# W             72
# G            162
# Playoffs       0
# Name: 1220, dtype: object)
# <class 'tuple'>
# (1221, Team         LAA
# League        AL
# Year        1962
# RS           718
# RA           706
# W             86
# G            162
# Playoffs       0
# Name: 1221, dtype: object)
# <class 'tuple'>
# (1222, Team         LAD
# League        NL
# Year        1962
# RS           842
# RA           697
# W            102
# G            165
# Playoffs       0
# Name: 1222, dtype: object)
# <class 'tuple'>
# (1223, Team         MIN
# League        AL
# Year        1962
# RS           798
# RA           713
# W             91
# G            163
# Playoffs       0
# Name: 1223, dtype: object)
# <class 'tuple'>
# (1224, Team         MLN
# League        NL
# Year        1962
# RS           730
# RA           665
# W             86
# G            162
# Playoffs       0
# Name: 1224, dtype: object)
# <class 'tuple'>
# (1225, Team         NYM
# League        NL
# Year        1962
# RS           617
# RA           948
# W             40
# G            161
# Playoffs       0
# Name: 1225, dtype: object)
# <class 'tuple'>
# (1226, Team         NYY
# League        AL
# Year        1962
# RS           817
# RA           680
# W             96
# G            162
# Playoffs       1
# Name: 1226, dtype: object)
# <class 'tuple'>
# (1227, Team         PHI
# League        NL
# Year        1962
# RS           705
# RA           759
# W             81
# G            161
# Playoffs       0
# Name: 1227, dtype: object)
# <class 'tuple'>
# (1228, Team         PIT
# League        NL
# Year        1962
# RS           706
# RA           626
# W             93
# G            161
# Playoffs       0
# Name: 1228, dtype: object)
# <class 'tuple'>
# (1229, Team         SFG
# League        NL
# Year        1962
# RS           878
# RA           690
# W            103
# G            165
# Playoffs       1
# Name: 1229, dtype: object)
# <class 'tuple'>
# (1230, Team         STL
# League        NL
# Year        1962
# RS           774
# RA           664
# W             84
# G            163
# Playoffs       0
# Name: 1230, dtype: object)
# <class 'tuple'>
# (1231, Team         WSA
# League        AL
# Year        1962
# RS           599
# RA           716
# W             60
# G            162
# Playoffs       0
# Name: 1231, dtype: object)
# <class 'tuple'>

# %% [markdown]
# **Note** : Sejak `.iterrows()` mengembalikan setiap baris DataFrame sebagai pasangan tuple (indeks, pandas Series), Anda dapat membagi tuple ini dan menggunakan indeks dan nilai-baris secara terpisah (seperti yang Anda lakukan dengan `for i,row in pit_df.iterrows()` ), atau Anda dapat menyimpan hasil `.iterrows()` dalam bentuk tuple (seperti yang Anda lakukan dengan `for row_tuple in pit_df.iterrows()` ).
#
# Jika menggunakan `i,row`, Anda dapat mengakses hal-hal dari baris menggunakan tanda kurung siku (mis. `row['Team']`). Jika menggunakan `row_tuple`, Anda harus menentukan elemen tuple mana yang ingin Anda akses sebelum meraih nama tim (mis., `row_tuple[1]['Team']`).
#
# Dengan pendekatan mana pun, menggunakan `.iterrows()` masih akan jauh lebih cepat daripada menggunakan `.iloc`.

# %% [markdown]
# ### Practice: Run differentials with .iterrows()
#
# Anda telah disewa oleh San Francisco Giants sebagai analis — selamat! Pemilik tim ingin Anda menghitung metrik yang disebut *run differential* untuk setiap musim dari tahun 2008 hingga 2012. Metrik ini dihitung dengan mengurangi jumlah total run yang diizinkan oleh tim dalam satu musim dari jumlah total run tim yang dicetak dalam suatu musim. `'RS'` berarti *runs scored* dan `'RA'` berarti *runs allowed*.
#
# Fungsi di bawah ini menghitung metrik ini:

# %%
def calc_run_diff(runs_scored, runs_allowed):

    run_diff = runs_scored - runs_allowed

    return run_diff

# %%
giants_df = pit_df[(pit_df['Team'] == 'SFG') & (pit_df['Year'] >= 2008)]

# %%
# Create an empty list to store run differentials
run_diffs = []

# Write a for loop and collect runs allowed and runs scored for each row
for i,row in giants_df.iterrows():
    runs_scored = row['RS']
    runs_allowed = row['RA']
    
    # Use the provided function to calculate run_diff for each row
    run_diff = calc_run_diff(runs_scored, runs_allowed)
    
    # Append each run differential to the output list
    run_diffs.append(run_diff)

giants_df['RD'] = run_diffs    
print(giants_df)
# Out:
#     Team League  Year   RS   RA   W    G  Playoffs   RD
# 24   SFG     NL  2012  718  649  94  162         1   69
# 54   SFG     NL  2011  570  578  86  162         0   -8
# 84   SFG     NL  2010  697  583  92  162         1  114
# 114  SFG     NL  2009  657  611  88  162         0   46
# 144  SFG     NL  2008  640  759  72  162         0 -119
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# **Note** : Lihatlah DataFrame `giants_df` dengan kolom *run differential* yang baru (`'RD'`) yang Anda buat di atas.
#
# Kolom `'Playoffs'` memberi tahu Anda jika suatu tim membuat playoff untuk musim tertentu. `1` berarti tim membuat babak playoff di musim itu dan `0` berarti tim tidak membuat babak playoff di musim itu.
#
# Apakah Anda memperhatikan bahwa di musim dengan *run differentials* tertinggi Giants membuat playoff? Bahkan, di kedua musim ini (2010 dan 2012), San Francisco Giants tidak hanya berhasil lolos tetapi juga memenangkan World Series! Keren!

# %% [markdown]
# ## Another iterator method: `.itertuples()`

# %% [markdown]
# ### Team wins data

# %%
team_wins_df = baseball_df[['Team', 'Year', 'W']]
team_wins_df = team_wins_df[team_wins_df['Year'] == 2012]

# %%
team_wins_df.head()
# Out:
#   Team  Year   W
# 0  ARI  2012  81
# 1  ATL  2012  94
# 2  BAL  2012  93
# 3  BOS  2012  69
# 4  CHC  2012  61

# %%
for row_tuple in team_wins_df.iterrows():
    print(row_tuple)
    print(type(row_tuple[1]))
# Out:
# (0, Team     ARI
# Year    2012
# W         81
# Name: 0, dtype: object)
# <class 'pandas.core.series.Series'>
# (1, Team     ATL
# Year    2012
# W         94
# Name: 1, dtype: object)
# <class 'pandas.core.series.Series'>
# (2, Team     BAL
# Year    2012
# W         93
# Name: 2, dtype: object)
# <class 'pandas.core.series.Series'>
# (3, Team     BOS
# Year    2012
# W         69
# Name: 3, dtype: object)
# <class 'pandas.core.series.Series'>
# (4, Team     CHC
# Year    2012
# W         61
# Name: 4, dtype: object)
# <class 'pandas.core.series.Series'>
# (5, Team     CHW
# Year    2012
# W         85
# Name: 5, dtype: object)
# <class 'pandas.core.series.Series'>
# (6, Team     CIN
# Year    2012
# W         97
# Name: 6, dtype: object)
# <class 'pandas.core.series.Series'>
# (7, Team     CLE
# Year    2012
# W         68
# Name: 7, dtype: object)
# <class 'pandas.core.series.Series'>
# (8, Team     COL
# Year    2012
# W         64
# Name: 8, dtype: object)
# <class 'pandas.core.series.Series'>
# (9, Team     DET
# Year    2012
# W         88
# Name: 9, dtype: object)
# <class 'pandas.core.series.Series'>
# (10, Team     HOU
# Year    2012
# W         55
# Name: 10, dtype: object)
# <class 'pandas.core.series.Series'>
# (11, Team     KCR
# Year    2012
# W         72
# Name: 11, dtype: object)
# <class 'pandas.core.series.Series'>
# (12, Team     LAA
# Year    2012
# W         89
# Name: 12, dtype: object)
# <class 'pandas.core.series.Series'>
# (13, Team     LAD
# Year    2012
# W         86
# Name: 13, dtype: object)
# <class 'pandas.core.series.Series'>
# (14, Team     MIA
# Year    2012
# W         69
# Name: 14, dtype: object)
# <class 'pandas.core.series.Series'>
# (15, Team     MIL
# Year    2012
# W         83
# Name: 15, dtype: object)
# <class 'pandas.core.series.Series'>
# (16, Team     MIN
# Year    2012
# W         66
# Name: 16, dtype: object)
# <class 'pandas.core.series.Series'>
# (17, Team     NYM
# Year    2012
# W         74
# Name: 17, dtype: object)
# <class 'pandas.core.series.Series'>
# (18, Team     NYY
# Year    2012
# W         95
# Name: 18, dtype: object)
# <class 'pandas.core.series.Series'>
# (19, Team     OAK
# Year    2012
# W         94
# Name: 19, dtype: object)
# <class 'pandas.core.series.Series'>
# (20, Team     PHI
# Year    2012
# W         81
# Name: 20, dtype: object)
# <class 'pandas.core.series.Series'>
# (21, Team     PIT
# Year    2012
# W         79
# Name: 21, dtype: object)
# <class 'pandas.core.series.Series'>
# (22, Team     SDP
# Year    2012
# W         76
# Name: 22, dtype: object)
# <class 'pandas.core.series.Series'>
# (23, Team     SEA
# Year    2012
# W         75
# Name: 23, dtype: object)
# <class 'pandas.core.series.Series'>
# (24, Team     SFG
# Year    2012
# W         94
# Name: 24, dtype: object)
# <class 'pandas.core.series.Series'>
# (25, Team     STL
# Year    2012
# W         88
# Name: 25, dtype: object)
# <class 'pandas.core.series.Series'>
# (26, Team     TBR
# Year    2012
# W         90
# Name: 26, dtype: object)
# <class 'pandas.core.series.Series'>
# (27, Team     TEX
# Year    2012
# W         93
# Name: 27, dtype: object)
# <class 'pandas.core.series.Series'>
# (28, Team     TOR
# Year    2012
# W         73
# Name: 28, dtype: object)
# <class 'pandas.core.series.Series'>
# (29, Team     WSN
# Year    2012
# W         98
# Name: 29, dtype: object)
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Iterating with .itertuples()

# %%
for row_namedtuple in team_wins_df.itertuples():
    print(row_namedtuple)
# Out:
# Pandas(Index=0, Team='ARI', Year=2012, W=81)
# Pandas(Index=1, Team='ATL', Year=2012, W=94)
# Pandas(Index=2, Team='BAL', Year=2012, W=93)
# Pandas(Index=3, Team='BOS', Year=2012, W=69)
# Pandas(Index=4, Team='CHC', Year=2012, W=61)
# Pandas(Index=5, Team='CHW', Year=2012, W=85)
# Pandas(Index=6, Team='CIN', Year=2012, W=97)
# Pandas(Index=7, Team='CLE', Year=2012, W=68)
# Pandas(Index=8, Team='COL', Year=2012, W=64)
# Pandas(Index=9, Team='DET', Year=2012, W=88)
# Pandas(Index=10, Team='HOU', Year=2012, W=55)
# Pandas(Index=11, Team='KCR', Year=2012, W=72)
# Pandas(Index=12, Team='LAA', Year=2012, W=89)
# Pandas(Index=13, Team='LAD', Year=2012, W=86)
# Pandas(Index=14, Team='MIA', Year=2012, W=69)
# Pandas(Index=15, Team='MIL', Year=2012, W=83)
# Pandas(Index=16, Team='MIN', Year=2012, W=66)
# Pandas(Index=17, Team='NYM', Year=2012, W=74)
# Pandas(Index=18, Team='NYY', Year=2012, W=95)
# Pandas(Index=19, Team='OAK', Year=2012, W=94)
# Pandas(Index=20, Team='PHI', Year=2012, W=81)
# Pandas(Index=21, Team='PIT', Year=2012, W=79)
# Pandas(Index=22, Team='SDP', Year=2012, W=76)
# Pandas(Index=23, Team='SEA', Year=2012, W=75)
# Pandas(Index=24, Team='SFG', Year=2012, W=94)
# Pandas(Index=25, Team='STL', Year=2012, W=88)
# Pandas(Index=26, Team='TBR', Year=2012, W=90)
# Pandas(Index=27, Team='TEX', Year=2012, W=93)
# Pandas(Index=28, Team='TOR', Year=2012, W=73)
# Pandas(Index=29, Team='WSN', Year=2012, W=98)

# %%
print(row_namedtuple.Index)
# Out:
# 29

# %%
print(row_namedtuple.Team)
# Out:
# WSN

# %% [markdown]
# ### Comparing methods

# %%
# %%timeit
for row_tuple in team_wins_df.iterrows():
    data = row_tuple
# Out:
# 2.63 ms ± 62.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
for row_namedtuple in team_wins_df.itertuples():
    data = row_namedtuple
# Out:
# 396 µs ± 3.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
for row_tuple in team_wins_df.iterrows():
    print(row_tuple[1]['Team'])
# Out:
# ARI
# ATL
# BAL
# BOS
# CHC
# CHW
# CIN
# CLE
# COL
# DET
# HOU
# KCR
# LAA
# LAD
# MIA
# MIL
# MIN
# NYM
# NYY
# OAK
# PHI
# PIT
# SDP
# SEA
# SFG
# STL
# TBR
# TEX
# TOR
# WSN

# %%
# TypeError: tuple indices must be integers or slices, not str
for row_namedtuple in team_wins_df.itertuples():
    print(row_namedtuple['Team'])

# %%
for row_namedtuple in team_wins_df.itertuples():
    print(row_namedtuple.Team)
# Out:
# ARI
# ATL
# BAL
# BOS
# CHC
# CHW
# CIN
# CLE
# COL
# DET
# HOU
# KCR
# LAA
# LAD
# MIA
# MIL
# MIN
# NYM
# NYY
# OAK
# PHI
# PIT
# SDP
# SEA
# SFG
# STL
# TBR
# TEX
# TOR
# WSN

# %% [markdown]
# ### Practice: Iterating with `.itertuples()`
#
# Ingat, `.itertuples()` mengembalikan setiap baris DataFrame sebagai tipe data khusus yang disebut **namedtuple**. Anda dapat mencari atribut dalam sebuah namedtuple dengan sintaks khusus. Mari kita berlatih bekerja dengan namedtuple.
#
# DataFrame pandas telah dimuat sebagai `rangers_df`. DataFrame ini berisi statistik (`'Team'`, `'League'`, `'Year'`, `'RS'`, `'RA'`, `'W'`, `'G'`, dan `'Playoffs'`) untuk tim baseball Liga Utama bernama Texas Rangers (disingkat `'TEX'`).

# %%
rangers_df = baseball_df[['Team', 'League', 'Year', 'RS', 'RA', 'W', 'G', 'Playoffs']]
rangers_df = baseball_df[baseball_df['Team'] == 'TEX']

# %%
# Loop over the DataFrame and print each row
for row in rangers_df.itertuples():
    print(row)
# Out:
# Pandas(Index=27, Team='TEX', League='AL', Year=2012, RS=808, RA=707, W=93, Playoffs=1, G=162, WP=0.57)
# Pandas(Index=57, Team='TEX', League='AL', Year=2011, RS=855, RA=677, W=96, Playoffs=1, G=162, WP=0.59)
# Pandas(Index=87, Team='TEX', League='AL', Year=2010, RS=787, RA=687, W=90, Playoffs=1, G=162, WP=0.56)
# Pandas(Index=117, Team='TEX', League='AL', Year=2009, RS=784, RA=740, W=87, Playoffs=0, G=162, WP=0.54)
# Pandas(Index=147, Team='TEX', League='AL', Year=2008, RS=901, RA=967, W=79, Playoffs=0, G=162, WP=0.49)
# Pandas(Index=177, Team='TEX', League='AL', Year=2007, RS=816, RA=844, W=75, Playoffs=0, G=162, WP=0.46)
# Pandas(Index=207, Team='TEX', League='AL', Year=2006, RS=835, RA=784, W=80, Playoffs=0, G=162, WP=0.49)
# Pandas(Index=237, Team='TEX', League='AL', Year=2005, RS=865, RA=858, W=79, Playoffs=0, G=162, WP=0.49)
# Pandas(Index=268, Team='TEX', League='AL', Year=2004, RS=860, RA=794, W=89, Playoffs=0, G=162, WP=0.55)
# Pandas(Index=298, Team='TEX', League='AL', Year=2003, RS=826, RA=969, W=71, Playoffs=0, G=162, WP=0.44)
# Pandas(Index=328, Team='TEX', League='AL', Year=2002, RS=843, RA=882, W=72, Playoffs=0, G=162, WP=0.44)
# Pandas(Index=358, Team='TEX', League='AL', Year=2001, RS=890, RA=968, W=73, Playoffs=0, G=162, WP=0.45)
# Pandas(Index=388, Team='TEX', League='AL', Year=2000, RS=848, RA=974, W=71, Playoffs=0, G=162, WP=0.44)
# Pandas(Index=418, Team='TEX', League='AL', Year=1999, RS=945, RA=859, W=95, Playoffs=1, G=162, WP=0.59)
# Pandas(Index=448, Team='TEX', League='AL', Year=1998, RS=940, RA=871, W=88, Playoffs=1, G=162, WP=0.54)
# Pandas(Index=476, Team='TEX', League='AL', Year=1997, RS=807, RA=823, W=77, Playoffs=0, G=162, WP=0.48)
# Pandas(Index=504, Team='TEX', League='AL', Year=1996, RS=928, RA=799, W=90, Playoffs=1, G=163, WP=0.55)
# Pandas(Index=532, Team='TEX', League='AL', Year=1993, RS=835, RA=751, W=86, Playoffs=0, G=162, WP=0.53)
# Pandas(Index=558, Team='TEX', League='AL', Year=1992, RS=682, RA=753, W=77, Playoffs=0, G=162, WP=0.48)
# Pandas(Index=584, Team='TEX', League='AL', Year=1991, RS=829, RA=814, W=85, Playoffs=0, G=162, WP=0.52)
# Pandas(Index=610, Team='TEX', League='AL', Year=1990, RS=676, RA=696, W=83, Playoffs=0, G=162, WP=0.51)
# Pandas(Index=636, Team='TEX', League='AL', Year=1989, RS=695, RA=714, W=83, Playoffs=0, G=162, WP=0.51)
# Pandas(Index=662, Team='TEX', League='AL', Year=1988, RS=637, RA=735, W=70, Playoffs=0, G=161, WP=0.43)
# Pandas(Index=688, Team='TEX', League='AL', Year=1987, RS=823, RA=849, W=75, Playoffs=0, G=162, WP=0.46)
# Pandas(Index=714, Team='TEX', League='AL', Year=1986, RS=771, RA=743, W=87, Playoffs=0, G=162, WP=0.54)
# Pandas(Index=740, Team='TEX', League='AL', Year=1985, RS=617, RA=785, W=62, Playoffs=0, G=161, WP=0.39)
# Pandas(Index=766, Team='TEX', League='AL', Year=1984, RS=656, RA=714, W=69, Playoffs=0, G=161, WP=0.43)
# Pandas(Index=792, Team='TEX', League='AL', Year=1983, RS=639, RA=609, W=77, Playoffs=0, G=163, WP=0.47)
# Pandas(Index=818, Team='TEX', League='AL', Year=1982, RS=590, RA=749, W=64, Playoffs=0, G=162, WP=0.4)
# Pandas(Index=844, Team='TEX', League='AL', Year=1980, RS=756, RA=752, W=76, Playoffs=0, G=163, WP=0.47)
# Pandas(Index=870, Team='TEX', League='AL', Year=1979, RS=750, RA=698, W=83, Playoffs=0, G=162, WP=0.51)
# Pandas(Index=896, Team='TEX', League='AL', Year=1978, RS=692, RA=632, W=87, Playoffs=0, G=162, WP=0.54)
# Pandas(Index=922, Team='TEX', League='AL', Year=1977, RS=767, RA=657, W=94, Playoffs=0, G=162, WP=0.58)
# Pandas(Index=947, Team='TEX', League='AL', Year=1976, RS=616, RA=652, W=76, Playoffs=0, G=162, WP=0.47)
# Pandas(Index=971, Team='TEX', League='AL', Year=1975, RS=714, RA=733, W=79, Playoffs=0, G=162, WP=0.49)
# Pandas(Index=995, Team='TEX', League='AL', Year=1974, RS=690, RA=698, W=83, Playoffs=0, G=161, WP=0.52)
# Pandas(Index=1019, Team='TEX', League='AL', Year=1973, RS=619, RA=844, W=57, Playoffs=0, G=162, WP=0.35)

# %%
# Loop over the DataFrame and print each row's Index, Year and Wins (W)
for row in rangers_df.itertuples():
    i = row.Index
    year = row.Year
    wins = row.W
    print(i, year, wins)
# Out:
# 27 2012 93
# 57 2011 96
# 87 2010 90
# 117 2009 87
# 147 2008 79
# 177 2007 75
# 207 2006 80
# 237 2005 79
# 268 2004 89
# 298 2003 71
# 328 2002 72
# 358 2001 73
# 388 2000 71
# 418 1999 95
# 448 1998 88
# 476 1997 77
# 504 1996 90
# 532 1993 86
# 558 1992 77
# 584 1991 85
# 610 1990 83
# 636 1989 83
# 662 1988 70
# 688 1987 75
# 714 1986 87
# 740 1985 62
# 766 1984 69
# 792 1983 77
# 818 1982 64
# 844 1980 76
# 870 1979 83
# 896 1978 87
# 922 1977 94
# 947 1976 76
# 971 1975 79
# 995 1974 83
# 1019 1973 57

# %%
# Loop over the DataFrame and print each row's Index, Year and Wins (W)
for row in rangers_df.itertuples():
    i = row.Index
    year = row.Year
    wins = row.W
  
    # Check if rangers made Playoffs (1 means yes; 0 means no)
    if row.Playoffs == 1:
        print(i, year, wins)
# Out:
# 27 2012 93
# 57 2011 96
# 87 2010 90
# 418 1999 95
# 448 1998 88
# 504 1996 90

# %% [markdown]
# **Note** : Anda terbiasa menggunakan `.itertuples()`. Ingat, Anda perlu menggunakan sintaks *dot* untuk mereferensikan atribut dalam **namedtuple**.
#
# Anda dapat membuat variabel baru menggunakan referensi titik baris (seperti yang Anda lakukan saat menyimpan `row.Index` sebagai variabel `i`). Atau Anda dapat menggunakan referensi titik baris secara langsung untuk melakukan perhitungan dan pemeriksaan. Perhatikan bahwa Anda tidak harus menyimpan `row.Playoffs` ke variabel baru dalam pernyataan `if` Anda (Anda dapat menggunakan `row.Playoffs` langsung di `if` Anda).
#
# Apakah Anda memperhatikan pola dalam penampilan playoff Texas Rangers? Hanya enam penampilan dan dua kelompok pengelompokan yang berbeda (satu dari 2010 - 2012 dan satu dari 1996 - 1999).

# %% [markdown]
# ### Practice: Run differentials with `.itertuples()`
#
# New York Yankees telah melakukan perdagangan dengan San Francisco Giants untuk kontrak analis Anda — Anda adalah komoditas panas! Bos baru Anda telah melihat pekerjaan Anda dengan Giants dan sekarang ingin Anda melakukan sesuatu yang mirip dengan data Yankees. Dia ingin Anda menghitung *run differentials* untuk Yankees dari tahun 1962 hingga tahun 2012 dan menemukan musim mana mereka memiliki *run differentials* terbaik.
#
# Anda ingat fungsi yang Anda gunakan saat bekerja dengan Giants :

# %%
def calc_run_diff(runs_scored, runs_allowed):

    run_diff = runs_scored - runs_allowed

    return run_diff

# %% [markdown]
# Mari kita gunakan `.itertuples()` untuk loop DataFrame `yankees_df`.

# %%
yankees_df = baseball_df[['Team', 'League', 'Year', 'RS', 'RA', 'W', 'G', 'Playoffs']]
yankees_df = baseball_df[baseball_df['Team'] == 'NYY'].reset_index()

# %%
run_diffs = []

# Loop over the DataFrame and calculate each row's run differential
for row in yankees_df.itertuples():
    
    runs_scored = row.RS
    runs_allowed = row.RA

    run_diff = calc_run_diff(runs_scored, runs_allowed)
    
    run_diffs.append(run_diff)

# Append new column
yankees_df['RD'] = run_diffs
print(yankees_df)
# Out:
#     index Team League  Year   RS   RA    W  Playoffs    G    WP   RD
# 0      18  NYY     AL  2012  804  668   95         1  162  0.59  136
# 1      48  NYY     AL  2011  867  657   97         1  162  0.60  210
# 2      78  NYY     AL  2010  859  693   95         1  162  0.59  166
# 3     108  NYY     AL  2009  915  753  103         1  162  0.64  162
# 4     138  NYY     AL  2008  789  727   89         0  162  0.55   62
# 5     168  NYY     AL  2007  968  777   94         1  162  0.58  191
# 6     198  NYY     AL  2006  930  767   97         1  162  0.60  163
# 7     228  NYY     AL  2005  886  789   95         1  162  0.59   97
# 8     259  NYY     AL  2004  897  808  101         1  162  0.62   89
# 9     289  NYY     AL  2003  877  716  101         1  163  0.62  161
# 10    319  NYY     AL  2002  897  697  103         1  161  0.64  200
# 11    349  NYY     AL  2001  804  713   95         1  161  0.59   91
# 12    379  NYY     AL  2000  871  814   87         1  161  0.54   57
# 13    409  NYY     AL  1999  900  731   98         1  162  0.60  169
# 14    439  NYY     AL  1998  965  656  114         1  162  0.70  309
# 15    468  NYY     AL  1997  891  688   96         1  162  0.59  203
# 16    496  NYY     AL  1996  871  787   92         1  162  0.57   84
# 17    524  NYY     AL  1993  821  761   88         0  162  0.54   60
# 18    550  NYY     AL  1992  733  746   76         0  162  0.47  -13
# 19    576  NYY     AL  1991  674  777   71         0  162  0.44 -103
# 20    602  NYY     AL  1990  603  749   67         0  162  0.41 -146
# 21    628  NYY     AL  1989  698  792   74         0  161  0.46  -94
# 22    654  NYY     AL  1988  772  748   85         0  161  0.53   24
# 23    680  NYY     AL  1987  788  758   89         0  162  0.55   30
# 24    706  NYY     AL  1986  797  738   90         0  162  0.56   59
# 25    732  NYY     AL  1985  839  660   97         0  161  0.60  179
# 26    758  NYY     AL  1984  758  679   87         0  162  0.54   79
# 27    784  NYY     AL  1983  770  703   91         0  162  0.56   67
# 28    810  NYY     AL  1982  709  716   79         0  162  0.49   -7
# 29    836  NYY     AL  1980  820  662  103         1  162  0.64  158
# 30    862  NYY     AL  1979  734  672   89         0  160  0.56   62
# 31    888  NYY     AL  1978  735  582  100         1  163  0.61  153
# 32    914  NYY     AL  1977  831  651  100         1  162  0.62  180
# 33    940  NYY     AL  1976  730  575   97         1  159  0.61  155
# 34    964  NYY     AL  1975  681  588   83         0  160  0.52   93
# 35    988  NYY     AL  1974  671  623   89         0  162  0.55   48
# 36   1012  NYY     AL  1973  641  610   80         0  162  0.49   31
# 37   1036  NYY     AL  1971  648  641   81         0  162  0.50    7
# 38   1060  NYY     AL  1970  680  612   93         0  163  0.57   68
# 39   1083  NYY     AL  1969  562  587   80         0  162  0.49  -25
# 40   1105  NYY     AL  1968  536  531   83         0  164  0.51    5
# 41   1126  NYY     AL  1967  522  621   72         0  163  0.44  -99
# 42   1146  NYY     AL  1966  611  612   70         0  160  0.44   -1
# 43   1166  NYY     AL  1965  611  604   77         0  162  0.48    7
# 44   1186  NYY     AL  1964  730  577   99         1  164  0.60  153
# 45   1206  NYY     AL  1963  714  547  104         1  161  0.65  167
# 46   1226  NYY     AL  1962  817  680   96         1  162  0.59  137

# %% [markdown]
# **Question**
#
# Pada tahun berapa di dalam DataFrame Anda, New York Yankees memiliki *run differential* tertinggi?
#
# * Pada tahun 1998 (dengan Run Diferensial 309)
#
# **Note** : Anda menggunakan `.itertuples()` untuk membantu Yankees menghitung *run differential*. Ingat, menggunakan `.itertuples()` sama seperti menggunakan `.iterrows()` kecuali itu cenderung lebih cepat. Anda juga harus menggunakan referensi *dot* ketika mencari atribut dengan `.itertuples()`.
#
# Anda menemukan bahwa *run differential* tertinggi Yankees adalah pada tahun 1998. Apakah Anda tahu mereka benar-benar memegang rekor untuk *run differential* tertinggi dalam musim MLB (411 pada tahun 1939 di mana RS 967 dan RA 556)? Wow!

# %% [markdown]
# ## pandas alternative to looping

# %% [markdown]
# ### pandas `.apply()` method
#
# * Mengambil fungsi dan menerapkannya ke DataFrame
#   * Harus menentukan sumbu untuk diterapkan ( 0 untuk kolom; 1 untuk baris)
# * Dapat digunakan dengan anonymous functions ( `lambda` functions)
#
# Contoh:

# %%
baseball_df.apply(lambda row: calc_run_diff(row['RS'], row['RA']), axis=1)
# Out:
# 0        46
# 1       100
# 2         7
# 3       -72
# 4      -146
#        ...
# 1227    -54
# 1228     80
# 1229    188
# 1230    110
# 1231   -117
# Length: 1232, dtype: int64

# %% [markdown]
# ### Run differentials with `.apply()`

# %%
run_diffs_apply = baseball_df.apply(lambda row: calc_run_diff(row['RS'], row['RA']), axis=1)
baseball_df['RD'] = run_diffs_apply
print(baseball_df)
# Out:
#      Team League  Year   RS   RA    W  Playoffs    G    WP   RD
# 0     ARI     NL  2012  734  688   81         0  162  0.50   46
# 1     ATL     NL  2012  700  600   94         1  162  0.58  100
# 2     BAL     AL  2012  712  705   93         1  162  0.57    7
# 3     BOS     AL  2012  734  806   69         0  162  0.43  -72
# 4     CHC     NL  2012  613  759   61         0  162  0.38 -146
# ...   ...    ...   ...  ...  ...  ...       ...  ...   ...  ...
# 1227  PHI     NL  1962  705  759   81         0  161  0.50  -54
# 1228  PIT     NL  1962  706  626   93         0  161  0.58   80
# 1229  SFG     NL  1962  878  690  103         1  165  0.62  188
# 1230  STL     NL  1962  774  664   84         0  163  0.52  110
# 1231  WSA     AL  1962  599  716   60         0  162  0.37 -117
#
# [1232 rows x 10 columns]

# %% [markdown]
# ### Comparing approaches

# %%
# %%timeit
run_diffs_iterrows = []

for i,row in baseball_df.iterrows():
    run_diff = calc_run_diff(row['RS'], row['RA'])
    run_diffs_iterrows.append(run_diff)
    
baseball_df['RD'] = run_diffs_iterrows
# Out:
# 135 ms ± 1.06 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
run_diffs_apply = baseball_df.apply(lambda row: calc_run_diff(row['RS'], row['RA']), axis=1)
baseball_df['RD'] = run_diffs_apply
# Out:
# 29.3 ms ± 406 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Analyzing baseball stats with `.apply()`
#
# Tampa Bay Rays ingin Anda menganalisis data mereka.
#
# Mereka menginginkan metrik sebagai berikut:
# * Jumlah setiap kolom dalam data
# * Jumlah total *runs scored* dalam setahun ( `'RS'` + `'RA'` untuk setiap tahun)
# * Kolom `'Playoffs'` dalam format teks daripada menggunakan angka `1` dan `0`
#
# Fungsi di bawah ini dapat digunakan untuk mengonversi kolom `'Playoffs'` menjadi teks:

# %%
def text_playoffs(num_playoffs): 
    if num_playoffs == 1:
        return 'Yes'
    else:
        return 'No'

# %% [markdown]
# Gunakan `.apply()` untuk mendapatkan metrik ini. DataFrame ( `rays_df` ) telah dimuat. DataFrame ini diindeks pada kolom `'Year'`.

# %%
rays_df_filter = baseball_df[baseball_df['Team'] == 'TBR']

# %%
rays_df = rays_df_filter[['Year','RS','RA','W','Playoffs']].set_index('Year')

# %%
rays_df
# Out:
#        RS   RA   W  Playoffs
# Year
# 2012  697  577  90         0
# 2011  707  614  91         1
# 2010  802  649  96         1
# 2009  803  754  84         0
# 2008  774  671  97         1

# %%
# Gather sum of all columns
stat_totals = rays_df.apply(sum, axis=0)
print(stat_totals)
# Out:
# RS          3783
# RA          3265
# W            458
# Playoffs       3
# dtype: int64

# %%
# Gather total runs scored in all games per year
total_runs_scored = rays_df[['RS', 'RA']].apply(sum, axis=1)
print(total_runs_scored)
# Out:
# Year
# 2012    1274
# 2011    1321
# 2010    1451
# 2009    1557
# 2008    1445
# dtype: int64

# %%
# Convert numeric playoffs to text
textual_playoffs = rays_df.apply(lambda row: text_playoffs(row['Playoffs']), axis=1)
print(textual_playoffs)
# Out:
# Year
# 2012     No
# 2011    Yes
# 2010    Yes
# 2009     No
# 2008    Yes
# dtype: object

# %% [markdown]
# **Note** : Metode `.apply()` memungkinkan Anda menerapkan fungsi ke semua baris atau kolom DataFrame dengan menentukan sumbu/axis.
#
# Jika Anda telah menggunakan pandas untuk beberapa waktu, Anda mungkin telah memperhatikan bahwa cara yang lebih baik untuk menemukan statistik ini adalah menggunakan metode bawaan pandas `.sum()`.
#
# Anda bisa menggunakan `rays_df.sum(axis=0)` untuk mendapatkan jumlah kolom dan `rays_df[['RS', 'RA']].sum(axis=1)` untuk mendapatkan jumlah baris.
#
# Anda juga bisa menggunakan `.apply()` langsung pada Series (atau kolom) dari DataFrame. Misalnya, Anda bisa menggunakan `rays_df['Playoffs'].apply(text_playoffs)` untuk mengkonversi kolom `'Playoffs'` ke text.

# %% [markdown]
# ### Settle a debate with `.apply()`
#
# Sudah ada kabar sampai ke Arizona Diamondbacks tentang keterampilan analitik Anda yang luar biasa. Mereka ingin Anda membantu menyelesaikan perdebatan di antara para manajer. Satu manajer mengklaim bahwa tim telah membuat babak playoff setiap tahun mereka memiliki persentase kemenangan 0,50 atau lebih besar. Manajer lain mengatakan ini tidak benar.
#
# Mari kita gunakan fungsi di bawah ini dan metode `.apply()` untuk melihat manajer mana yang benar.

# %%
def calc_win_perc(wins, games_played):
    
    win_perc = wins / games_played
    return np.round(win_perc, 2)

# %%
ari_df_filter = baseball_df[baseball_df['Team'] == 'ARI']
dbacks_df = ari_df_filter[['Team','League','Year','RS','RA','W','G','Playoffs']].reset_index()

# %%
# Display the first five rows of the DataFrame
dbacks_df.head()
# Out:
#    index Team League  Year   RS   RA   W    G  Playoffs
# 0      0  ARI     NL  2012  734  688  81  162         0
# 1     30  ARI     NL  2011  731  662  94  162         1
# 2     60  ARI     NL  2010  713  836  65  162         0
# 3     90  ARI     NL  2009  720  782  70  162         0
# 4    120  ARI     NL  2008  720  706  82  162         0

# %%
# Create a win percentage Series 
win_percs = dbacks_df.apply(lambda row: calc_win_perc(row['W'], row['G']), axis=1)
print(win_percs, '\n')
# Out:
# 0     0.50
# 1     0.58
# 2     0.40
# 3     0.43
# 4     0.51
# 5     0.56
# 6     0.47
# 7     0.48
# 8     0.31
# 9     0.52
# 10    0.60
# 11    0.57
# 12    0.52
# 13    0.62
# 14    0.40
# dtype: float64

# %%
# Append a new column to dbacks_df
dbacks_df['WP'] = win_percs
print(dbacks_df, '\n')

# Display dbacks_df where WP is greater than 0.50
print(dbacks_df[dbacks_df['WP'] >= 0.50])
# Out:
#     index Team League  Year   RS   RA    W    G  Playoffs    WP
# 0       0  ARI     NL  2012  734  688   81  162         0  0.50
# 1      30  ARI     NL  2011  731  662   94  162         1  0.58
# 2      60  ARI     NL  2010  713  836   65  162         0  0.40
# 3      90  ARI     NL  2009  720  782   70  162         0  0.43
# 4     120  ARI     NL  2008  720  706   82  162         0  0.51
# 5     150  ARI     NL  2007  712  732   90  162         1  0.56
# 6     180  ARI     NL  2006  773  788   76  162         0  0.47
# 7     210  ARI     NL  2005  696  856   77  162         0  0.48
# 8     241  ARI     NL  2004  615  899   51  162         0  0.31
# 9     271  ARI     NL  2003  717  685   84  162         0  0.52
# 10    301  ARI     NL  2002  819  674   98  162         1  0.60
# 11    331  ARI     NL  2001  818  677   92  162         1  0.57
# 12    361  ARI     NL  2000  792  754   85  162         0  0.52
# 13    391  ARI     NL  1999  908  676  100  162         1  0.62
# 14    421  ARI     NL  1998  665  812   65  162         0  0.40
#
#     index Team League  Year   RS   RA    W    G  Playoffs    WP
# 0       0  ARI     NL  2012  734  688   81  162         0  0.50
# 1      30  ARI     NL  2011  731  662   94  162         1  0.58
# 4     120  ARI     NL  2008  720  706   82  162         0  0.51
# 5     150  ARI     NL  2007  712  732   90  162         1  0.56
# 9     271  ARI     NL  2003  717  685   84  162         0  0.52
# 10    301  ARI     NL  2002  819  674   98  162         1  0.60
# 11    331  ARI     NL  2001  818  677   92  162         1  0.57
# 12    361  ARI     NL  2000  792  754   85  162         0  0.52
# 13    391  ARI     NL  1999  908  676  100  162         1  0.62

# %% [markdown]
# **Question**
#
# Manajer mana yang benar dalam klaim mereka?
#
# * Manajer yang mengklaim **tim belum membuat** babak playoff setiap tahun mereka memiliki persentase kemenangan 0,50 atau lebih besar.
#
# **Note** : Menggunakan metode `.apply()` dengan fungsi `lambda` memungkinkan Anda untuk menerapkan fungsi ke DataFrame tanpa perlu menulis `for` loop.
#
# Sayangnya, manajer kedua benar. Pada tahun 2012, 2008, 2003, dan 2000 Arizona Diamondbacks memiliki persentase kemenangan yang lebih besar dari atau sama dengan 0.50, tetapi masih belum mencapai babak playoff.

# %% [markdown]
# ## Optimal pandas iterating

# %% [markdown]
# ### pandas internals
#
# * Menghilangkan loop juga berlaku untuk menggunakan pandas
# * panda dibangun di atas NumPy
#   * Manfaatkan efisiensi NumPy array

# %%
wins_np = baseball_df['W'].values
print(type(wins_np))
# Out:
# <class 'numpy.ndarray'>

# %%
print(wins_np)
# Out:
# [ 81  94  93 ... 103  84  60]

# %% [markdown]
# ### Power of vectorization
#
# * Broadcasting (vectorizing) sangat efisien!

# %%
baseball_df['RS'].values - baseball_df['RA'].values
# Out:
# array([  46,  100,    7, ...,  188,  110, -117])

# %% [markdown]
# ### Run differentials with arrays

# %%
run_diffs_np = baseball_df['RS'].values - baseball_df['RA'].values
baseball_df['RD'] = run_diffs_np
print(baseball_df)
# Out:
#      Team League  Year   RS   RA    W  Playoffs    G    WP   RD
# 0     ARI     NL  2012  734  688   81         0  162  0.50   46
# 1     ATL     NL  2012  700  600   94         1  162  0.58  100
# 2     BAL     AL  2012  712  705   93         1  162  0.57    7
# 3     BOS     AL  2012  734  806   69         0  162  0.43  -72
# 4     CHC     NL  2012  613  759   61         0  162  0.38 -146
# ...   ...    ...   ...  ...  ...  ...       ...  ...   ...  ...
# 1227  PHI     NL  1962  705  759   81         0  161  0.50  -54
# 1228  PIT     NL  1962  706  626   93         0  161  0.58   80
# 1229  SFG     NL  1962  878  690  103         1  165  0.62  188
# 1230  STL     NL  1962  774  664   84         0  163  0.52  110
# 1231  WSA     AL  1962  599  716   60         0  162  0.37 -117
#
# [1232 rows x 10 columns]

# %% [markdown]
# ### Comparing approaches

# %%
# %%timeit
run_diffs_np = baseball_df['RS'].values - baseball_df['RA'].values

baseball_df['RD'] = run_diffs_np
# Out:
# 149 µs ± 1.17 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ### Replacing .iloc with underlying arrays
#
# Sekarang setelah Anda memiliki pemahaman yang lebih baik tentang internal DataFrame mari memperbarui salah satu analisis Anda sebelumnya untuk memanfaatkan array yang mendasari DataFrame. Anda akan mengunjungi kembali perhitungan persentase kemenangan yang Anda lakukan baris demi baris dengan metode `.iloc`:

# %%
def calc_win_perc(wins, games_played):
    win_perc = wins / games_played
    return np.round(win_perc,2)

win_percs_list = []

for i in range(len(baseball_df)):
    row = baseball_df.iloc[i]

    wins = row['W']
    games_played = row['G']

    win_perc = calc_win_perc(wins, games_played)

    win_percs_list.append(win_perc)

baseball_df['WP'] = win_percs_list

# %% [markdown]
# Mari kita perbarui analisis ini untuk menggunakan array alih-alih metode `.iloc`.

# %%
# Use the W array and G array to calculate win percentages
win_percs_np = calc_win_perc(baseball_df['W'].values, baseball_df['G'].values)

# Append a new column to baseball_df that stores all win percentages
baseball_df['WP'] = win_percs_np

baseball_df.head()
# Out:
#   Team League  Year   RS   RA   W  Playoffs    G    WP
# 0  ARI     NL  2012  734  688  81         0  162  0.50
# 1  ATL     NL  2012  700  600  94         1  162  0.58
# 2  BAL     AL  2012  712  705  93         1  162  0.57
# 3  BOS     AL  2012  734  806  69         0  162  0.43
# 4  CHC     NL  2012  613  759  61         0  162  0.38

# %% [markdown]
# **Question**
#
# Gunakan `timeit` dalam (*cell magic mode*) di dalam konsol IPython Anda untuk membandingkan runtime antara blok kode lama menggunakan `.iloc` dan kode baru yang Anda kembangkan menggunakan NumPy array.
#
# Jangan sertakan kode yang mendefinisikan fungsi `calc_win_perc()` atau pernyataan `print()` saat penghitungan waktu.
#
# Anda harus memasukkan **delapan baris kode** saat menghitung waktu blok kode lama dan **dua baris kode** saat menghitung waktu kode baru yang Anda kembangkan.

# %%
# %%timeit
win_percs_list = []
for i in range(len(baseball_df)):
    row = baseball_df.iloc[i]
    wins = row['W']
    games_played = row['G']
    win_perc = calc_win_perc(wins, games_played)
    win_percs_list.append(win_perc)
baseball_df['WP'] = win_percs_list
# Out:
# 256 ms ± 4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
win_percs_np = calc_win_perc(baseball_df['W'].values, baseball_df['G'].values)
baseball_df['WP'] = win_percs_np
# Out:
# 177 µs ± 8.78 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# **Answer** : Pendekatan `NumPy` array lebih cepat dari pendekatan `.iloc`.
#
# Menggunakan array yang mendasari DataFrame untuk melakukan perhitungan benar-benar dapat mempercepat kode Anda dan menghasilkan beberapa keuntungan efisiensi yang signifikan. Apakah Anda memperhatikan bahwa pendekatan NumPy array tidak hanya lebih cepat, tetapi juga menggunakan lebih sedikit baris kode dan lebih mudah dibaca?

# %% [markdown]
# ### Bringing it all together: Predict win percentage
#
# Anda ingin mencoba *memprediksi* persentase kemenangan tim untuk musim tertentu dengan menggunakan total skor lari tim dalam satu musim ('RS') dan total lari yang diizinkan dalam satu musim ('RA') dengan fungsi berikut:

# %%
def predict_win_perc(RS, RA):
    prediction = RS ** 2 / (RS ** 2 + RA ** 2)
    return np.round(prediction, 2)

# %% [markdown]
# Mari kita bandingkan pendekatan yang telah Anda pelajari untuk menghitung prediksi persentase kemenangan untuk setiap musim (atau baris) di DataFrame Anda.

# %%
win_perc_preds_loop = []

# Use a loop and .itertuples() to collect each row's predicted win percentage
for row in baseball_df.itertuples():
    runs_scored = row.RS
    runs_allowed = row.RA
    win_perc_pred = predict_win_perc(runs_scored, runs_allowed)
    win_perc_preds_loop.append(win_perc_pred)

# Apply predict_win_perc to each row of the DataFrame
win_perc_preds_apply = baseball_df.apply(lambda row: predict_win_perc(row['RS'], row['RA']), axis=1)

# Calculate the win percentage predictions using NumPy arrays
win_perc_preds_np = predict_win_perc(baseball_df['RS'].values, baseball_df['RA'].values)
baseball_df['WP_preds'] = win_perc_preds_np
print(baseball_df.head())
# Out:
#   Team League  Year   RS   RA   W  Playoffs    G    WP  WP_preds
# 0  ARI     NL  2012  734  688  81         0  162  0.50      0.53
# 1  ATL     NL  2012  700  600  94         1  162  0.58      0.58
# 2  BAL     AL  2012  712  705  93         1  162  0.57      0.50
# 3  BOS     AL  2012  734  806  69         0  162  0.43      0.45
# 4  CHC     NL  2012  613  759  61         0  162  0.38      0.39

# %% [markdown]
# **Question**
#
# Bagaimana urutan pendekatan dari tercepat ke paling lambat?

# %%
# %%timeit
win_perc_preds_loop = []
for row in baseball_df.itertuples():
    runs_scored = row.RS
    runs_allowed = row.RA
    win_perc_pred = predict_win_perc(runs_scored, runs_allowed)
    win_perc_preds_loop.append(win_perc_pred)
# Out:
# 16.8 ms ± 242 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit win_perc_preds_apply = baseball_df.apply(lambda row: predict_win_perc(row['RS'], row['RA']), axis=1)
# Out:
# 46.2 ms ± 831 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit win_perc_preds_np = predict_win_perc(baseball_df['RS'].values, baseball_df['RA'].values)
# Out:
# 37.4 µs ± 340 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# **Answer**
#
# Menggunakan `NumPy array` adalah pendekatan **tercepat**, diikuti oleh pendekatan `.itertuples()`, dan pendekatan `.apply()` **paling lambat**.
#
# Anda berlatih menggunakan tiga pendekatan berbeda untuk iterate menggunakan DataFrame pandas dan melakukan perhitungan. Apakah Anda memperhatikan bahwa pendekatan `.itertuples()` mengalahkan pendekatan `.apply()`? Meskipun kedua implementasi ini bisa berguna, Anda harus menggunakan default untuk array yang mendasari DataFrame untuk melakukan perhitungan.
#
# Lihatlah prediksi persentase kemenangan Anda (kolom `'WP_preds'`) dan bandingkan dengan persentase kemenangan aktual (kolom `'WP'`). Tidak buruk!
#
# Anda telah melakukan pekerjaan luar biasa selama kursus! Sekarang, Anda sudah siap untuk menulis kode Python dan pandas yang efisien!

# %% [markdown]
# ## What you have learned
#
# * Definisi kode **efisien** dan **Pythonic**
# * Cara menggunakan library bawaan Python yang powerful
# * Keuntungan dari NumPy arrays
# * Beberapa perintah *magic* yang berguna untuk kode profil
# * Cara menggunakan solusi yang efisien dengan `zip()`, `itertools`, `collections`, dan teori `set` .
# * *The cost of looping and how to eliminate loops*
# * Praktik terbaik untuk iterasi dengan pandas DataFrames
